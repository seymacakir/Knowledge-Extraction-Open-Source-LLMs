# %%
# !pip install datasets transformers torch torchvision torchaudio evaluate tqdm
# !pip install requests>=2.32.2
# !pip install accelerate
# !pip install transformers[sentencepiece]
# !pip install transformers[torch]
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.20.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.18.0+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.3.0+cu121)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.10/dist-packages (0.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.5.82)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.32.1)
# Requirement already satisfied: numpy<2.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.3.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.23.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.5.82)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: transformers[sentencepiece] in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (4.66.4)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.1.99)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers[sentencepiece]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers[sentencepiece]) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[sentencepiece]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[sentencepiece]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[sentencepiece]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[sentencepiece]) (2024.6.2)
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.3.0+cu121)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.32.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers[torch]) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->transformers[torch]) (12.5.82)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->transformers[torch]) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->transformers[torch]) (1.3.0)

# %%
import datasets
import json
import numpy as np
import evaluate
import torch
import torch.nn.functional as F
from datasets import Dataset, DatasetDict
from transformers import AutoTokenizer
from transformers import AutoModelForQuestionAnswering
import collections
from tqdm.auto import tqdm
from transformers import TrainingArguments
from transformers import Trainer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load the SQuAD JSON files
with open('/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/SQuAD/train-v2.0.json') as train:
    train_data = json.load(train)
with open('/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/SQuAD/dev-v2.0.json') as dev:
    dev_data = json.load(dev)

# Extract the 'data' field which contains the actual dataset
training_data = train_data['data']
validation_data = dev_data['data']

# # Verify the structure of the loaded data
# print("Sample from training data:")
# print(json.dumps(training_data[0], indent=2))

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# Function to transform the data into the required format
def transform_data(data):
    transformed_data = {
        'id': [],
        'title': [],
        'context': [],
        'question': [],
        'answers': []
    }
    for article in data['data']:
        title = article['title']
        for paragraph in article['paragraphs']:
            context = paragraph['context']
            for qa in paragraph['qas']:
                transformed_data['id'].append(qa['id'])
                transformed_data['title'].append(title)
                transformed_data['context'].append(context)
                transformed_data['question'].append(qa['question'])
                transformed_data['answers'].append({
                    'text': [answer['text'] for answer in qa['answers']],
                    'answer_start': [answer['answer_start'] for answer in qa['answers']]
                })
    return transformed_data

# Transform the data
train_transformed = transform_data(train_data)
dev_transformed = transform_data(dev_data)

# Create Dataset objects
train_dataset = Dataset.from_dict(train_transformed)
dev_dataset = Dataset.from_dict(dev_transformed)

# Create a DatasetDict with the Dataset objects to prepare it processing
raw_datasets = DatasetDict({
    'train': train_dataset,
    'validation': dev_dataset
})

# %%
# Transform the data
train_transformed = transform_data(train_data)
dev_transformed = transform_data(dev_data)

# Create Dataset objects
train_dataset = Dataset.from_dict(train_transformed)
dev_dataset = Dataset.from_dict(dev_transformed)

# Create a DatasetDict with the Dataset objects to prepare it processing
raw_datasets = DatasetDict({
    'train': train_dataset,
    'validation': dev_dataset
})

# %%
print(raw_datasets)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 130319
#     })
#     validation: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 11873
#     })
# })

# %%
def remove_empty_answers(dataset):
    def is_valid_example(example):
        return len(example['answers']['text']) > 0

    return dataset.filter(is_valid_example)

# %%
# filtering out examples (question-answer pairs) where there are no answers.
# Converts the given SQUAD 2.0 dataset into SQUAD 1.0 dataset

train_dataset_cleaned = remove_empty_answers(raw_datasets["train"])
# Out:
# Filter:   0%|          | 0/130319 [00:00<?, ? examples/s]

# %%
# bring the train and validation sets together in a single dictionary

raw_datasets_processed = DatasetDict({
    'train': train_dataset_cleaned,
    'validation': raw_datasets["validation"]
})

# %%
# Check the structure
print("Context: ", raw_datasets_processed["train"][3]["context"])
print("Question: ", raw_datasets_processed["train"][3]["question"])
print("Answer: ", raw_datasets_processed["train"][3]["answers"])
# Out:
# Context:  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".
# Question:  In what city and state did Beyonce  grow up?
# Answer:  {'answer_start': [166], 'text': ['Houston, Texas']}

# %%
raw_datasets_processed["validation"]
# Out:
# Dataset({
#     features: ['id', 'title', 'context', 'question', 'answers'],
#     num_rows: 11873
# })

# %%
# Overall, this code is initializing a tokenizer specifically designed
# for the "roberta-base" pre-trained model. This tokenizer will be
# used to process text data in a way that the model can understand.

model_checkpoint = "FacebookAI/roberta-base"
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.22k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]

# %%
tokenizer.is_fast
# Out:
# True

# %%
max_length = 384 # The maximum length of a feature (question and context)
doc_stride = 128 # The authorized overlap between two part of the context when splitting it is needed.

# %%
# For this notebook to work with any kind of models, we need to account for the special case where
# the model expects padding on the left (in which case we switch the order of the question and the context):
pad_on_right = tokenizer.padding_side == "right"

# %%
def prepare_train_features(examples):
    # Some of the questions have lots of whitespace on the left, which is not useful and will make the
    # truncation of the context fail (the tokenized question will take a lots of space). So we remove that
    # left whitespace
    examples["question"] = [q.lstrip() for q in examples["question"]]

    # Tokenize our examples with truncation and padding, but keep the overflows using a stride. This results
    # in one example possible giving several features when a context is long, each of those features having a
    # context that overlaps a bit the context of the previous feature.
    tokenized_examples = tokenizer(
        examples["question" if pad_on_right else "context"],
        examples["context" if pad_on_right else "question"],
        truncation="only_second" if pad_on_right else "only_first",
        max_length=max_length,
        stride=doc_stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )

    # Since one example might give us several features if it has a long context, we need a map from a feature to
    # its corresponding example. This key gives us just that.
    sample_mapping = tokenized_examples.pop("overflow_to_sample_mapping")
    # The offset mappings will give us a map from token to character position in the original context. This will
    # help us compute the start_positions and end_positions.
    offset_mapping = tokenized_examples.pop("offset_mapping")

    # Let's label those examples!
    tokenized_examples["start_positions"] = []
    tokenized_examples["end_positions"] = []

    for i, offsets in enumerate(offset_mapping):
        # We will label impossible answers with the index of the CLS token.
        input_ids = tokenized_examples["input_ids"][i]
        cls_index = input_ids.index(tokenizer.cls_token_id)

        # Grab the sequence corresponding to that example (to know what is the context and what is the question).
        sequence_ids = tokenized_examples.sequence_ids(i)

        # One example can give several spans, this is the index of the example containing this span of text.
        sample_index = sample_mapping[i]
        answers = examples["answers"][sample_index]
        # If no answers are given, set the cls_index as answer.
        if len(answers["answer_start"]) == 0:
            tokenized_examples["start_positions"].append(cls_index)
            tokenized_examples["end_positions"].append(cls_index)
        else:
            # Start/end character index of the answer in the text.
            start_char = answers["answer_start"][0]
            end_char = start_char + len(answers["text"][0])

            # Start token index of the current span in the text.
            token_start_index = 0
            while sequence_ids[token_start_index] != (1 if pad_on_right else 0):
                token_start_index += 1

            # End token index of the current span in the text.
            token_end_index = len(input_ids) - 1
            while sequence_ids[token_end_index] != (1 if pad_on_right else 0):
                token_end_index -= 1

            # Detect if the answer is out of the span (in which case this feature is labeled with the CLS index).
            if not (offsets[token_start_index][0] <= start_char and offsets[token_end_index][1] >= end_char):
                tokenized_examples["start_positions"].append(cls_index)
                tokenized_examples["end_positions"].append(cls_index)
            else:
                # Otherwise move the token_start_index and token_end_index to the two ends of the answer.
                # Note: we could go after the last offset if the answer is the last word (edge case).
                while token_start_index < len(offsets) and offsets[token_start_index][0] <= start_char:
                    token_start_index += 1
                tokenized_examples["start_positions"].append(token_start_index - 1)
                while offsets[token_end_index][1] >= end_char:
                    token_end_index -= 1
                tokenized_examples["end_positions"].append(token_end_index + 1)

    return tokenized_examples

# %%
tokenized_datasets = raw_datasets_processed.map(prepare_train_features, batched=True, remove_columns=raw_datasets_processed["train"].column_names)
# Out:
# Map:   0%|          | 0/86821 [00:00<?, ? examples/s]
# Map:   0%|          | 0/11873 [00:00<?, ? examples/s]

# %%
# Load the pretrained model for question answering.

model = AutoModelForQuestionAnswering.from_pretrained(model_checkpoint)
# Out:
# config.json:   0%|          | 0.00/692 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/496M [00:00<?, ?B/s]

# %%
model_name = model_checkpoint.split("/")[-1]
batch_size = 16

args = TrainingArguments(
    f"{model_name}-finetuned-squad",
    evaluation_strategy = "epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=1,
    weight_decay=0.01,
    push_to_hub=True,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1474: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
# make sure GPU is ready
import tensorflow as tf
tf.test.gpu_device_name()
tf.config.list_physical_devices('GPU')
# Out:
# '/device:GPU:0'

# %%
from transformers import default_data_collator
data_collator = default_data_collator

# %%
# Instantiate Trainer
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    data_collator=data_collator,
    tokenizer=tokenizer,
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='5487' max='5487' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5487/5487 1:48:02, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.865900</td>
#       <td>5.364106</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=5487, training_loss=0.9881501695769547, metrics={'train_runtime': 6483.6298, 'train_samples_per_second': 13.539, 'train_steps_per_second': 0.846, 'total_flos': 1.7202276007147008e+16, 'train_loss': 0.9881501695769547, 'epoch': 1.0})

# %%
trainer.save_model("squad-trained-1epoch")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-89fe5f4904e2> in <cell line: 1>()
# ----> 1 trainer.save_model("squad-trained-1epoch")
#
# NameError: name 'trainer' is not defined

# %%
trainer.push_to_hub("f-arnold/roberta-finetuned-squad-1epoch")
# Out:
# CommitInfo(commit_url='https://huggingface.co/f-arnold/roberta-base-finetuned-squad/commit/62dec1deb2dd1c6c14267ffd7386c65f5bb21586', commit_message='f-arnold/roberta-finetuned-squad-1epoch', commit_description='', oid='62dec1deb2dd1c6c14267ffd7386c65f5bb21586', pr_url=None, pr_revision=None, pr_num=None)

# %%
# Load the pretrained model for question answering.

model = AutoModelForQuestionAnswering.from_pretrained("f-arnold/roberta-base-finetuned-squad")

# %%
# Define a function that generates predictions from the model.

def make_predictions(model, dataset, batch_size=16, no_answer_threshold=0.5):
    model.eval()
    model.to("cuda")  # Move the model to GPU
    predictions = []

    with torch.no_grad():
        for i in tqdm(range(0, len(dataset), batch_size)):
            batch = dataset[i:i + batch_size]

            # Prepare inputs and move them to GPU
            inputs = {
                key: torch.tensor(val).to("cuda")
                for key, val in batch.items()
                if key in ["input_ids", "attention_mask"]
            }
            outputs = model(**inputs)

            start_logits = outputs.start_logits.cpu().numpy()
            end_logits = outputs.end_logits.cpu().numpy()

            # Calculate no-answer probability
            no_answer_prob = F.softmax(torch.tensor((start_logits[:, 0] + end_logits[:, 0]) / 2), dim=-1).cpu().numpy()

            for j, example_id in enumerate(batch["example_id"]):
                start_idx = np.argmax(start_logits[j])
                end_idx = np.argmax(end_logits[j])
                no_ans_prob = no_answer_prob[j]

                # Check if the no-answer probability exceeds the threshold
                if no_ans_prob > no_answer_threshold:
                    prediction = (example_id, None, None, no_ans_prob)
                else:
                    prediction = (example_id, start_idx, end_idx, no_ans_prob)
                predictions.append(prediction)

    return predictions

# %%
def postprocess_predictions(dataset, predictions):
    # Aggregate predictions by example_id
    example_predictions = collections.defaultdict(list)
    for example, (example_id, start_idx, end_idx, no_answer_prob) in zip(dataset, predictions):
        offsets = example["offset_mapping"]
        context = example["context"]

        if start_idx is None or end_idx is None or start_idx >= len(offsets) or end_idx >= len(offsets):
            text = ""
        else:
            while start_idx < len(offsets) and offsets[start_idx] is None:
                start_idx += 1
            while end_idx >= 0 and offsets[end_idx] is None:
                end_idx -= 1

            if start_idx >= len(offsets) or end_idx < 0 or offsets[start_idx] is None or offsets[end_idx] is None:
                text = ""
            else:
                start_char = offsets[start_idx][0]
                end_char = offsets[end_idx][1]
                text = context[start_char:end_char]

        example_predictions[example_id].append({
            "text": text,
            "no_answer_prob": no_answer_prob
        })

    # Choose the best prediction per example_id (e.g., the one with the lowest no_answer_prob)
    formatted_predictions = [
        {
            "id": example_id,
            "answer": min(preds, key=lambda x: x["no_answer_prob"])["text"],
            "no_answer_probability": min(preds, key=lambda x: x["no_answer_prob"])["no_answer_prob"]
        }
        for example_id, preds in example_predictions.items()
    ]

    return formatted_predictions

# %%
import torch.nn.functional as F

# %%
# preprocesses validation data for question answering in a similar way to the training function.
# It performs tokenization, handles potential splitting due to the sliding window,
# and prepares the data for evaluation by the model.

def preprocess_validation_examples(examples):
    questions = [q.strip() for q in examples["question"]]
    inputs = tokenizer(
        questions,
        examples["context"],
        max_length=max_length,
        truncation="only_second",
        stride=stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )

    sample_map = inputs.pop("overflow_to_sample_mapping")
    example_ids = []
    contexts = []

    for i in range(len(inputs["input_ids"])):
        sample_idx = sample_map[i]
        example_ids.append(examples["id"][sample_idx])
        contexts.append(examples["context"][sample_idx])

        sequence_ids = inputs.sequence_ids(i)
        offset = inputs["offset_mapping"][i]
        inputs["offset_mapping"][i] = [
            o if sequence_ids[k] == 1 else None for k, o in enumerate(offset)
        ]

    inputs["example_id"] = example_ids
    inputs["context"] = contexts
    return inputs

# %%
max_length = 384
stride = 128
validation_dataset = raw_datasets["validation"].map(
    preprocess_validation_examples,
    batched=True,
    remove_columns=raw_datasets["validation"].column_names,
)
# Out:
# Map:   0%|          | 0/11873 [00:00<?, ? examples/s]

#  ('57094b4f9928a814004714f9', 118, 119, 0.06497604),
#  ('57094b4f9928a814004714fa', 137, 138, 0.05107326),
#  ('5a2c14b4bfd06b001a5ae9d3', 25, 26, 0.049387176),
#  ('5a2c14b4bfd06b001a5ae9d4', 121, 122, 0.045616623),
#  ('5a2c14b4bfd06b001a5ae9d5', 119, 120, 0.060565136),
#  ('5a2c14b4bfd06b001a5ae9d6', 51, 62, 0.05578697),
#  ('5a2c14b4bfd06b001a5ae9d7', 135, 136, 0.06871892),
#  ('57094ca7efce8f15003a7dd6', 27, 30, 0.0768195),
#  ('57094ca7efce8f15003a7dd7', 182, 183, 0.05884894),
#  ('57094ca7efce8f15003a7dd8', 106, 107, 0.06485983),
#  ('57094ca7efce8f15003a7dd9', 106, 107, 0.074250594),
#  ('57094ca7efce8f15003a7dda', 127, 130, 0.08421509),
#  ('5a2c16e3bfd06b001a5ae9e7', 27, 30, 0.08014171),
#  ('5a2c16e3bfd06b001a5ae9e8', 182, 183, 0.05132557),
#  ('5a2c16e3bfd06b001a5ae9e9', 107, 109, 0.09749165),
#  ('5a2c16e3bfd06b001a5ae9ea', 52, 54, 0.045170315),
#  ('5a2c16e3bfd06b001a5ae9eb', 143, 144, 0.072192356),
#  ('57094d489928a8140047150a', 23, 24, 0.04155512),
#  ('57094d489928a8140047150b', 25, 26, 0.06036351),
#  ('57094d489928a8140047150c', 31, 32, 0.070310295),
#  ('57094d489928a8140047150d', 77, 79, 0.032125905),
#  ...]

# %%
final_predictions = postprocess_predictions(validation_dataset, predictions)

# %%
final_predictions
# Out:
# [{'id': '56ddde6b9a695914005b9628',
#   'answer': 'France',
#   'no_answer_probability': 0.03785553},
#  {'id': '56ddde6b9a695914005b9629',
#   'answer': '10th and 11th centuries',
#   'no_answer_probability': 0.05775123},
#  {'id': '56ddde6b9a695914005b962a',
#   'answer': 'Denmark, Iceland and Norway',
#   'no_answer_probability': 0.066653505},
#  {'id': '56ddde6b9a695914005b962b',
#   'answer': 'Rollo',
#   'no_answer_probability': 0.057829574},
#  {'id': '56ddde6b9a695914005b962c',
#   'answer': '10th',
#   'no_answer_probability': 0.054816753},
#  {'id': '5ad39d53604f3c001a3fe8d1',
#   'answer': 'The Normans',
#   'no_answer_probability': 0.05132028},
#  {'id': '5ad39d53604f3c001a3fe8d2',
#   'answer': 'Normandy',
#   'no_answer_probability': 0.03750651},
#  {'id': '5ad39d53604f3c001a3fe8d3',
#   'answer': 'West Francia',
#   'no_answer_probability': 0.045478437},
#  {'id': '5ad39d53604f3c001a3fe8d4',
#   'answer': 'first half of the 10th century',
#   'no_answer_probability': 0.07493337},
#  {'id': '56dddf4066d3e219004dad5f',
#   'answer': 'William the Conqueror',
#   'no_answer_probability': 0.054222982},
#  {'id': '56dddf4066d3e219004dad60',
#   'answer': 'Richard I of Normandy',
#   'no_answer_probability': 0.17690685},
#  {'id': '56dddf4066d3e219004dad61',
#   'answer': 'Christian',
#   'no_answer_probability': 0.052062754},
#  {'id': '5ad3a266604f3c001a3fea27',
#   'answer': 'political, cultural and military',
#   'no_answer_probability': 0.05197306},
#  {'id': '5ad3a266604f3c001a3fea28',
#   'answer': 'The Normans',
#   'no_answer_probability': 0.042466108},
#  {'id': '5ad3a266604f3c001a3fea29',
#   'answer': 'The Normans',
#   'no_answer_probability': 0.046454336},
#  {'id': '5ad3a266604f3c001a3fea2a',
#   'answer': 'Richard I',
#   'no_answer_probability': 0.091768704},
#  {'id': '5ad3a266604f3c001a3fea2b',
#   'answer': 'Sicily',
#   'no_answer_probability': 0.036447797},
#  {'id': '56dde0379a695914005b9636',
#   'answer': 'Norseman, Viking',
#   'no_answer_probability': 0.032027263},
#  {'id': '56dde0379a695914005b9637',
#   'answer': '9th century',
#   'no_answer_probability': 0.22896332},
#  {'id': '5ad3ab70604f3c001a3feb89',
#   'answer': 'Normans',
#   'no_answer_probability': 0.022594722},
#  {'id': '5ad3ab70604f3c001a3feb8a',
#   'answer': 'Medieval Latin, 9th century',
#   'no_answer_probability': 0.0272691},
#  {'id': '56dde0ba66d3e219004dad75',
#   'answer': '911',
#   'no_answer_probability': 0.028649416},
#  {'id': '56dde0ba66d3e219004dad76',
#   'answer': 'King Charles III of West Francia',
#   'no_answer_probability': 0.031458206},
#  {'id': '56dde0ba66d3e219004dad77',
#   'answer': 'Epte',
#   'no_answer_probability': 0.05889513},
#  {'id': '5ad3ad61604f3c001a3fec0d',
#   'answer': '10th century',
#   'no_answer_probability': 0.057990372},
#  {'id': '5ad3ad61604f3c001a3fec0e',
#   'answer': 'Saint-Clair-sur-Epte',
#   'no_answer_probability': 0.024318224},
#  {'id': '5ad3ad61604f3c001a3fec0f',
#   'answer': 'Rollo',
#   'no_answer_probability': 0.030280786},
#  {'id': '5ad3ad61604f3c001a3fec10',
#   'answer': 'further Viking incursions',
#   'no_answer_probability': 0.17661229},
#  {'id': '56dde1d966d3e219004dad8d',
#   'answer': 'no foreign settlers',
#   'no_answer_probability': 0.035760015},
#  {'id': '5ad3ae14604f3c001a3fec39',
#   'answer': '880s',
#   'no_answer_probability': 0.022567028},
#  {'id': '5ad3ae14604f3c001a3fec3a',
#   'answer': 'Danes, Norwegians, Norse–Gaels, Orkney Vikings, possibly Swedes, and Anglo-Danes',
#   'no_answer_probability': 0.16558501},
#  {'id': '56dde27d9a695914005b9651',
#   'answer': 'Norse',
#   'no_answer_probability': 0.020581234},
#  {'id': '56dde27d9a695914005b9652',
#   'answer': 'north',
#   'no_answer_probability': 0.029695313},
#  {'id': '5ad3af11604f3c001a3fec63',
#   'answer': '',
#   'no_answer_probability': 0.04245843},
#  {'id': '5ad3af11604f3c001a3fec64',
#   'answer': 'customs',
#   'no_answer_probability': 0.04146727},
#  {'id': '5ad3af11604f3c001a3fec65',
#   'answer': 'Catholicism (Christianity) and the Gallo-Romance language of the local people, blending their maternal Frankish heritage with Old Norse traditions and customs to synthesize a unique "Norman',
#   'no_answer_probability': 0.025377193},
#  {'id': '56dde2fa66d3e219004dad9b',
#   'answer': 'fighting horsemen',
#   'no_answer_probability': 0.030645892},
#  {'id': '5ad3c626604f3c001a3ff011',
#   'answer': 'the rest of France',
#   'no_answer_probability': 0.033630352},
#  {'id': '5ad3c626604f3c001a3ff012',
#   'answer': 'fighting horsemen',
#   'no_answer_probability': 0.027751166},
#  {'id': '5ad3c626604f3c001a3ff013',
#   'answer': 'Bohemund I',
#   'no_answer_probability': 0.05281483},
#  {'id': '56de0f6a4396321400ee257f',
#   'answer': 'Pechenegs, the Bulgars, and especially the Seljuk Turks',
#   'no_answer_probability': 0.05430011},
#  {'id': '5ad3dbc6604f3c001a3ff3e9',
#   'answer': 'Normans',
#   'no_answer_probability': 0.038848195},
#  {'id': '5ad3dbc6604f3c001a3ff3ea',
#   'answer': 'the Pechenegs, the Bulgars, and especially the Seljuk Turks',
#   'no_answer_probability': 0.0604773},
#  {'id': '5ad3dbc6604f3c001a3ff3eb',
#   'answer': 'Norman mercenaries',
#   'no_answer_probability': 0.03384541},
#  {'id': '5ad3dbc6604f3c001a3ff3ec',
#   'answer': 'George Maniaces',
#   'no_answer_probability': 0.1076298},
#  {'id': '56de0ffd4396321400ee258d',
#   'answer': '1050s',
#   'no_answer_probability': 0.07677257},
#  {'id': '56de0ffd4396321400ee258e',
#   'answer': '1060s',
#   'no_answer_probability': 0.07947351},
#  {'id': '56de0ffd4396321400ee258f',
#   'answer': 'Alexius Komnenos',
#   'no_answer_probability': 0.2648127},
#  {'id': '5ad3de8b604f3c001a3ff467',
#   'answer': 'Hervé',
#   'no_answer_probability': 0.0010245566},
#  {'id': '5ad3de8b604f3c001a3ff468',
#   'answer': '1050s',
#   'no_answer_probability': 0.0014966525},
#  {'id': '5ad3de8b604f3c001a3ff469',
#   'answer': 'Roussel de Bailleul',
#   'no_answer_probability': 0.0010655744},
#  {'id': '5ad3de8b604f3c001a3ff46a',
#   'answer': '1060s',
#   'no_answer_probability': 0.0013734172},
#  {'id': '56de10b44396321400ee2593',
#   'answer': 'Afranji',
#   'no_answer_probability': 0.0015920695},
#  {'id': '56de10b44396321400ee2594',
#   'answer': 'Oursel',
#   'no_answer_probability': 0.0011217333},
#  {'id': '56de10b44396321400ee2595',
#   'answer': 'Turkish forces',
#   'no_answer_probability': 0.0011486511},
#  {'id': '5ad3e96b604f3c001a3ff689',
#   'answer': 'Some Normans',
#   'no_answer_probability': 0.00088357675},
#  {'id': '5ad3e96b604f3c001a3ff68a',
#   'answer': 'Armenian state',
#   'no_answer_probability': 0.0011158241},
#  {'id': '5ad3e96b604f3c001a3ff68b',
#   'answer': 'Oursel',
#   'no_answer_probability': 0.0009816049},
#  {'id': '5ad3e96b604f3c001a3ff68c',
#   'answer': 'into the upper Euphrates valley in northern Syria',
#   'no_answer_probability': 0.0022320312},
#  {'id': '56de11154396321400ee25aa',
#   'answer': 'Norman mercenary origin during the period of the Comnenian Restoration, when Byzantine emperors were seeking out western European warriors. The Raoulii were descended from an Italo-Norman named Raoul',
#   'no_answer_probability': 0.0008802176},
#  {'id': '5ad3ea79604f3c001a3ff6e9',
#   'answer': 'Byzantine Greece',
#   'no_answer_probability': 0.0015399854},
#  {'id': '5ad3ea79604f3c001a3ff6ea',
#   'answer': 'George Maniaces',
#   'no_answer_probability': 0.0028748473},
#  {'id': '5ad3ea79604f3c001a3ff6eb',
#   'answer': 'Sicilian',
#   'no_answer_probability': 0.0011200295},
#  {'id': '56de148dcffd8e1900b4b5bc',
#   'answer': '',
#   'no_answer_probability': 0.0991749},
#  {'id': '56de148dcffd8e1900b4b5bd',
#   'answer': 'February 1082',
#   'no_answer_probability': 0.052481074},
#  {'id': '56de148dcffd8e1900b4b5be',
#   'answer': '30,000',
#   'no_answer_probability': 0.015719958},
#  {'id': '5ad3ed26604f3c001a3ff799',
#   'answer': 'Robert Guiscard',
#   'no_answer_probability': 0.05197951},
#  {'id': '5ad3ed26604f3c001a3ff79a',
#   'answer': 'Gregory VII',
#   'no_answer_probability': 0.0023376846},
#  {'id': '5ad3ed26604f3c001a3ff79b',
#   'answer': 'Dyrrachium',
#   'no_answer_probability': 0.06923606},
#  {'id': '5ad3ed26604f3c001a3ff79c',
#   'answer': '30,000',
#   'no_answer_probability': 0.06525014},
#  {'id': '56de15104396321400ee25b7',
#   'answer': 'Deabolis',
#   'no_answer_probability': 0.00014863748},
#  {'id': '56de15104396321400ee25b8',
#   'answer': 'Bohemond',
#   'no_answer_probability': 8.314743e-05},
#  {'id': '56de15104396321400ee25b9',
#   'answer': 'Deabolis',
#   'no_answer_probability': 0.00013493974},
#  {'id': '5ad3ee2d604f3c001a3ff7e1',
#   'answer': 'Dyrrachium',
#   'no_answer_probability': 0.05289826},
#  {'id': '5ad3ee2d604f3c001a3ff7e2',
#   'answer': '',
#   'no_answer_probability': 0.049137376},
#  {'id': '5ad3ee2d604f3c001a3ff7e3',
#   'answer': 'Robert',
#   'no_answer_probability': 0.05933524},
#  {'id': '56de1563cffd8e1900b4b5c2',
#   'answer': '1185',
#   'no_answer_probability': 0.053129718},
#  {'id': '56de1563cffd8e1900b4b5c3',
#   'answer': 'Dyrrachium',
#   'no_answer_probability': 0.039474484},
#  {'id': '56de1563cffd8e1900b4b5c4',
#   'answer': 'Adriatic',
#   'no_answer_probability': 0.059179522},
#  {'id': '5ad3f028604f3c001a3ff823',
#   'answer': 'Norman army',
#   'no_answer_probability': 0.034751363},
#  {'id': '5ad3f028604f3c001a3ff824',
#   'answer': 'high Byzantine officials',
#   'no_answer_probability': 0.10409419},
#  {'id': '5ad3f028604f3c001a3ff825',
#   'answer': 'Dyrrachium',
#   'no_answer_probability': 0.038994245},
#  {'id': '56de15dbcffd8e1900b4b5c8',
#   'answer': 'Duke Richard II of Normandy, and King Ethelred II of England',
#   'no_answer_probability': 0.07006705},
#  {'id': '56de15dbcffd8e1900b4b5c9',
#   'answer': 'Duke Richard II of Normandy',
#   'no_answer_probability': 0.10021544},
#  {'id': '56de15dbcffd8e1900b4b5ca',
#   'answer': 'Normandy',
#   'no_answer_probability': 0.0527777},
#  {'id': '56de15dbcffd8e1900b4b5cb',
#   'answer': 'Sweyn Forkbeard',
#   'no_answer_probability': 0.10929747},
#  {'id': '5ad3f187604f3c001a3ff86f',
#   'answer': 'Emma',
#   'no_answer_probability': 0.06310128},
#  {'id': '5ad3f187604f3c001a3ff870',
#   'answer': '1013',
#   'no_answer_probability': 0.059858978},
#  {'id': '5ad3f187604f3c001a3ff871',
#   'answer': 'The Normans',
#   'no_answer_probability': 0.0536877},
#  {'id': '56de1645cffd8e1900b4b5d0',
#   'answer': 'Harthacnut',
#   'no_answer_probability': 0.09452399},
#  {'id': '56de1645cffd8e1900b4b5d1',
#   'answer': '1041',
#   'no_answer_probability': 0.06460078},
#  {'id': '56de1645cffd8e1900b4b5d2',
#   'answer': 'Robert of Jumièges',
#   'no_answer_probability': 0.057799596},
#  {'id': '5ad3f350604f3c001a3ff8ef',
#   'answer': '1041',
#   'no_answer_probability': 0.0531239},
#  {'id': '5ad3f350604f3c001a3ff8f0',
#   'answer': 'English cavalry force',
#   'no_answer_probability': 0.043397866},
#  {'id': '5ad3f350604f3c001a3ff8f1',
#   'answer': 'Edward the Confessor',
#   'no_answer_probability': 0.043678988},
#  {'id': '56de16ca4396321400ee25c5',
#   'answer': 'Battle of Hastings',
#   'no_answer_probability': 0.074039035},
#  {'id': '56de16ca4396321400ee25c6',
#   'answer': 'Duke William II of Normandy',
#   'no_answer_probability': 0.06451634},
#  {'id': '56de16ca4396321400ee25c7',
#   'answer': '1066',
#   'no_answer_probability': 0.05004223},
#  {'id': '56de16ca4396321400ee25c8',
#   'answer': 'Anglo-Saxons',
#   'no_answer_probability': 0.104918934},
#  {'id': '5ad3f4b1604f3c001a3ff951',
#   'answer': '1066',
#   'no_answer_probability': 0.05321624},
#  {'id': '5ad3f4b1604f3c001a3ff952',
#   'answer': 'Battle of Hastings',
#   'no_answer_probability': 0.055458777},
#  {'id': '5ad3f4b1604f3c001a3ff953',
#   'answer': 'Anglo-Saxons',
#   'no_answer_probability': 0.054779716},
#  {'id': '5ad3f4b1604f3c001a3ff954',
#   'answer': 'Early Norman kings of England',
#   'no_answer_probability': 0.046979357},
#  {'id': '56de1728cffd8e1900b4b5d7',
#   'answer': 'Modern English',
#   'no_answer_probability': 0.08766184},
#  {'id': '5ad3f5b0604f3c001a3ff9ab',
#   'answer': 'Norman aristocracy',
#   'no_answer_probability': 0.051262427},
#  {'id': '5ad3f5b0604f3c001a3ff9ac',
#   'answer': 'Anglo-Saxon language of their subjects',
#   'no_answer_probability': 0.052979916},
#  {'id': '5ad3f5b0604f3c001a3ff9ad',
#   'answer': 'Geoffrey Chaucer',
#   'no_answer_probability': 0.124188624},
#  {'id': '56de179dcffd8e1900b4b5da',
#   'answer': '1169',
#   'no_answer_probability': 0.07206983},
#  {'id': '56de179dcffd8e1900b4b5db',
#   'answer': 'Irish',
#   'no_answer_probability': 0.06823737},
#  {'id': '56de179dcffd8e1900b4b5dc',
#   'answer': 'Irish',
#   'no_answer_probability': 0.07236163},
#  {'id': '5ad3f6f5604f3c001a3ffa09',
#   'answer': 'Bannow Bay',
#   'no_answer_probability': 0.08954483},
#  {'id': '5ad3f6f5604f3c001a3ffa0a',
#   'answer': 'The Normans',
#   'no_answer_probability': 0.085214674},
#  {'id': '5ad3f6f5604f3c001a3ffa0b',
#   'answer': 'Trim Castle and Dublin Castle',
#   'no_answer_probability': 0.090751514},
#  {'id': '56de17f9cffd8e1900b4b5e0',
#   'answer': '',
#   'no_answer_probability': 0.043241713},
#  {'id': '56de17f9cffd8e1900b4b5e1',
#   'answer': 'King Malcolm III of Scotland',
#   'no_answer_probability': 0.044751223},
#  {'id': '56de17f9cffd8e1900b4b5e2',
#   'answer': '1072',
#   'no_answer_probability': 0.05970743},
#  {'id': '56de17f9cffd8e1900b4b5e3',
#   'answer': 'his son Duncan',
#   'no_answer_probability': 0.039956134},
#  {'id': '5ad3f7ac604f3c001a3ffa3b',
#   'answer': 'Margaret',
#   'no_answer_probability': 0.037277576},
#  {'id': '5ad3f7ac604f3c001a3ffa3c',
#   'answer': 'William',
#   'no_answer_probability': 0.038201604},
#  {'id': '5ad3f7ac604f3c001a3ffa3d',
#   'answer': 'Duncan',
#   'no_answer_probability': 0.038326096},
#  {'id': '56de3cd0cffd8e1900b4b6be',
#   'answer': 'Sybilla of Normandy',
#   'no_answer_probability': 0.043189824},
#  {'id': '56de3cd0cffd8e1900b4b6bf',
#   'answer': 'Norman',
#   'no_answer_probability': 0.046406236},
#  {'id': '5ad3f8d2604f3c001a3ffa8d',
#   'answer': 'Sybilla of Normandy',
#   'no_answer_probability': 0.053285953},
#  {'id': '5ad3f8d2604f3c001a3ffa8e',
#   'answer': 'Normans and Norman culture',
#   'no_answer_probability': 0.038714577},
#  {'id': '56de3d594396321400ee26ca',
#   'answer': 'Hereford',
#   'no_answer_probability': 0.065775715},
#  {'id': '56de3d594396321400ee26cb',
#   'answer': 'the Welsh',
#   'no_answer_probability': 0.06953743},
#  {'id': '56de3d594396321400ee26cc',
#   'answer': 'Edward the Confessor',
#   'no_answer_probability': 0.07962111},
#  {'id': '5ad3fb01604f3c001a3ffb35',
#   'answer': 'the Normans',
#   'no_answer_probability': 0.059758537},
#  {'id': '5ad3fb01604f3c001a3ffb36',
#   'answer': 'Ralph',
#   'no_answer_probability': 0.04074189},
#  {'id': '56de3dbacffd8e1900b4b6d2',
#   'answer': 'the Marches',
#   'no_answer_probability': 0.040969513},
#  {'id': '5ad3fb6e604f3c001a3ffb5f',
#   'answer': 'the Marches',
#   'no_answer_probability': 0.07202823},
#  {'id': '5ad3fb6e604f3c001a3ffb60',
#   'answer': 'Bernard de Neufmarché, Roger of Montgomery in Shropshire and Hugh Lupus in Cheshire',
#   'no_answer_probability': 0.04869365},
#  {'id': '56de3e414396321400ee26d8',
#   'answer': '1018',
#   'no_answer_probability': 0.059816293},
#  {'id': '56de3e414396321400ee26d9',
#   'answer': 'William of Montreuil',
#   'no_answer_probability': 0.10561129},
#  {'id': '5ad3fc41604f3c001a3ffb8f',
#   'answer': 'Antioch',
#   'no_answer_probability': 0.08661459},
#  {'id': '5ad3fc41604f3c001a3ffb90',
#   'answer': 'religious wars',
#   'no_answer_probability': 0.0557273},
#  {'id': '5ad3fc41604f3c001a3ffb91',
#   'answer': 'Roger de Tosny',
#   'no_answer_probability': 0.076697744},
#  {'id': '5ad3fc41604f3c001a3ffb92',
#   'answer': 'War of Barbastro',
#   'no_answer_probability': 0.031277362},
#  {'id': '56de3ebc4396321400ee26e6',
#   'answer': '1097',
#   'no_answer_probability': 0.040907405},
#  {'id': '56de3ebc4396321400ee26e7',
#   'answer': 'Tancred',
#   'no_answer_probability': 0.0536082},
#  {'id': '56de3ebc4396321400ee26e8',
#   'answer': 'Jerusalem',
#   'no_answer_probability': 0.03707608},
#  {'id': '5ad4017a604f3c001a3ffd1f',
#   'answer': '1097',
#   'no_answer_probability': 0.029261634},
#  {'id': '5ad4017a604f3c001a3ffd20',
#   'answer': 'Bohemond of Taranto',
#   'no_answer_probability': 0.026732327},
#  {'id': '56de3efccffd8e1900b4b6fe',
#   'answer': '380 years',
#   'no_answer_probability': 0.3399375},
#  {'id': '5ad401f2604f3c001a3ffd41',
#   'answer': 'Western European',
#   'no_answer_probability': 0.021462625},
#  {'id': '5ad401f2604f3c001a3ffd42',
#   'answer': 'Anglo-Norman forces',
#   'no_answer_probability': 0.026753332},
#  {'id': '56de3f784396321400ee26fa',
#   'answer': 'a storm',
#   'no_answer_probability': 0.054534104},
#  {'id': '56de3f784396321400ee26fb',
#   'answer': 'Berengaria',
#   'no_answer_probability': 0.07602724},
#  {'id': '56de3f784396321400ee26fc',
#   'answer': '1191',
#   'no_answer_probability': 0.04680812},
#  {'id': '56de3f784396321400ee26fd',
#   'answer': 'Isaac Komnenos',
#   'no_answer_probability': 0.059504796},
#  {'id': '5ad40280604f3c001a3ffd57',
#   'answer': 'Richard the Lion-hearted',
#   'no_answer_probability': 0.053108905},
#  {'id': '5ad40280604f3c001a3ffd58',
#   'answer': '1191',
#   'no_answer_probability': 0.048265327},
#  {'id': '5ad40280604f3c001a3ffd59',
#   'answer': 'Isaac Komnenos',
#   'no_answer_probability': 0.05473499},
#  {'id': '56de40da4396321400ee2708',
#   'answer': 'Conrad of Montferrat',
#   'no_answer_probability': 0.13685052},
#  {'id': '56de40da4396321400ee2709',
#   'answer': 'silver',
#   'no_answer_probability': 0.066236995},
#  {'id': '56de40da4396321400ee270a',
#   'answer': 'Guy de Lusignan',
#   'no_answer_probability': 0.06487455},
#  {'id': '5ad404a6604f3c001a3ffde1',
#   'answer': 'Isaac',
#   'no_answer_probability': 0.062387362},
#  {'id': '5ad404a6604f3c001a3ffde2',
#   'answer': 'Guy de Lusignan',
#   'no_answer_probability': 0.069907814},
#  {'id': '5ad404a6604f3c001a3ffde3',
#   'answer': 'Richard',
#   'no_answer_probability': 0.07496839},
#  {'id': '56de49564396321400ee277a',
#   'answer': 'Africa',
#   'no_answer_probability': 0.023163838},
#  {'id': '5ad40419604f3c001a3ffdb7',
#   'answer': 'Jean de Bethencourt and the Poitevine Gadifer de la Salle',
#   'no_answer_probability': 0.039821792},
#  {'id': '5ad40419604f3c001a3ffdb8',
#   'answer': 'Lanzarote, Fuerteventura and El Hierro',
#   'no_answer_probability': 0.03348731},
#  {'id': '56de49a8cffd8e1900b4b7a7',
#   'answer': 'Bethencourt',
#   'no_answer_probability': 0.054207366},
#  {'id': '56de49a8cffd8e1900b4b7a8',
#   'answer': '',
#   'no_answer_probability': 0.07159137},
#  {'id': '56de49a8cffd8e1900b4b7a9',
#   'answer': '',
#   'no_answer_probability': 0.061586097},
#  {'id': '5ad403c1604f3c001a3ffd97',
#   'answer': 'King of the Canary Islands',
#   'no_answer_probability': 0.017378828},
#  {'id': '5ad403c1604f3c001a3ffd98',
#   'answer': 'Maciot de Bethencourt',
#   'no_answer_probability': 0.056742724},
#  {'id': '56de4a474396321400ee2786',
#   'answer': 'the Channel Islands',
#   'no_answer_probability': 0.15078072},
#  {'id': '56de4a474396321400ee2787',
#   'answer': 'two',
#   'no_answer_probability': 0.016014388},
#  {'id': '5ad40358604f3c001a3ffd7d',
#   'answer': 'Très ancien coutumier',
#   'no_answer_probability': 0.0152173685},
#  {'id': '5ad40358604f3c001a3ffd7e',
#   'answer': 'Grand coutumier de Normandie',
#   'no_answer_probability': 0.022945637},
#  {'id': '5ad40358604f3c001a3ffd7f',
#   'answer': 'Grand coutumier de Normandie',
#   'no_answer_probability': 0.011200768},
#  {'id': '56de4a89cffd8e1900b4b7bd',
#   'answer': 'Romanesque',
#   'no_answer_probability': 0.012560078},
#  {'id': '56de4a89cffd8e1900b4b7be',
#   'answer': 'rounded',
#   'no_answer_probability': 0.01828742},
#  {'id': '5ad402ce604f3c001a3ffd67',
#   'answer': 'rounded',
#   'no_answer_probability': 0.015691902},
#  {'id': '56de4b074396321400ee2793',
#   'answer': 'Early Gothic',
#   'no_answer_probability': 0.26773077},
#  {'id': '56de4b074396321400ee2794',
#   'answer': 'Early Gothic',
#   'no_answer_probability': 0.39155006},
#  {'id': '56de4b074396321400ee2795',
#   'answer': 'Kingdom of Sicily',
#   'no_answer_probability': 0.0500543},
#  {'id': '5ad400b0604f3c001a3ffcdf',
#   'answer': 'Early Gothic',
#   'no_answer_probability': 0.047461335},
#  {'id': '5ad400b0604f3c001a3ffce0',
#   'answer': 'Norman',
#   'no_answer_probability': 0.015184186},
#  {'id': '5ad400b0604f3c001a3ffce1',
#   'answer': 'the Normans',
#   'no_answer_probability': 0.01545218},
#  {'id': '56de4b5c4396321400ee2799',
#   'answer': 'early 11th century',
#   'no_answer_probability': 0.030956985},
#  {'id': '56de4b5c4396321400ee279a',
#   'answer': 'the dukes',
#   'no_answer_probability': 0.030959731},
#  {'id': '5ad3ffd7604f3c001a3ffca7',
#   'answer': 'visual',
#   'no_answer_probability': 0.022838902},
#  {'id': '5ad3ffd7604f3c001a3ffca8',
#   'answer': 'the dukes',
#   'no_answer_probability': 0.03190834},
#  {'id': '5ad3ffd7604f3c001a3ffca9',
#   'answer': 'duchy',
#   'no_answer_probability': 0.06627101},
#  {'id': '5ad3ffd7604f3c001a3ffcaa',
#   'answer': 'Normandy',
#   'no_answer_probability': 0.11875478},
#  {'id': '56de4bb84396321400ee27a2',
#   'answer': '16th century',
#   'no_answer_probability': 0.06996173},
#  {'id': '5ad3ff1b604f3c001a3ffc73',
#   'answer': 'French Wars of Religion',
#   'no_answer_probability': 0.05468464},
#  {'id': '5ad3ff1b604f3c001a3ffc74',
#   'answer': 'French Revolution',
#   'no_answer_probability': 0.029724874},
#  {'id': '56de4c324396321400ee27ab',
#   'answer': 'embroidery',
#   'no_answer_probability': 0.06563962},
#  {'id': '56de4c324396321400ee27ac',
#   'answer': 'Bayeux Tapestry',
#   'no_answer_probability': 0.098590694},
#  {'id': '56de4c324396321400ee27ad',
#   'answer': 'Odo',
#   'no_answer_probability': 0.04080686},
#  {'id': '5ad3fe91604f3c001a3ffc47',
#   'answer': 'Bayeux Tapestry',
#   'no_answer_probability': 0.03592589},
#  {'id': '5ad3fe91604f3c001a3ffc48',
#   'answer': 'Odo',
#   'no_answer_probability': 0.032437682},
#  {'id': '56de51244396321400ee27ef',
#   'answer': 'mosaics',
#   'no_answer_probability': 0.052575637},
#  {'id': '5ad3fe0d604f3c001a3ffc1b',
#   'answer': 'stonework or metalwork',
#   'no_answer_probability': 0.11116008},
#  {'id': '5ad3fe0d604f3c001a3ffc1c',
#   'answer': 'mosaics',
#   'no_answer_probability': 0.05085428},
#  {'id': '5ad3fe0d604f3c001a3ffc1d',
#   'answer': 'Lombard Salerno',
#   'no_answer_probability': 0.056160502},
#  {'id': '56de51c64396321400ee27f7',
#   'answer': '11th',
#   'no_answer_probability': 0.045872245},
#  {'id': '56de51c64396321400ee27f8',
#   'answer': 'William of Volpiano and John of Ravenna',
#   'no_answer_probability': 0.07057948},
#  {'id': '5ad3fd68604f3c001a3ffbe7',
#   'answer': 'classical music',
#   'no_answer_probability': 0.045733545},
#  {'id': '5ad3fd68604f3c001a3ffbe8',
#   'answer': 'musical production and education',
#   'no_answer_probability': 0.07362916},
#  {'id': '56de52614396321400ee27fb',
#   'answer': 'southern Italy',
#   'no_answer_probability': 0.04248215},
#  {'id': '56de52614396321400ee27fc',
#   'answer': "Sant'Eufemia",
#   'no_answer_probability': 0.067290895},
#  {'id': '56de52614396321400ee27fd',
#   'answer': 'Robert Guiscard',
#   'no_answer_probability': 0.068992436},
#  {'id': '56de52614396321400ee27fe',
#   'answer': 'singing',
#   'no_answer_probability': 0.02992532},
#  {'id': '5ad3fccf604f3c001a3ffbb5',
#   'answer': 'several monks of Saint-Evroul',
#   'no_answer_probability': 0.031659417},
#  {'id': '56e16182e3433e1400422e28',
#   'answer': 'Computational complexity theory',
#   'no_answer_probability': 0.022447748},
#  {'id': '56e16182e3433e1400422e29',
#   'answer': 'their inherent difficulty',
#   'no_answer_probability': 0.37442175},
#  {'id': '56e16182e3433e1400422e2a',
#   'answer': 'A computational problem',
#   'no_answer_probability': 0.022711726},
#  {'id': '5ad5316b5b96ef001a10ab72',
#   'answer': 'a branch of the theory of computation in theoretical computer science that focuses on classifying computational problems according to their inherent difficulty, and relating those classes to each other. A computational problem is understood to be a task that is in principle amenable to being solved by a computer',
#   'no_answer_probability': 0.07852096},
#  {'id': '5ad5316b5b96ef001a10ab73',
#   'answer': 'Computational complexity theory',
#   'no_answer_probability': 0.02309624},
#  {'id': '5ad5316b5b96ef001a10ab74',
#   'answer': 'A computational problem',
#   'no_answer_probability': 0.018726144},
#  {'id': '5ad5316b5b96ef001a10ab75',
#   'answer': 'A computational problem',
#   'no_answer_probability': 0.021574205},
#  {'id': '5ad5316b5b96ef001a10ab76',
#   'answer': 'an algorithm',
#   'no_answer_probability': 0.052118815},
#  {'id': '56e16839cd28a01900c67887',
#   'answer': 'significant resources',
#   'no_answer_probability': 0.026669465},
#  {'id': '56e16839cd28a01900c67888',
#   'answer': '',
#   'no_answer_probability': 0.019915113},
#  {'id': '56e16839cd28a01900c67889',
#   'answer': 'time and storage',
#   'no_answer_probability': 0.12738612},
#  {'id': '56e16839cd28a01900c6788a',
#   'answer': 'number of gates',
#   'no_answer_probability': 0.036696177},
#  {'id': '56e16839cd28a01900c6788b',
#   'answer': 'to determine the practical limits on what computers can and cannot do',
#   'no_answer_probability': 0.031052947},
#  {'id': '5ad532575b96ef001a10ab7c',
#   'answer': 'significant resources',
#   'no_answer_probability': 0.021607304},
#  {'id': '5ad532575b96ef001a10ab7d',
#   'answer': '',
#   'no_answer_probability': 0.024605066},
#  {'id': '5ad532575b96ef001a10ab7e',
#   'answer': 'time and storage',
#   'no_answer_probability': 0.124134995},
#  {'id': '5ad532575b96ef001a10ab7f',
#   'answer': 'number of gates',
#   'no_answer_probability': 0.035832472},
#  {'id': '5ad532575b96ef001a10ab80',
#   'answer': 'processors',
#   'no_answer_probability': 0.08719873},
#  {'id': '56e17644e3433e1400422f40',
#   'answer': 'analysis of algorithms and computability theory',
#   'no_answer_probability': 0.10709737},
#  {'id': '56e17644e3433e1400422f41',
#   'answer': 'computational complexity theory',
#   'no_answer_probability': 0.021205554},
#  {'id': '56e17644e3433e1400422f42',
#   'answer': 'computational complexity theory',
#   'no_answer_probability': 0.019898236},
#  {'id': '56e17644e3433e1400422f43',
#   'answer': 'theoretical',
#   'no_answer_probability': 0.021983413},
#  {'id': '5ad5344b5b96ef001a10ab86',
#   'answer': 'analysis of algorithms and computability theory',
#   'no_answer_probability': 0.07441344},
#  {'id': '5ad5344b5b96ef001a10ab87',
#   'answer': 'the former is devoted to analyzing the amount of resources needed by a particular algorithm to solve a problem',
#   'no_answer_probability': 0.22429544},
#  {'id': '5ad5344b5b96ef001a10ab88',
#   'answer': 'analysis of algorithms and computational complexity theory',
#   'no_answer_probability': 0.022677682},
#  {'id': '5ad5344b5b96ef001a10ab89',
#   'answer': 'it tries to classify problems that can or cannot be solved with appropriately restricted resources',
#   'no_answer_probability': 0.046522878},
#  {'id': '5ad5344b5b96ef001a10ab8a',
#   'answer': '',
#   'no_answer_probability': 0.043596983},
#  {'id': '56e17a7ccd28a01900c679a1',
#   'answer': 'a problem instance',
#   'no_answer_probability': 0.066315934},
#  {'id': '56e17a7ccd28a01900c679a2',
#   'answer': 'a problem',
#   'no_answer_probability': 0.052500784},
#  {'id': '56e17a7ccd28a01900c679a3',
#   'answer': 'concrete',
#   'no_answer_probability': 0.0906663},
#  {'id': '56e17a7ccd28a01900c679a4',
#   'answer': 'problem instance',
#   'no_answer_probability': 0.05758876},
#  {'id': '56e17a7ccd28a01900c679a5',
#   'answer': 'the solution',
#   'no_answer_probability': 0.060826983},
#  {'id': '5ad5364c5b96ef001a10ab90',
#   'answer': 'A computational problem',
#   'no_answer_probability': 0.057039604},
#  {'id': '5ad5364c5b96ef001a10ab91',
#   'answer': 'a problem instance',
#   'no_answer_probability': 0.06900342},
#  {'id': '5ad5364c5b96ef001a10ab92',
#   'answer': 'a problem',
#   'no_answer_probability': 0.05205438},
#  {'id': '5ad5364c5b96ef001a10ab93',
#   'answer': 'solution',
#   'no_answer_probability': 0.059696864},
#  {'id': '5ad5364c5b96ef001a10ab94',
#   'answer': 'the instance',
#   'no_answer_probability': 0.06869639},
#  {'id': '56e17e6ee3433e1400422f7f',
#   'answer': '2000',
#   'no_answer_probability': 0.037286673},
#  {'id': '56e17e6ee3433e1400422f80',
#   'answer': 'asking for a round trip through all sites in Milan',
#   'no_answer_probability': 0.14774115},
#  {'id': '56e17e6ee3433e1400422f81',
#   'answer': 'computational problems',
#   'no_answer_probability': 0.052599516},
#  {'id': '5ad537a15b96ef001a10ab9a',
#   'answer': '2000 kilometres',
#   'no_answer_probability': 0.03786334},
#  {'id': '5ad537a15b96ef001a10ab9b',
#   'answer': '',
#   'no_answer_probability': 0.015691476},
#  {'id': '5ad537a15b96ef001a10ab9c',
#   'answer': 'asking for a round trip through all sites in Milan',
#   'no_answer_probability': 0.042198088},
#  {'id': '5ad537a15b96ef001a10ab9d',
#   'answer': 'computational problems',
#   'no_answer_probability': 0.012034278},
#  {'id': '56e181d9e3433e1400422fa0',
#   'answer': 'a problem instance',
#   'no_answer_probability': 0.008403276},
#  {'id': '56e181d9e3433e1400422fa1',
#   'answer': 'binary alphabet',
#   'no_answer_probability': 0.014753933},
#  {'id': '56e181d9e3433e1400422fa2',
#   'answer': '',
#   'no_answer_probability': 0.0096316375},
#  {'id': '56e181d9e3433e1400422fa3',
#   'answer': 'binary notation',
#   'no_answer_probability': 0.015541675},
#  {'id': '56e181d9e3433e1400422fa4',
#   'answer': '',
#   'no_answer_probability': 0.56493247},
#  {'id': '5ad5391e5b96ef001a10aba2',
#   'answer': 'a problem instance is a string over an alphabet',
#   'no_answer_probability': 0.007797279},
#  {'id': '5ad5391e5b96ef001a10aba3',
#   'answer': 'binary alphabet',
#   'no_answer_probability': 0.011097943},
#  {'id': '5ad5391e5b96ef001a10aba4',
#   'answer': 'bitstrings',
#   'no_answer_probability': 0.009242325},
#  {'id': '5ad5391e5b96ef001a10aba5',
#   'answer': 'integers',
#   'no_answer_probability': 0.0104560405},
#  {'id': '5ad5391e5b96ef001a10aba6',
#   'answer': 'via their adjacency matrices',
#   'no_answer_probability': 0.12493484},
#  {'id': '56e190bce3433e1400422fc8',
#   'answer': 'Decision problems',
#   'no_answer_probability': 0.009834323},
#  {'id': '56e190bce3433e1400422fc9',
#   'answer': '1 or 0',
#   'no_answer_probability': 0.06898257},
#  {'id': '56e190bce3433e1400422fca',
#   'answer': '1 or 0',
#   'no_answer_probability': 0.074467786},
#  {'id': '56e190bce3433e1400422fcb',
#   'answer': 'yes',
#   'no_answer_probability': 0.012605151},
#  {'id': '56e190bce3433e1400422fcc',
#   'answer': 'yes',
#   'no_answer_probability': 0.011095496},
#  {'id': '5ad53b9d5b96ef001a10abc8',
#   'answer': 'Decision problems',
#   'no_answer_probability': 0.009119386},
#  {'id': '5ad53b9d5b96ef001a10abc9',
#   'answer': 'A decision problem',
#   'no_answer_probability': 0.009369441},
#  {'id': '5ad53b9d5b96ef001a10abca',
#   'answer': 'A decision problem',
#   'no_answer_probability': 0.010185839},
#  {'id': '5ad53b9d5b96ef001a10abcb',
#   'answer': '1 or 0',
#   'no_answer_probability': 0.024757056},
#  {'id': '5ad53b9d5b96ef001a10abcc',
#   'answer': 'yes',
#   'no_answer_probability': 0.010611544},
#  {'id': '56e19557e3433e1400422fee',
#   'answer': 'arbitrary',
#   'no_answer_probability': 0.009916521},
#  {'id': '56e19557e3433e1400422ff0',
#   'answer': 'The formal language',
#   'no_answer_probability': 0.008878943},
#  {'id': '56e19557e3433e1400422ff1',
#   'answer': 'how graphs are encoded as binary strings',
#   'no_answer_probability': 0.25824532},
#  {'id': '5ad53d705b96ef001a10abd2',
#   'answer': 'arbitrary',
#   'no_answer_probability': 0.009491872},
#  {'id': '5ad53d705b96ef001a10abd3',
#   'answer': 'The formal language',
#   'no_answer_probability': 0.008786989},
#  {'id': '5ad53d705b96ef001a10abd4',
#   'answer': 'graphs are encoded as binary strings',
#   'no_answer_probability': 0.06423889},
#  {'id': '5ad53d705b96ef001a10abd5',
#   'answer': '',
#   'no_answer_probability': 0.53471124},
#  {'id': '56e19724cd28a01900c679f6',
#   'answer': 'computational problem',
#   'no_answer_probability': 0.009944515},
#  {'id': '56e19724cd28a01900c679f7',
#   'answer': 'a single',
#   'no_answer_probability': 0.008041884},
#  {'id': '56e19724cd28a01900c679f8',
#   'answer': 'A function problem',
#   'no_answer_probability': 0.010956785},
#  {'id': '56e19724cd28a01900c679f9',
#   'answer': 'integer factorization problem',
#   'no_answer_probability': 0.29755962},
#  {'id': '56e19724cd28a01900c679fa',
#   'answer': 'complex',
#   'no_answer_probability': 0.027007414},
#  {'id': '5ad53e615b96ef001a10abda',
#   'answer': 'A function problem',
#   'no_answer_probability': 0.010210208},
#  {'id': '5ad53e615b96ef001a10abdb',
#   'answer': 'a single output (of a total function',
#   'no_answer_probability': 0.008873926},
#  {'id': '5ad53e615b96ef001a10abdc',
#   'answer': 'the traveling salesman problem and the integer factorization problem',
#   'no_answer_probability': 0.017337723},
#  {'id': '5ad53e615b96ef001a10abdd',
#   'answer': 'the traveling salesman problem and the integer factorization problem',
#   'no_answer_probability': 0.30679175},
#  {'id': '5ad53e615b96ef001a10abde',
#   'answer': 'complex',
#   'no_answer_probability': 0.026521388},
#  {'id': '56e1a0dccd28a01900c67a2e',
#   'answer': 'as decision problems',
#   'no_answer_probability': 0.04870725},
#  {'id': '56e1a0dccd28a01900c67a2f',
#   'answer': 'triples',
#   'no_answer_probability': 0.018940737},
#  {'id': '5ad53f815b96ef001a10abe4',
#   'answer': 'function problems',
#   'no_answer_probability': 0.021059679},
#  {'id': '5ad53f815b96ef001a10abe5',
#   'answer': 'the set of triples',
#   'no_answer_probability': 0.01488485},
#  {'id': '5ad53f815b96ef001a10abe6',
#   'answer': 'Deciding whether a given triple is a member of this set',
#   'no_answer_probability': 0.036629666},
#  {'id': '56e1a38de3433e140042305c',
#   'answer': 'the size of the input in bits',
#   'no_answer_probability': 0.024169784},
#  {'id': '56e1a38de3433e140042305d',
#   'answer': 'the instance',
#   'no_answer_probability': 0.017236777},
#  {'id': '56e1a38de3433e140042305e',
#   'answer': 'as a function of the size of the instance',
#   'no_answer_probability': 0.11311244},
#  {'id': '56e1a38de3433e140042305f',
#   'answer': 'bits',
#   'no_answer_probability': 0.055881795},
#  {'id': '56e1a38de3433e1400423060',
#   'answer': 'input size',
#   'no_answer_probability': 0.042465966},
#  {'id': '5ad541ad5b96ef001a10abea',
#   'answer': 'one may wish to see how much time the best algorithm requires to solve the problem',
#   'no_answer_probability': 0.06981688},
#  {'id': '5ad541ad5b96ef001a10abeb',
#   'answer': 'the instance',
#   'no_answer_probability': 0.0469289},
#  {'id': '5ad541ad5b96ef001a10abec',
#   'answer': 'as a function of the size of the instance',
#   'no_answer_probability': 0.2050125},
#  {'id': '5ad541ad5b96ef001a10abed',
#   'answer': 'Complexity theory',
#   'no_answer_probability': 0.053022273},
#  {'id': '5ad541ad5b96ef001a10abee',
#   'answer': 'as a function of the size of the instance',
#   'no_answer_probability': 0.10269},
#  {'id': '56e1a564cd28a01900c67a48',
#   'answer': 'Cobham',
#   'no_answer_probability': 0.049576823},
#  {'id': '56e1a564cd28a01900c67a49',
#   'answer': 'time taken',
#   'no_answer_probability': 0.05316882},
#  {'id': '56e1a564cd28a01900c67a4a',
#   'answer': 'T(n)',
#   'no_answer_probability': 0.030325377},
#  {'id': '56e1a564cd28a01900c67a4b',
#   'answer': 'the maximum time taken over all inputs of size n',
#   'no_answer_probability': 0.052005015},
#  {'id': '56e1a564cd28a01900c67a4c',
#   'answer': 'polynomial time algorithm',
#   'no_answer_probability': 0.07182943},
#  {'id': '5ad542db5b96ef001a10abf4',
#   'answer': 'n',
#   'no_answer_probability': 0.030070536},
#  {'id': '5ad542db5b96ef001a10abf5',
#   'answer': 'Cobham',
#   'no_answer_probability': 0.052374497},
#  {'id': '5ad542db5b96ef001a10abf6',
#   'answer': 'T(n)',
#   'no_answer_probability': 0.028812045},
#  {'id': '5ad542db5b96ef001a10abf7',
#   'answer': 'the maximum time taken over all inputs of size n',
#   'no_answer_probability': 0.05601916},
#  {'id': '5ad542db5b96ef001a10abf8',
#   'answer': 'polynomial time algorithm',
#   'no_answer_probability': 0.14238752},
#  {'id': '56e1aba0e3433e1400423094',
#   'answer': 'Turing machine',
#   'no_answer_probability': 0.048416648},
#  {'id': '56e1aba0e3433e1400423095',
#   'answer': 'an algorithm',
#   'no_answer_probability': 0.07094685},
#  {'id': '56e1aba0e3433e1400423097',
#   'answer': 'Turing machine',
#   'no_answer_probability': 0.050341893},
#  {'id': '56e1aba0e3433e1400423098',
#   'answer': 'symbols',
#   'no_answer_probability': 0.06504196},
#  {'id': '5ad543c05b96ef001a10abfe',
#   'answer': 'A Turing machine',
#   'no_answer_probability': 0.047994714},
#  {'id': '5ad543c05b96ef001a10abff',
#   'answer': 'A Turing machine',
#   'no_answer_probability': 0.043641444},
#  {'id': '5ad543c05b96ef001a10ac00',
#   'answer': 'Turing machines',
#   'no_answer_probability': 0.06308416},
#  {'id': '5ad543c05b96ef001a10ac01',
#   'answer': 'Turing machine',
#   'no_answer_probability': 0.04679838},
#  {'id': '56e1aff7cd28a01900c67a68',
#   'answer': 'deterministic Turing machine',
#   'no_answer_probability': 0.05005172},
#  {'id': '56e1aff7cd28a01900c67a69',
#   'answer': 'a fixed set of rules',
#   'no_answer_probability': 0.06729262},
#  {'id': '56e1aff7cd28a01900c67a6a',
#   'answer': 'probabilistic Turing machine',
#   'no_answer_probability': 0.056985192},
#  {'id': '56e1aff7cd28a01900c67a6b',
#   'answer': 'non-deterministic Turing machine',
#   'no_answer_probability': 0.069500074},
#  {'id': '56e1aff7cd28a01900c67a6c',
#   'answer': 'randomized algorithms',
#   'no_answer_probability': 0.057221893},
#  {'id': '5ad546c75b96ef001a10ac0e',
#   'answer': 'A deterministic Turing machine',
#   'no_answer_probability': 0.0616267},
#  {'id': '5ad546c75b96ef001a10ac0f',
#   'answer': 'A probabilistic Turing machine',
#   'no_answer_probability': 0.058668293},
#  {'id': '5ad546c75b96ef001a10ac10',
#   'answer': 'The ability to make probabilistic decisions',
#   'no_answer_probability': 0.028145486},
#  {'id': '5ad546c75b96ef001a10ac11',
#   'answer': 'non-deterministic Turing machine',
#   'no_answer_probability': 0.020504065},
#  {'id': '5ad546c75b96ef001a10ac12',
#   'answer': 'the Turing machine branches into many possible computational paths at each step',
#   'no_answer_probability': 0.03168494},
#  {'id': '56e1b00ce3433e140042309e',
#   'answer': 'complexity classes',
#   'no_answer_probability': 0.01770283},
#  {'id': '56e1b00ce3433e140042309f',
#   'answer': 'time or space) are bounded',
#   'no_answer_probability': 0.067745775},
#  {'id': '56e1b00ce3433e14004230a1',
#   'answer': 'deterministic Turing machines, probabilistic Turing machines, non-deterministic Turing machines, quantum Turing machines, symmetric Turing machines and alternating Turing machines',
#   'no_answer_probability': 0.2855503},
#  {'id': '5ad545545b96ef001a10ac06',
#   'answer': 'define complexity classes',
#   'no_answer_probability': 0.02697866},
#  {'id': '5ad545545b96ef001a10ac07',
#   'answer': 'time or space) are bounded',
#   'no_answer_probability': 0.039149493},
#  {'id': '5ad545545b96ef001a10ac08',
#   'answer': '',
#   'no_answer_probability': 0.014354178},
#  {'id': '5ad545545b96ef001a10ac09',
#   'answer': 'some of these may be more powerful than others',
#   'no_answer_probability': 0.017001847},
#  {'id': '56e1b169cd28a01900c67a72',
#   'answer': 'random access machines',
#   'no_answer_probability': 0.015027908},
#  {'id': '56e1b169cd28a01900c67a73',
#   'answer': 'time and memory consumption',
#   'no_answer_probability': 0.034403797},
#  {'id': '56e1b169cd28a01900c67a74',
#   'answer': 'time and memory',
#   'no_answer_probability': 0.025089435},
#  {'id': '56e1b169cd28a01900c67a75',
#   'answer': 'the machines operate deterministically',
#   'no_answer_probability': 0.34312552},
#  {'id': '5ad547945b96ef001a10ac18',
#   'answer': 'random access machines',
#   'no_answer_probability': 0.0143850995},
#  {'id': '5ad547945b96ef001a10ac19',
#   'answer': 'time and memory consumption',
#   'no_answer_probability': 0.019150542},
#  {'id': '5ad547945b96ef001a10ac1a',
#   'answer': 'time and memory',
#   'no_answer_probability': 0.05470393},
#  {'id': '5ad547945b96ef001a10ac1b',
#   'answer': 'the machines operate deterministically',
#   'no_answer_probability': 0.45400438},
#  {'id': '56e1b355e3433e14004230b0',
#   'answer': 'non-deterministic',
#   'no_answer_probability': 0.028505761},
#  {'id': '56e1b355e3433e14004230b1',
#   'answer': 'more unusual resources',
#   'no_answer_probability': 0.08512976},
#  {'id': '56e1b355e3433e14004230b2',
#   'answer': 'mathematical models',
#   'no_answer_probability': 0.032300707},
#  {'id': '56e1b355e3433e14004230b3',
#   'answer': 'non-deterministic time',
#   'no_answer_probability': 0.031842627},
#  {'id': '5ad5489b5b96ef001a10ac2a',
#   'answer': 'computational problems',
#   'no_answer_probability': 0.030899512},
#  {'id': '5ad5489b5b96ef001a10ac2b',
#   'answer': 'non-deterministic Turing machine',
#   'no_answer_probability': 0.021200206},
#  {'id': '5ad5489b5b96ef001a10ac2c',
#   'answer': 'non-deterministic Turing machine',
#   'no_answer_probability': 0.025206162},
#  {'id': '5ad5489b5b96ef001a10ac2d',
#   'answer': 'non-deterministic Turing machine',
#   'no_answer_probability': 0.022879021},
#  {'id': '5ad5489b5b96ef001a10ac2e',
#   'answer': 'non-deterministic time',
#   'no_answer_probability': 0.023445405},
#  {'id': '56e1b62ecd28a01900c67aa3',
#   'answer': 'the total number of state transitions, or steps',
#   'no_answer_probability': 0.036084935},
#  {'id': '56e1b62ecd28a01900c67aa4',
#   'answer': 'difficulty',
#   'no_answer_probability': 0.035797667},
#  {'id': '56e1b62ecd28a01900c67aa5',
#   'answer': 'DTIME(f(n)).',
#   'no_answer_probability': 0.04918581},
#  {'id': '56e1b62ecd28a01900c67aa6',
#   'answer': 'time and space, a computational model such as the deterministic Turing machine is used. The time required by a deterministic Turing machine M on input x is the total number of state transitions, or steps, the machine makes before it halts and outputs the answer ("yes" or "no"). A Turing machine M is said to operate within time f(n), if the time required by M on each input of length n is at most f(n).',
#   'no_answer_probability': 0.027252266},
#  {'id': '5ad54a375b96ef001a10ac48',
#   'answer': 'a computational model such as the deterministic Turing machine',
#   'no_answer_probability': 0.041561797},
#  {'id': '5ad54a375b96ef001a10ac49',
#   'answer': 'within time f(n),',
#   'no_answer_probability': 0.031213554},
#  {'id': '5ad54a375b96ef001a10ac4a',
#   'answer': 'DTIME(f(n)).',
#   'no_answer_probability': 0.037987944},
#  {'id': '5ad54a375b96ef001a10ac4b',
#   'answer': 'time and space',
#   'no_answer_probability': 0.016838169},
#  {'id': '5ad54a375b96ef001a10ac4c',
#   'answer': 'if there exists a Turing machine operating in time f(n) that solves the problem',
#   'no_answer_probability': 0.24912217},
#  {'id': '56e1b754cd28a01900c67abc',
#   'answer': 'complexity',
#   'no_answer_probability': 0.03066068},
#  {'id': '56e1b754cd28a01900c67abd',
#   'answer': 'computational',
#   'no_answer_probability': 0.026557937},
#  {'id': '56e1b754cd28a01900c67abe',
#   'answer': 'Blum complexity axioms',
#   'no_answer_probability': 0.2310916},
#  {'id': '56e1b754cd28a01900c67abf',
#   'answer': 'complexity',
#   'no_answer_probability': 0.022129348},
#  {'id': '56e1b754cd28a01900c67ac0',
#   'answer': 'complexity',
#   'no_answer_probability': 0.023948029},
#  {'id': '5ad54b035b96ef001a10ac52',
#   'answer': 'Analogous definitions',
#   'no_answer_probability': 0.035311405},
#  {'id': '5ad54b035b96ef001a10ac53',
#   'answer': 'time and space',
#   'no_answer_probability': 0.028504996},
#  {'id': '5ad54b035b96ef001a10ac54',
#   'answer': 'Blum complexity axioms',
#   'no_answer_probability': 0.118155725},
#  {'id': '5ad54b035b96ef001a10ac55',
#   'answer': 'communication complexity, circuit complexity, and decision tree complexity',
#   'no_answer_probability': 0.08052862},
#  {'id': '5ad54b035b96ef001a10ac56',
#   'answer': 'complexity measures',
#   'no_answer_probability': 0.031688035},
#  {'id': '56e1b8f3e3433e14004230e6',
#   'answer': 'The best, worst and average',
#   'no_answer_probability': 0.016919209},
#  {'id': '56e1b8f3e3433e14004230e7',
#   'answer': 'time complexity',
#   'no_answer_probability': 0.019342622},
#  {'id': '56e1b8f3e3433e14004230e8',
#   'answer': 'time complexity',
#   'no_answer_probability': 0.043859247},
#  {'id': '56e1b8f3e3433e14004230e9',
#   'answer': 'time',
#   'no_answer_probability': 0.05750341},
#  {'id': '5ad54c2f5b96ef001a10ac5c',
#   'answer': 'The best, worst and average',
#   'no_answer_probability': 0.03777672},
#  {'id': '5ad54c2f5b96ef001a10ac5d',
#   'answer': 'The best, worst and average case complexity',
#   'no_answer_probability': 0.040275767},
#  {'id': '5ad54c2f5b96ef001a10ac5e',
#   'answer': 'time complexity',
#   'no_answer_probability': 0.043762583},
#  {'id': '5ad54c2f5b96ef001a10ac5f',
#   'answer': 'size n',
#   'no_answer_probability': 0.03603781},
#  {'id': '56e1ba41cd28a01900c67ae0',
#   'answer': 'quicksort',
#   'no_answer_probability': 0.08091309},
#  {'id': '56e1ba41cd28a01900c67ae1',
#   'answer': 'worst-case',
#   'no_answer_probability': 0.056309186},
#  {'id': '56e1ba41cd28a01900c67ae2',
#   'answer': 'O(n2)',
#   'no_answer_probability': 0.057505112},
#  {'id': '5ad54d625b96ef001a10ac64',
#   'answer': 'deterministic sorting algorithm quicksort',
#   'no_answer_probability': 0.06949607},
#  {'id': '5ad54d625b96ef001a10ac65',
#   'answer': 'solves the problem of sorting a list of integers that is given as the input',
#   'no_answer_probability': 0.12624604},
#  {'id': '5ad54d625b96ef001a10ac66',
#   'answer': 'worst-case',
#   'no_answer_probability': 0.0499064},
#  {'id': '5ad54d625b96ef001a10ac67',
#   'answer': 'O(n2)',
#   'no_answer_probability': 0.057144135},
#  {'id': '5ad54d625b96ef001a10ac68',
#   'answer': 'best',
#   'no_answer_probability': 0.052711766},
#  {'id': '56e1bc3ae3433e1400423104',
#   'answer': 'the most efficient algorithm solving a given problem',
#   'no_answer_probability': 0.12690167},
#  {'id': '56e1bc3ae3433e1400423105',
#   'answer': 'algorithms',
#   'no_answer_probability': 0.063650966},
#  {'id': '56e1bc3ae3433e1400423106',
#   'answer': 'lower',
#   'no_answer_probability': 0.031568024},
#  {'id': '56e1bc3ae3433e1400423107',
#   'answer': 'worst-case complexity',
#   'no_answer_probability': 0.040296566},
#  {'id': '56e1bc3ae3433e1400423108',
#   'answer': '"all possible algorithms',
#   'no_answer_probability': 0.030382887},
#  {'id': '5ad54e7c5b96ef001a10ac76',
#   'answer': 'proving upper and lower bounds on the minimum amount of time required by the most efficient algorithm solving a given problem',
#   'no_answer_probability': 0.056744736},
#  {'id': '5ad54e7c5b96ef001a10ac77',
#   'answer': 'The complexity of an algorithm',
#   'no_answer_probability': 0.02776572},
#  {'id': '5ad54e7c5b96ef001a10ac78',
#   'answer': 'Analyzing a particular algorithm',
#   'no_answer_probability': 0.06369526},
#  {'id': '5ad54e7c5b96ef001a10ac79',
#   'answer': 'To show an upper bound T(n) on the time complexity of a problem',
#   'no_answer_probability': 0.033775814},
#  {'id': '5ad54e7c5b96ef001a10ac7a',
#   'answer': 'make a statement about all possible algorithms that solve a given problem',
#   'no_answer_probability': 0.11197644},
#  {'id': '56e1bd4acd28a01900c67afc',
#   'answer': 'big O notation',
#   'no_answer_probability': 0.028433327},
#  {'id': '56e1bd4acd28a01900c67afd',
#   'answer': 'constant factors and smaller terms',
#   'no_answer_probability': 0.2502831},
#  {'id': '56e1bd4acd28a01900c67afe',
#   'answer': 'O(n2).',
#   'no_answer_probability': 0.037729606},
#  {'id': '56e1bd4acd28a01900c67aff',
#   'answer': 'computational model',
#   'no_answer_probability': 0.11671936},
#  {'id': '5ad54f775b96ef001a10ac88',
#   'answer': 'Upper and lower bounds',
#   'no_answer_probability': 0.044563245},
#  {'id': '5ad54f775b96ef001a10ac89',
#   'answer': 'big O notation',
#   'no_answer_probability': 0.039782193},
#  {'id': '5ad54f775b96ef001a10ac8a',
#   'answer': 'big O notation',
#   'no_answer_probability': 0.031973146},
#  {'id': '5ad54f775b96ef001a10ac8b',
#   'answer': 'O(n2).',
#   'no_answer_probability': 0.054310612},
#  {'id': '56e1c0f6cd28a01900c67b2c',
#   'answer': 'complexity classes',
#   'no_answer_probability': 0.04559699},
#  {'id': '56e1c0f6cd28a01900c67b2d',
#   'answer': 'complicated definitions that do not fit into this framework',
#   'no_answer_probability': 0.040377393},
#  {'id': '56e1c0f6cd28a01900c67b2e',
#   'answer': 'complicated definitions',
#   'no_answer_probability': 0.019748693},
#  {'id': '5ad5501f5b96ef001a10ac90',
#   'answer': 'complicated definitions',
#   'no_answer_probability': 0.033943538},
#  {'id': '5ad5501f5b96ef001a10ac91',
#   'answer': 'complexity classes',
#   'no_answer_probability': 0.039215684},
#  {'id': '5ad5501f5b96ef001a10ac92',
#   'answer': 'this framework',
#   'no_answer_probability': 0.03974098},
#  {'id': '5ad5501f5b96ef001a10ac93',
#   'answer': 'complicated definitions',
#   'no_answer_probability': 0.02347519},
#  {'id': '56e1c2eee3433e1400423134',
#   'answer': 'the chosen machine model',
#   'no_answer_probability': 0.1399092},
#  {'id': '56e1c2eee3433e1400423135',
#   'answer': 'linear',
#   'no_answer_probability': 0.03996533},
#  {'id': '56e1c2eee3433e1400423136',
#   'answer': 'single-tape',
#   'no_answer_probability': 0.21531089},
#  {'id': '56e1c2eee3433e1400423137',
#   'answer': 'Cobham-Edmonds',
# ...
#   'no_answer_probability': 0.015335512},
#  {'id': '57060cc352bb89140068980f',
#   'answer': 'Los Angeles Area',
#   'no_answer_probability': 0.018740723},
#  {'id': '57060cc352bb891400689810',
#   'answer': 'San Fernando Valley',
#   'no_answer_probability': 0.070244014},
#  {'id': '57060cc352bb891400689811',
#   'answer': 'Los Angeles',
#   'no_answer_probability': 0.01466222},
#  {'id': '5ad0470477cf76001a686f80',
#   'answer': 'Downtown Burbank, Downtown Santa Monica, Downtown Glendale and Downtown Long Beach',
#   'no_answer_probability': 0.043741275},
#  {'id': '5ad0470477cf76001a686f81',
#   'answer': 'Downtown Los Angeles central business district',
#   'no_answer_probability': 0.017739799},
#  {'id': '5ad0470477cf76001a686f82',
#   'answer': '',
#   'no_answer_probability': 0.10569222},
#  {'id': '57060df252bb891400689820',
#   'answer': 'business',
#   'no_answer_probability': 0.015416317},
#  {'id': '57060df252bb891400689821',
#   'answer': '',
#   'no_answer_probability': 0.019454524},
#  {'id': '57060df252bb891400689822',
#   'answer': 'Hospitality Business/Financial Centre',
#   'no_answer_probability': 0.015407564},
#  {'id': '5ad0475c77cf76001a686f86',
#   'answer': 'Downtown San Bernardino, Hospitality Business/Financial Centre, University Town which are in San Bernardino and Downtown Riverside',
#   'no_answer_probability': 0.02402501},
#  {'id': '5ad0475c77cf76001a686f87',
#   'answer': 'Downtown San Bernardino, Hospitality Business/Financial Centre, University Town which are in San Bernardino and Downtown Riverside',
#   'no_answer_probability': 0.029715799},
#  {'id': '57060eaf75f01819005e7910',
#   'answer': 'Orange County',
#   'no_answer_probability': 0.012445357},
#  {'id': '57060eaf75f01819005e7911',
#   'answer': '',
#   'no_answer_probability': 0.53874534},
#  {'id': '57060eaf75f01819005e7912',
#   'answer': 'West Irvine',
#   'no_answer_probability': 0.014773117},
#  {'id': '57060eaf75f01819005e7913',
#   'answer': 'South Coast Metro',
#   'no_answer_probability': 0.049306754},
#  {'id': '57060eaf75f01819005e7914',
#   'answer': 'rapidly',
#   'no_answer_probability': 0.037715726},
#  {'id': '5ad0483977cf76001a686f8a',
#   'answer': 'Orange County',
#   'no_answer_probability': 0.037726935},
#  {'id': '5ad0483977cf76001a686f8b',
#   'answer': 'South Coast Metro and Newport Center districts',
#   'no_answer_probability': 0.18730192},
#  {'id': '5ad0483977cf76001a686f8c',
#   'answer': 'The Irvine Spectrum, West Irvine, and international corporations',
#   'no_answer_probability': 0.061312065},
#  {'id': '5ad0483977cf76001a686f8d',
#   'answer': 'West Irvine',
#   'no_answer_probability': 0.029931694},
#  {'id': '57060f3e75f01819005e7922',
#   'answer': 'Downtown San Diego',
#   'no_answer_probability': 0.033509027},
#  {'id': '57060f3e75f01819005e7923',
#   'answer': 'Northern San Diego',
#   'no_answer_probability': 0.14659925},
#  {'id': '57060f3e75f01819005e7924',
#   'answer': 'North County',
#   'no_answer_probability': 0.07844659},
#  {'id': '57060f3e75f01819005e7925',
#   'answer': 'San Diego',
#   'no_answer_probability': 0.028672125},
#  {'id': '5ad04b2377cf76001a686f92',
#   'answer': 'Downtown San Diego',
#   'no_answer_probability': 0.024915002},
#  {'id': '5ad04b2377cf76001a686f93',
#   'answer': 'Most of these districts',
#   'no_answer_probability': 0.03417802},
#  {'id': '5ad04b2377cf76001a686f94',
#   'answer': 'Carmel Valley, Del Mar Heights, Mission Valley, Rancho Bernardo, Sorrento Mesa, and University City',
#   'no_answer_probability': 0.040614367},
#  {'id': '570610b275f01819005e792a',
#   'answer': 'Los Angeles International Airport',
#   'no_answer_probability': 0.04201098},
#  {'id': '570610b275f01819005e792b',
#   'answer': 'passenger volume',
#   'no_answer_probability': 0.0344642},
#  {'id': '570610b275f01819005e792c',
#   'answer': 'third',
#   'no_answer_probability': 0.13329536},
#  {'id': '570610b275f01819005e792d',
#   'answer': 'San Diego International Airport',
#   'no_answer_probability': 0.039552014},
#  {'id': '570610b275f01819005e792e',
#   'answer': 'Van Nuys Airport',
#   'no_answer_probability': 0.1040212},
#  {'id': '5ad04bfc77cf76001a686f98',
#   'answer': 'Los Angeles International Airport',
#   'no_answer_probability': 0.026964337},
#  {'id': '5ad04bfc77cf76001a686f99',
#   'answer': 'Los Angeles International Airport',
#   'no_answer_probability': 0.029194882},
#  {'id': '5ad04bfc77cf76001a686f9a',
#   'answer': 'Los Angeles International Airport',
#   'no_answer_probability': 0.037539076},
#  {'id': '5ad04bfc77cf76001a686f9b',
#   'answer': 'Orange County, Bakersfield, Ontario, Burbank and Long Beach',
#   'no_answer_probability': 0.21259351},
#  {'id': '5706111a52bb89140068984c',
#   'answer': 'Metrolink',
#   'no_answer_probability': 0.06062176},
#  {'id': '5706111a52bb89140068984d',
#   'answer': 'seven',
#   'no_answer_probability': 0.040645007},
#  {'id': '5706111a52bb89140068984e',
#   'answer': 'Six',
#   'no_answer_probability': 0.044096768},
#  {'id': '5706111a52bb89140068984f',
#   'answer': 'Orange',
#   'no_answer_probability': 0.051074374},
#  {'id': '5ad04d3077cf76001a686fa0',
#   'answer': 'Downtown Los Angeles',
#   'no_answer_probability': 0.037681583},
#  {'id': '5ad04d3077cf76001a686fa1',
#   'answer': 'Metrolink',
#   'no_answer_probability': 0.032020044},
#  {'id': '5ad04d3077cf76001a686fa2',
#   'answer': 'Riverside, Orange, and San Diego counties',
#   'no_answer_probability': 0.09061173},
#  {'id': '570611c475f01819005e793c',
#   'answer': 'Port of Los Angeles',
#   'no_answer_probability': 0.065032594},
#  {'id': '570611c475f01819005e793d',
#   'answer': 'Port of Long Beach',
#   'no_answer_probability': 0.10037431},
#  {'id': '570611c475f01819005e793e',
#   'answer': 'Southern',
#   'no_answer_probability': 0.027976789},
#  {'id': '5ad04de377cf76001a686fa6',
#   'answer': 'the Port of Los Angeles',
#   'no_answer_probability': 0.06418219},
#  {'id': '5ad04de377cf76001a686fa7',
#   'answer': 'Port of Long Beach',
#   'no_answer_probability': 0.06876141},
#  {'id': '5ad04de377cf76001a686fa8',
#   'answer': 'Port of Long Beach',
#   'no_answer_probability': 0.055192545},
#  {'id': '5ad04de377cf76001a686fa9',
#   'answer': 'Port of Long Beach',
#   'no_answer_probability': 0.078184105},
#  {'id': '5706139252bb891400689864',
#   'answer': 'The Tech Coast',
#   'no_answer_probability': 0.09164429},
#  {'id': '5706139252bb891400689865',
#   'answer': 'research universities',
#   'no_answer_probability': 0.07918686},
#  {'id': '5706139252bb891400689866',
#   'answer': 'private',
#   'no_answer_probability': 0.05952992},
#  {'id': '5706139252bb891400689867',
#   'answer': '5',
#   'no_answer_probability': 0.042982236},
#  {'id': '5706139252bb891400689868',
#   'answer': '12',
#   'no_answer_probability': 0.05384747},
#  {'id': '5ad04ecf77cf76001a686fae',
#   'answer': 'Irvine, Los Angeles, Riverside, Santa Barbara, and San Diego',
#   'no_answer_probability': 0.07714758},
#  {'id': '5ad04ecf77cf76001a686faf',
#   'answer': '5',
#   'no_answer_probability': 0.040442202},
#  {'id': '5ad04ecf77cf76001a686fb0',
#   'answer': '12',
#   'no_answer_probability': 0.05847379},
#  {'id': '5ad04ecf77cf76001a686fb1',
#   'answer': 'University of Redlands, University of San Diego, and the University of Southern California',
#   'no_answer_probability': 0.042844072},
#  {'id': '5ad04ecf77cf76001a686fb2',
#   'answer': 'San Bernardino',
#   'no_answer_probability': 0.055812735},
#  {'id': '5706143575f01819005e7950',
#   'answer': 'Professional',
#   'no_answer_probability': 0.06141562},
#  {'id': '5706143575f01819005e7951',
#   'answer': 'NBA',
#   'no_answer_probability': 0.07035298},
#  {'id': '5706143575f01819005e7952',
#   'answer': 'MLB',
#   'no_answer_probability': 0.03420288},
#  {'id': '5706143575f01819005e7953',
#   'answer': 'Los Angeles Kings',
#   'no_answer_probability': 0.053780675},
#  {'id': '5706143575f01819005e7954',
#   'answer': 'LA Galaxy',
#   'no_answer_probability': 0.18101102},
#  {'id': '5ad04f7977cf76001a686fb8',
#   'answer': 'Los Angeles Lakers, Los Angeles Clippers',
#   'no_answer_probability': 0.0765356},
#  {'id': '5ad04f7977cf76001a686fb9',
#   'answer': 'Los Angeles Rams, San Diego Chargers',
#   'no_answer_probability': 0.039064568},
#  {'id': '5ad04f7977cf76001a686fba',
#   'answer': 'Los Angeles Dodgers, Los Angeles Angels of Anaheim, San Diego Padres',
#   'no_answer_probability': 0.07681607},
#  {'id': '5ad04f7977cf76001a686fbb',
#   'answer': 'Los Angeles Kings, Anaheim Ducks',
#   'no_answer_probability': 0.08530569},
#  {'id': '5ad04f7977cf76001a686fbc',
#   'answer': 'LA Galaxy',
#   'no_answer_probability': 0.12138817},
#  {'id': '5706149552bb891400689880',
#   'answer': 'Chivas',
#   'no_answer_probability': 0.03496286},
#  {'id': '5706149552bb891400689881',
#   'answer': 'two',
#   'no_answer_probability': 0.04135562},
#  {'id': '5706149552bb891400689882',
#   'answer': '2014',
#   'no_answer_probability': 0.038970593},
#  {'id': '5706149552bb891400689883',
#   'answer': 'StubHub Center',
#   'no_answer_probability': 0.042454623},
#  {'id': '5706149552bb891400689884',
#   'answer': '2018',
#   'no_answer_probability': 0.056770105},
#  {'id': '5ad050c877cf76001a686fc2',
#   'answer': 'two',
#   'no_answer_probability': 0.046349812},
#  {'id': '5ad050c877cf76001a686fc3',
#   'answer': 'LA Galaxy and Chivas USA',
#   'no_answer_probability': 0.039231524},
#  {'id': '5ad050c877cf76001a686fc4',
#   'answer': '2005 to 2014, there were two Major League Soccer teams in Los Angeles — the LA Galaxy and Chivas USA — that both played at the StubHub Center and were local rivals. However, Chivas were suspended following the 2014 MLS season',
#   'no_answer_probability': 0.03180029},
#  {'id': '5ad050c877cf76001a686fc5',
#   'answer': '2018',
#   'no_answer_probability': 0.051386185},
#  {'id': '570614ff52bb89140068988a',
#   'answer': 'College sports',
#   'no_answer_probability': 0.026085643},
#  {'id': '570614ff52bb89140068988b',
#   'answer': 'USC Trojans',
#   'no_answer_probability': 0.04185699},
#  {'id': '570614ff52bb89140068988c',
#   'answer': 'USC Trojans',
#   'no_answer_probability': 0.04541432},
#  {'id': '570614ff52bb89140068988d',
#   'answer': 'Pac-12 Conference',
#   'no_answer_probability': 0.049186308},
#  {'id': '570614ff52bb89140068988e',
#   'answer': 'Pac-12 Conference',
#   'no_answer_probability': 0.055815894},
#  {'id': '5ad0511577cf76001a686fca',
#   'answer': 'USC Trojans',
#   'no_answer_probability': 0.033049896},
#  {'id': '5ad0511577cf76001a686fcb',
#   'answer': 'USC Trojans',
#   'no_answer_probability': 0.040535577},
#  {'id': '5ad0511577cf76001a686fcc',
#   'answer': 'Pac-12 Conference',
#   'no_answer_probability': 0.16966192},
#  {'id': '5706155352bb891400689894',
#   'answer': 'Rugby',
#   'no_answer_probability': 0.029380694},
#  {'id': '5706155352bb891400689895',
#   'answer': 'high school',
#   'no_answer_probability': 0.14070225},
#  {'id': '5706155352bb891400689896',
#   'answer': 'official school sport',
#   'no_answer_probability': 0.17653662},
#  {'id': '5ad051be77cf76001a686fd0',
#   'answer': 'Rugby',
#   'no_answer_probability': 0.03172475},
#  {'id': '57092322efce8f15003a7db0',
#   'answer': 'BSkyB',
#   'no_answer_probability': 0.04182096},
#  {'id': '57092322efce8f15003a7db1',
#   'answer': 'BSkyB',
#   'no_answer_probability': 0.03826385},
#  {'id': '57092322efce8f15003a7db2',
#   'answer': '2014',
#   'no_answer_probability': 0.02857813},
#  {'id': '57092322efce8f15003a7db3',
#   'answer': 'British Sky Broadcasting Group plc',
#   'no_answer_probability': 0.046268445},
#  {'id': '57092322efce8f15003a7db4',
#   'answer': 'Sky UK Limited',
#   'no_answer_probability': 0.07601812},
#  {'id': '5a2c08aebfd06b001a5ae989',
#   'answer': '',
#   'no_answer_probability': 0.02894842},
#  {'id': '5a2c08aebfd06b001a5ae98a',
#   'answer': 'BSkyB',
#   'no_answer_probability': 0.03348734},
#  {'id': '5a2c08aebfd06b001a5ae98b',
#   'answer': '2014',
#   'no_answer_probability': 0.02787808},
#  {'id': '5a2c08aebfd06b001a5ae98c',
#   'answer': 'November 1990',
#   'no_answer_probability': 0.03082234},
#  {'id': '5a2c08aebfd06b001a5ae98d',
#   'answer': 'Sky UK Limited',
#   'no_answer_probability': 0.04543398},
#  {'id': '57094a79efce8f15003a7dc4',
#   'answer': '2006',
#   'no_answer_probability': 0.05482995},
#  {'id': '57094a79efce8f15003a7dc5',
#   'answer': 'two',
#   'no_answer_probability': 0.053851217},
#  {'id': '57094a79efce8f15003a7dc6',
#   'answer': 'Sky',
#   'no_answer_probability': 0.09506076},
#  {'id': '57094a79efce8f15003a7dc7',
#   'answer': '£1.3bn',
#   'no_answer_probability': 0.12064983},
#  {'id': '5a2c0c2fbfd06b001a5ae99b',
#   'answer': 'BSkyB',
#   'no_answer_probability': 0.058722027},
#  {'id': '5a2c0c2fbfd06b001a5ae99c',
#   'answer': 'two',
#   'no_answer_probability': 0.056010295},
#  {'id': '5a2c0c2fbfd06b001a5ae99d',
#   'answer': 'four',
#   'no_answer_probability': 0.07486208},
#  {'id': '5a2c0c2fbfd06b001a5ae99e',
#   'answer': '£1.3bn',
#   'no_answer_probability': 0.10382495},
#  {'id': '5a2c0c2fbfd06b001a5ae99f',
#   'answer': '3D',
#   'no_answer_probability': 0.09333211},
#  {'id': '57094b4f9928a814004714f6',
#   'answer': 'ONdigital',
#   'no_answer_probability': 0.056511708},
#  {'id': '57094b4f9928a814004714f7',
#   'answer': "ITV Digital's free-to-air replacement, Freeview",
#   'no_answer_probability': 0.060411345},
#  {'id': '57094b4f9928a814004714f8',
#   'answer': 'three',
#   'no_answer_probability': 0.047817115},
#  {'id': '57094b4f9928a814004714f9',
#   'answer': 'Sky Three',
#   'no_answer_probability': 0.06497604},
#  {'id': '57094b4f9928a814004714fa',
#   'answer': 'Pick TV',
#   'no_answer_probability': 0.05107326},
#  {'id': '5a2c14b4bfd06b001a5ae9d3',
#   'answer': 'ONdigital',
#   'no_answer_probability': 0.049387176},
#  {'id': '5a2c14b4bfd06b001a5ae9d4',
#   'answer': 'Sky Three',
#   'no_answer_probability': 0.045616623},
#  {'id': '5a2c14b4bfd06b001a5ae9d5',
#   'answer': 'Sky Three',
#   'no_answer_probability': 0.060565136},
#  {'id': '5a2c14b4bfd06b001a5ae9d6',
#   'answer': "ITV Digital's free-to-air replacement, Freeview",
#   'no_answer_probability': 0.05578697},
#  {'id': '5a2c14b4bfd06b001a5ae9d7',
#   'answer': 'Pick TV',
#   'no_answer_probability': 0.06871892},
#  {'id': '57094ca7efce8f15003a7dd6',
#   'answer': 'Sky+ PVR',
#   'no_answer_probability': 0.0768195},
#  {'id': '57094ca7efce8f15003a7dd7',
#   'answer': 'September 2007',
#   'no_answer_probability': 0.05884894},
#  {'id': '57094ca7efce8f15003a7dd8',
#   'answer': 'monthly fee',
#   'no_answer_probability': 0.06485983},
#  {'id': '57094ca7efce8f15003a7dd9',
#   'answer': 'January 2010',
#   'no_answer_probability': 0.074250594},
#  {'id': '57094ca7efce8f15003a7dda',
#   'answer': 'Sky+HD Box',
#   'no_answer_probability': 0.08421509},
#  {'id': '5a2c16e3bfd06b001a5ae9e7',
#   'answer': 'Sky+ PVR',
#   'no_answer_probability': 0.08014171},
#  {'id': '5a2c16e3bfd06b001a5ae9e8',
#   'answer': 'September 2007',
#   'no_answer_probability': 0.05132557},
#  {'id': '5a2c16e3bfd06b001a5ae9e9',
#   'answer': 'a monthly fee',
#   'no_answer_probability': 0.09749165},
#  {'id': '5a2c16e3bfd06b001a5ae9ea',
#   'answer': '1 July 2007',
#   'no_answer_probability': 0.045170315},
#  {'id': '5a2c16e3bfd06b001a5ae9eb',
#   'answer': 'Sky+.',
#   'no_answer_probability': 0.072192356},
#  {'id': '57094d489928a8140047150a',
#   'answer': 'VideoGuard',
#   'no_answer_probability': 0.04155512},
#  {'id': '57094d489928a8140047150b',
#   'answer': 'NDS',
#   'no_answer_probability': 0.06036351},
#  {'id': '57094d489928a8140047150c',
#   'answer': 'Cisco Systems',
#   'no_answer_probability': 0.070310295},
#  {'id': '57094d489928a8140047150d',
#   'answer': 'BSkyB',
#   'no_answer_probability': 0.032125905},
#  {'id': '57094d489928a8140047150e',
#   'answer': 'Sky+',
#   'no_answer_probability': 0.20557638},
#  {'id': '5a2c3a5cbfd06b001a5aea79',
#   'answer': 'VideoGuard',
#   'no_answer_probability': 0.0507242},
#  {'id': '5a2c3a5cbfd06b001a5aea7a',
#   'answer': 'BSkyB utilises the VideoGuard pay-TV scrambling system owned by NDS, a Cisco Systems company. There are tight controls over use of VideoGuard decoders; they are not available as stand-alone DVB CAMs (conditional-access modules). BSkyB',
#   'no_answer_probability': 0.03642521},
#  {'id': '5a2c3a5cbfd06b001a5aea7b',
#   'answer': '',
#   'no_answer_probability': 0.06861746},
#  {'id': '5a2c3a5cbfd06b001a5aea7c',
#   'answer': 'Cisco Systems',
#   'no_answer_probability': 0.0384024},
#  {'id': '5a2c3a5cbfd06b001a5aea7d',
#   'answer': 'Sky+',
#   'no_answer_probability': 0.07648081},
#  {'id': '570953a7efce8f15003a7dfe',
#   'answer': '2007',
#   'no_answer_probability': 0.022689572},
#  ...]

# %%
# Create the no-answer probabilities dictionary
na_probs_dict = {pred['id']: pred['no_answer_probability'] for pred in final_predictions}

# Convert to dictionary format
pred_dict = {pred['id']: pred['answer'] for pred in final_predictions}

# %%
def save_predictions(predictions, filename):
    with open(filename, 'w') as f:
        json.dump(predictions, f)

# %%
def save_na_probs(na_probs_dict, filename):
    # Convert numpy float32 to regular Python floats for JSON serialization
    modified_dict = {k: float(v) for k, v in na_probs_dict.items()}
    with open(filename, 'w') as f:
        json.dump(modified_dict, f, indent=2)

# %%
# Save your predictions to a file in your mounted drive
save_predictions(pred_dict, '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/pred_roberta_finetuned.json')

# %%
save_na_probs(na_probs_dict, '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/na_probs_roberta_finetuned.json')

# %%
# Paths to the evaluation script and data files
eval_script_path = '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/SQuAD/evaluate-v2.0.py'
data_file_path = '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/SQuAD/dev-v2.0.json'
pred_file_path = '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/pred_roberta_finetuned.json'
na_prob_file_path = '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/na_probs_roberta_finetuned.json'
out_file_path = '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/eval_results_roberta_finetuned.json'
out_image_dir = '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/images_roberta_finetuned'

# %%
# Command to run the evaluation script
command = [
    'python', eval_script_path,
    data_file_path,
    pred_file_path,
    '-n', na_prob_file_path,
    '-o', out_file_path,
    '-p', out_image_dir
]

# %%
import subprocess
# Use the evaluation script
subprocess.run(command, check=False, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
# Out:
# CompletedProcess(args=['python', '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/SQuAD/evaluate-v2.0.py', '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/SQuAD/dev-v2.0.json', '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/pred_roberta_finetuned.json', '-n', '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/na_probs_roberta_finetuned.json', '-o', '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/eval_results_roberta_finetuned.json', '-p', '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/images_roberta_finetuned'], returncode=0, stdout=b'', stderr=b'')
