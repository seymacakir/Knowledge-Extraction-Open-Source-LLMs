# %%
# !pip install datasets transformers torch torchvision torchaudio evaluate tqdm requests>=2.32.1 accelerate transformers[sentencepiece] transformers[torch]
# !pip install datasets transformers torch torchvision torchaudio evaluate tqdm
# !pip install requests>=2.32.1
# !pip install accelerate
# !pip install transformers[sentencepiece]
# !pip install transformers[torch]
# Out:
# Collecting datasets
#   Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.18.0+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.3.0+cu121)
# Collecting evaluate
#   Downloading evaluate-0.4.2-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 40.2 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 18.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting requests>=2.32.2 (from datasets)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 10.2 MB/s eta 0:00:00
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 31.1 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 75.4 MB/s eta 0:00:00
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, requests, pyarrow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, datasets, evaluate
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 16.1.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 16.1.0 which is incompatible.
# Successfully installed datasets-2.20.0 dill-0.3.8 evaluate-0.4.2 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 pyarrow-16.1.0 requests-2.32.3 xxhash-3.4.1
# Collecting accelerate
#   Downloading accelerate-0.32.1-py3-none-any.whl (314 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.1/314.1 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.3.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.23.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.5.82)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.32.1
# Requirement already satisfied: transformers[sentencepiece] in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (4.66.4)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.1.99)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers[sentencepiece]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers[sentencepiece]) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[sentencepiece]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[sentencepiece]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[sentencepiece]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[sentencepiece]) (2024.6.2)
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.3.0+cu121)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.32.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers[torch]) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->transformers[torch]) (12.5.82)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->transformers[torch]) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->transformers[torch]) (1.3.0)

# %%
from datasets import Dataset, DatasetDict
import json
from tqdm.auto import tqdm
from transformers import AutoTokenizer, AutoModelForQuestionAnswering, TrainingArguments, Trainer, default_data_collator
import tensorflow as tf
import torch
import numpy as np
import collections

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the SQuAD JSON files
with open('/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/SQuAD/train-v2.0.json') as f:
    train_data = json.load(f)

with open('/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/SQuAD/dev-v2.0.json') as g:
    dev_data = json.load(g)

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# Function to transform the data into the required format
def transform_data(data):
    transformed_data = {
        'id': [],
        'title': [],
        'context': [],
        'question': [],
        'answers': []
    }
    for article in data:
        title = article['title']
        for paragraph in article['paragraphs']:
            context = paragraph['context']
            for qa in paragraph['qas']:
                transformed_data['id'].append(qa['id'])
                transformed_data['title'].append(title)
                transformed_data['context'].append(context)
                transformed_data['question'].append(qa['question'])
                transformed_data['answers'].append({
                    'text': [answer['text'] for answer in qa['answers']],
                    'answer_start': [answer['answer_start'] for answer in qa['answers']]
                })
    return transformed_data

# Transform the data
train_transformed = transform_data(train_data['data'])
dev_transformed = transform_data(dev_data['data'])

# Create Dataset objects and DatasetDict
raw_datasets = DatasetDict({
    'train': Dataset.from_dict(train_transformed),
    'validation': Dataset.from_dict(dev_transformed)
})

# %%
print(raw_datasets)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 130319
#     })
#     validation: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 11873
#     })
# })

# %%
# model_checkpoint = "roberta-base" # if you want to start fresh
model_checkpoint = "ozgurkk/roberta-large-finetuned-squad" # if you want to take on a fine-tuned model
# model_checkpoint = "FacebookAI/roberta-large"
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
tokenizer.is_fast
# Out:
# True

# %%
max_length = 384 # The maximum length of a feature (question and context)
doc_stride = 128 # The authorized overlap between two part of the context when splitting it is needed.

# %%
#For this notebook to work with any kind of models, we need to account for the special case where
# the model expects padding on the left (in which case we switch the order of the question and the context):
pad_on_right = tokenizer.padding_side == "right"

# %%
# Function to prepare training features
def prepare_train_features(examples):
    pad_on_right = tokenizer.padding_side == "right"
    examples["question"] = [q.lstrip() for q in examples["question"]]
    tokenized_examples = tokenizer(
        examples["question" if pad_on_right else "context"],
        examples["context" if pad_on_right else "question"],
        truncation="only_second" if pad_on_right else "only_first",
        max_length=384,
        stride=128,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )
    sample_mapping = tokenized_examples.pop("overflow_to_sample_mapping")
    offset_mapping = tokenized_examples.pop("offset_mapping")
    tokenized_examples["start_positions"] = []
    tokenized_examples["end_positions"] = []
    for i, offsets in enumerate(offset_mapping):
        input_ids = tokenized_examples["input_ids"][i]
        cls_index = input_ids.index(tokenizer.cls_token_id)
        sequence_ids = tokenized_examples.sequence_ids(i)
        sample_index = sample_mapping[i]
        answers = examples["answers"][sample_index]
        if len(answers["answer_start"]) == 0:
            tokenized_examples["start_positions"].append(cls_index)
            tokenized_examples["end_positions"].append(cls_index)
        else:
            start_char = answers["answer_start"][0]
            end_char = start_char + len(answers["text"][0])
            token_start_index = 0
            while sequence_ids[token_start_index] != (1 if pad_on_right else 0):
                token_start_index += 1
            token_end_index = len(input_ids) - 1
            while sequence_ids[token_end_index] != (1 if pad_on_right else 0):
                token_end_index -= 1
            if not (offsets[token_start_index][0] <= start_char and offsets[token_end_index][1] >= end_char):
                tokenized_examples["start_positions"].append(cls_index)
                tokenized_examples["end_positions"].append(cls_index)
            else:
                while token_start_index < len(offsets) and offsets[token_start_index][0] <= start_char:
                    token_start_index += 1
                tokenized_examples["start_positions"].append(token_start_index - 1)
                while offsets[token_end_index][1] >= end_char:
                    token_end_index -= 1
                tokenized_examples["end_positions"].append(token_end_index + 1)
    return tokenized_examples

# %%
# Check if the tokenizer has a CLS token
has_cls_token = tokenizer.cls_token is not None

# Retrieve the CLS token ID
cls_token_id = tokenizer.cls_token_id if has_cls_token else None

# Print out the CLS token and its ID
print(f"CLS Token: {tokenizer.cls_token}")
print(f"CLS Token ID: {cls_token_id}")

# Verify if the token ID is valid
if cls_token_id is not None:
    print(f"CLS Token ID is valid: {cls_token_id} is in the tokenizer vocabulary")
else:
    print("CLS Token is not available in the tokenizer")
# Out:
# CLS Token: <s>
# CLS Token ID: 0
# CLS Token ID is valid: 0 is in the tokenizer vocabulary

# %%
tokenized_datasets = raw_datasets.map(prepare_train_features, batched=True, remove_columns=raw_datasets["train"].column_names)
# Out:
# Map:   0%|          | 0/130319 [00:00<?, ? examples/s]
# Map:   0%|          | 0/11873 [00:00<?, ? examples/s]

# %%
# we are now at the stage where preprocessing is done - we can continue with fine-tuning
tokenized_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'start_positions', 'end_positions'],
#         num_rows: 131823
#     })
#     validation: Dataset({
#         features: ['input_ids', 'attention_mask', 'start_positions', 'end_positions'],
#         num_rows: 12165
#     })
# })

# %%
model = AutoModelForQuestionAnswering.from_pretrained(model_checkpoint)
# Out:
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaForQuestionAnswering were not initialized from the model checkpoint at FacebookAI/roberta-large and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# monitor gpu usage
# !nvidia-smi
# Out:
# Thu Jul 11 11:25:15 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA L4                      Off | 00000000:00:03.0 Off |                    0 |
# | N/A   34C    P8              12W /  72W |      1MiB / 23034MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
batch_size = 16
# Training arguments
training_args = TrainingArguments(
    output_dir="roberta-large-finetuned-squad",
    eval_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=1,
    weight_decay=0.01,
    push_to_hub=True,
    logging_dir='/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/tb_logs_roberta_large',
    logging_steps=500,
    save_steps=5000,
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=False,
    report_to="tensorboard",
    run_name="roberta-large-finetuning",
    remove_unused_columns=True,
    hub_model_id="ozgurkk/roberta-large-finetuned-squad",
    save_strategy="epoch",
    fp16=True,
    gradient_accumulation_steps=4,
    # warmup_steps=1000  # Adding warmup steps
    warmup_ratio=0.1  # 10% of the total steps are used for warmup
)

# %%
data_collator = default_data_collator

# %%
# Instantiate Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    data_collator=default_data_collator,
    tokenizer=tokenizer
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='1836' max='2059' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1836/2059 1:36:36 < 11:44, 0.32 it/s, Epoch 0.89/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='2059' max='2059' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2059/2059 1:51:42, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.738100</td>
#       <td>0.659502</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=2059, training_loss=1.0646058518426866, metrics={'train_runtime': 6705.5381, 'train_samples_per_second': 19.659, 'train_steps_per_second': 0.307, 'total_flos': 9.17859694459945e+16, 'train_loss': 1.0646058518426866, 'epoch': 0.999635878140551})

# %%
# trainer.save_model("/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/SQuAD/roberta-base-finetuned-squad")

# %%
trainer.push_to_hub()
# Out:
# CommitInfo(commit_url='https://huggingface.co/ozgurkk/roberta-large-finetuned-squad/commit/3687cb48b057344edec4e6fe525cb7571a127263', commit_message='End of training', commit_description='', oid='3687cb48b057344edec4e6fe525cb7571a127263', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# We have one logit for each feature and each token.
# The most obvious way to predict an answer for each feature is to take the index for the maximum of the start logits as a start position and the index of the maximum of the end logits as an end position.

# %% [markdown]
# This will work great in a lot of cases, but what if this prediction gives us something impossible: the start position could be greater than the end position, or point to a span of text in the question instead of the answer. In that case, we might want to look at the second best prediction to see if it gives a possible answer and select that instead.
#
# However, picking the second best answer is not as easy as picking the best one: is it the second best index in the start logits with the best index in the end logits? Or the best index in the start logits with the second best index in the end logits? And if that second best answer is not possible either, it gets even trickier for the third best answer.
#
# To classify our answers, we will use the score obtained by adding the start and end logits. We won't try to order all the possible answers and limit ourselves to with a hyper-parameter we call n_best_size. We'll pick the best indices in the start and end logits and gather all the answers this predicts. After checking if each one is valid, we will sort them by their score and keep the best one. Here is how we would do this on the first feature in the batch:

# %% [markdown]
# And then we can sort the `valid_answers` according to their `score` and only keep the best one. The only point left is how to check a given span is inside the context (and not the question) and how to get back the text inside. To do this, we need to add two things to our validation features:
# - the ID of the example that generated the feature (since each example can generate several features, as seen before);
# - the offset mapping that will give us a map from token indices to character positions in the context.
#
# That's why we will re-process the validation set with the following function, slightly different from `prepare_train_features`:

# %%
def prepare_validation_features(examples):
    examples["question"] = [q.lstrip() for q in examples["question"]]
    pad_on_right = tokenizer.padding_side == "right"
    tokenized_examples = tokenizer(
        examples["question" if pad_on_right else "context"],
        examples["context" if pad_on_right else "question"],
        truncation="only_second" if pad_on_right else "only_first",
        max_length=384,
        stride=128,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )
    sample_mapping = tokenized_examples.pop("overflow_to_sample_mapping")
    tokenized_examples["example_id"] = []
    for i in range(len(tokenized_examples["input_ids"])):
        sequence_ids = tokenized_examples.sequence_ids(i)
        context_index = 1 if pad_on_right else 0
        sample_index = sample_mapping[i]
        tokenized_examples["example_id"].append(examples["id"][sample_index])
        tokenized_examples["offset_mapping"][i] = [
            (o if sequence_ids[k] == context_index else None)
            for k, o in enumerate(tokenized_examples["offset_mapping"][i])
        ]
    return tokenized_examples

# %%
# apply preprocessing to the validation dataset
validation_features = raw_datasets["validation"].map(
    prepare_validation_features,
    batched=True,
    remove_columns=raw_datasets["validation"].column_names
)
# Out:
# Map:   0%|          | 0/11873 [00:00<?, ? examples/s]

# %%
validation_features
# Out:
# Dataset({
#     features: ['input_ids', 'attention_mask', 'offset_mapping', 'example_id'],
#     num_rows: 12165
# })

# %%
# get predictions for each feature
raw_predictions = trainer.predict(validation_features)

# %%
raw_predictions
# Out:
# PredictionOutput(predictions=(array([[  2.4824219,  -6.4023438,  -7.0703125, ..., -10.4453125,
#         -10.4453125, -10.4453125],
#        [  3.6210938,  -7.75     ,  -8.21875  , ..., -10.171875 ,
#         -10.171875 , -10.171875 ],
#        [  3.9863281,  -8.1015625,  -9.2265625, ..., -10.2109375,
#         -10.2109375, -10.2109375],
#        ...,
#        [  6.       ,  -8.0859375, -10.1328125, ..., -10.3125   ,
#         -10.3125   , -10.3125   ],
#        [  6.1367188,  -9.390625 ,  -9.828125 , ..., -10.296875 ,
#         -10.296875 , -10.296875 ],
#        [  6.2148438,  -9.5390625,  -9.9140625, ..., -10.28125  ,
#         -10.28125  , -10.28125  ]], dtype=float32), array([[  2.1855469,  -7.3984375,  -7.3007812, ..., -11.125    ,
#         -11.125    , -11.125    ],
#        [  3.3691406,  -8.1484375,  -8.640625 , ..., -10.859375 ,
#         -10.859375 , -10.859375 ],
#        [  3.6894531,  -9.3515625,  -9.5390625, ..., -10.9453125,
#         -10.9453125, -10.9453125],
#        ...,
#        [  5.8203125,  -8.390625 ,  -9.5234375, ..., -11.046875 ,
#         -11.046875 , -11.046875 ],
#        [  5.8398438,  -9.3984375,  -9.28125  , ..., -11.0234375,
#         -11.0234375, -11.0234375],
#        [  5.9804688,  -9.390625 ,  -9.2734375, ..., -10.9453125,
#         -10.9453125, -10.9453125]], dtype=float32)), label_ids=None, metrics={'test_runtime': 184.5882, 'test_samples_per_second': 65.903, 'test_steps_per_second': 4.123})

# %%
# trainer hides the columns that are not used by the model
# here example_id and offset_mapping - which we will need for post processing
# we should get them back
validation_features.set_format(type=validation_features.format["type"], columns=list(validation_features.features.keys()))

# %% [markdown]
# We're almost ready for our post-processing function. The last bit to deal with is the impossible answer (when `squad_v2 = True`). The code above only keeps answers that are inside the context, we need to also grab the score for the impossible answer (which has start and end indices corresponding to the index of the CLS token). When one example gives several features, we have to predict the impossible answer when all the features give a high score to the impossible answer (since one feature could predict the impossible answer just because the answer isn't in the part of the context it has access too), which is why the score of the impossible answer for one example is the *minimum* of the scores for the impossible answer in each feature generated by the example.
#
# We then predict the impossible answer when that score is greater than the score of the best non-impossible answer. All combined together, this gives us this post-processing function:

# %%
squad_v2 = True

# %%
# final_predictions = postprocess_qa_predictions(raw_datasets["validation"], validation_features, raw_predictions.predictions)
# Out:
# Post-processing 11873 example predictions split into 12165 features.
#   0%|          | 0/11873 [00:00<?, ?it/s]

# %%
def softmax(x):
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=0)

# %%
def postprocess_qa_predictions(
    examples, features, raw_predictions, tokenizer, n_best_size=20, max_answer_length=30, squad_v2=True
):
    all_start_logits, all_end_logits = raw_predictions
    # Build a map example to its corresponding features.
    example_id_to_index = {k: i for i, k in enumerate(examples["id"])}
    features_per_example = collections.defaultdict(list)
    for i, feature in enumerate(features):
        features_per_example[example_id_to_index[feature["example_id"]]].append(i)

    # The dictionaries we have to fill.
    predictions = collections.OrderedDict()
    no_answer_probs = collections.OrderedDict()

    # Logging.
    print(f"Post-processing {len(examples)} example predictions split into {len(features)} features.")

    # Let's loop over all the examples!
    for example_index, example in enumerate(tqdm(examples)):
        # Those are the indices of the features associated with the current example.
        feature_indices = features_per_example[example_index]

        min_null_score = float('inf')  # Only used if squad_v2 is True.
        valid_answers = []

        context = example["context"]
        # Looping through all the features associated with the current example.
        for feature_index in feature_indices:
            # We grab the predictions of the model for this feature.
            start_logits = all_start_logits[feature_index]
            end_logits = all_end_logits[feature_index]
            # This is what will allow us to map some positions in our logits to spans of texts in the original context.
            offset_mapping = features[feature_index]["offset_mapping"]

            # Update minimum null prediction.
            cls_index = features[feature_index]["input_ids"].index(tokenizer.cls_token_id)
            feature_null_score = start_logits[cls_index] + end_logits[cls_index]
            if feature_null_score < min_null_score:
                min_null_score = feature_null_score

            # Go through all possibilities for the `n_best_size` greater start and end logits.
            start_indexes = np.argsort(start_logits)[-1 : -n_best_size - 1 : -1].tolist()
            end_indexes = np.argsort(end_logits)[-1 : -n_best_size - 1 : -1].tolist()
            for start_index in start_indexes:
                for end_index in end_indexes:
                    # Don't consider out-of-scope answers, either because the indices are out of bounds or correspond
                    # to part of the input_ids that are not in the context.
                    if (
                        start_index >= len(offset_mapping)
                        or end_index >= len(offset_mapping)
                        or offset_mapping[start_index] is None
                        or offset_mapping[end_index] is None
                    ):
                        continue
                    # Don't consider answers with a length that is either < 0 or > max_answer_length.
                    if end_index < start_index or end_index - start_index + 1 > max_answer_length:
                        continue

                    start_char = offset_mapping[start_index][0]
                    end_char = offset_mapping[end_index][1]
                    valid_answers.append(
                        {
                            "score": float(start_logits[start_index] + end_logits[end_index]),
                            "text": context[start_char: end_char]
                        }
                    )

        if len(valid_answers) > 0:
            best_answer = sorted(valid_answers, key=lambda x: x["score"], reverse=True)[0]
        else:
            # In the very rare edge case we have not a single non-null prediction, we create a fake prediction to avoid
            # failure.
            best_answer = {"text": "", "score": 0.0}

        # Let's pick our final answer: the best one or the null answer (only for squad_v2)
        if not squad_v2:
            predictions[example["id"]] = best_answer["text"]
        else:
            answer = best_answer["text"] if best_answer["score"] > min_null_score else ""
            predictions[example["id"]] = answer
            no_answer_prob = softmax([best_answer["score"], min_null_score])[1]
            no_answer_probs[example["id"]] = float(no_answer_prob)

    if squad_v2:
        return predictions, no_answer_probs
    else:
        return predictions

# %%
final_predictions, na_probs_dict = postprocess_qa_predictions(
    raw_datasets["validation"], validation_features, raw_predictions.predictions, tokenizer, squad_v2=True
)
# Out:
#   0%|          | 0/11873 [00:00<?, ?it/s]

# %%
final_predictions
# Out:
# OrderedDict([('56ddde6b9a695914005b9628', 'France'),
#              ('56ddde6b9a695914005b9629', '10th and 11th centuries'),
#              ('56ddde6b9a695914005b962a', 'Denmark, Iceland and Norway'),
#              ('56ddde6b9a695914005b962b', 'Rollo'),
#              ('56ddde6b9a695914005b962c', '10th century'),
#              ('5ad39d53604f3c001a3fe8d1', ''),
#              ('5ad39d53604f3c001a3fe8d2', ''),
#              ('5ad39d53604f3c001a3fe8d3', ''),
#              ('5ad39d53604f3c001a3fe8d4', ''),
#              ('56dddf4066d3e219004dad5f', 'William the Conqueror'),
#              ('56dddf4066d3e219004dad60', 'Richard I of Normandy'),
#              ('56dddf4066d3e219004dad61', 'Christian'),
#              ('5ad3a266604f3c001a3fea27', ''),
#              ('5ad3a266604f3c001a3fea28', ''),
#              ('5ad3a266604f3c001a3fea29', ''),
#              ('5ad3a266604f3c001a3fea2a', 'Richard I of Normandy'),
#              ('5ad3a266604f3c001a3fea2b', ''),
#              ('56dde0379a695914005b9636', 'Norseman, Viking".'),
#              ('56dde0379a695914005b9637', '9th century'),
#              ('5ad3ab70604f3c001a3feb89', ''),
#              ('5ad3ab70604f3c001a3feb8a', ''),
#              ('56dde0ba66d3e219004dad75', '911'),
#              ('56dde0ba66d3e219004dad76', ''),
#              ('56dde0ba66d3e219004dad77', 'Seine'),
#              ('5ad3ad61604f3c001a3fec0d', ''),
#              ('5ad3ad61604f3c001a3fec0e', ''),
#              ('5ad3ad61604f3c001a3fec0f', ''),
#              ('5ad3ad61604f3c001a3fec10', 'further Viking incursions'),
#              ('56dde1d966d3e219004dad8d', ''),
#              ('5ad3ae14604f3c001a3fec39', ''),
#              ('5ad3ae14604f3c001a3fec3a',
#               'Danes, Norwegians, Norse–Gaels, Orkney Vikings'),
#              ('56dde27d9a695914005b9651', 'Catholicism'),
#              ('56dde27d9a695914005b9652', 'north'),
#              ('5ad3af11604f3c001a3fec63', ''),
#              ('5ad3af11604f3c001a3fec64', ''),
#              ('5ad3af11604f3c001a3fec65', ''),
#              ('56dde2fa66d3e219004dad9b', 'fighting horsemen'),
#              ('5ad3c626604f3c001a3ff011', ''),
#              ('5ad3c626604f3c001a3ff012', 'fighting horsemen'),
#              ('5ad3c626604f3c001a3ff013', ''),
#              ('56de0f6a4396321400ee257f',
#               'Pechenegs, the Bulgars, and especially the Seljuk Turks'),
#              ('5ad3dbc6604f3c001a3ff3e9', ''),
#              ('5ad3dbc6604f3c001a3ff3ea',
#               'the Pechenegs, the Bulgars, and especially the Seljuk Turks'),
#              ('5ad3dbc6604f3c001a3ff3eb', ''),
#              ('5ad3dbc6604f3c001a3ff3ec',
#               'Sicilian campaign of George Maniaces'),
#              ('56de0ffd4396321400ee258d', '1050s'),
#              ('56de0ffd4396321400ee258e', '1060s'),
#              ('56de0ffd4396321400ee258f', 'Alexius Komnenos'),
#              ('5ad3de8b604f3c001a3ff467', 'Hervé'),
#              ('5ad3de8b604f3c001a3ff468', ''),
#              ('5ad3de8b604f3c001a3ff469', ''),
#              ('5ad3de8b604f3c001a3ff46a', ''),
#              ('56de10b44396321400ee2593', 'Afranji'),
#              ('56de10b44396321400ee2594', 'Oursel'),
#              ('56de10b44396321400ee2595', 'Turkish forces'),
#              ('5ad3e96b604f3c001a3ff689', ''),
#              ('5ad3e96b604f3c001a3ff68a', ''),
#              ('5ad3e96b604f3c001a3ff68b', ''),
#              ('5ad3e96b604f3c001a3ff68c',
#               'upper Euphrates valley in northern Syria'),
#              ('56de11154396321400ee25aa', 'Italo-Norman named Raoul'),
#              ('5ad3ea79604f3c001a3ff6e9', 'Byzantine Greece'),
#              ('5ad3ea79604f3c001a3ff6ea', ''),
#              ('5ad3ea79604f3c001a3ff6eb', ''),
#              ('56de148dcffd8e1900b4b5bc', 'Robert Guiscard'),
#              ('56de148dcffd8e1900b4b5bd', 'February 1082'),
#              ('56de148dcffd8e1900b4b5be', '30,000'),
#              ('5ad3ed26604f3c001a3ff799', ''),
#              ('5ad3ed26604f3c001a3ff79a', ''),
#              ('5ad3ed26604f3c001a3ff79b', ''),
#              ('5ad3ed26604f3c001a3ff79c', '30,000'),
#              ('56de15104396321400ee25b7', 'Deabolis'),
#              ('56de15104396321400ee25b8', 'Bohemond'),
#              ('56de15104396321400ee25b9', 'Deabolis'),
#              ('5ad3ee2d604f3c001a3ff7e1', ''),
#              ('5ad3ee2d604f3c001a3ff7e2', ''),
#              ('5ad3ee2d604f3c001a3ff7e3', 'Robert'),
#              ('56de1563cffd8e1900b4b5c2', '1185'),
#              ('56de1563cffd8e1900b4b5c3', 'Dyrrachium'),
#              ('56de1563cffd8e1900b4b5c4', 'Adriatic'),
#              ('5ad3f028604f3c001a3ff823', ''),
#              ('5ad3f028604f3c001a3ff824', 'high Byzantine officials'),
#              ('5ad3f028604f3c001a3ff825', ''),
#              ('56de15dbcffd8e1900b4b5c8', 'King Ethelred II of England'),
#              ('56de15dbcffd8e1900b4b5c9', 'Duke Richard II of Normandy'),
#              ('56de15dbcffd8e1900b4b5ca', 'Normandy'),
#              ('56de15dbcffd8e1900b4b5cb', 'Sweyn Forkbeard'),
#              ('5ad3f187604f3c001a3ff86f', ''),
#              ('5ad3f187604f3c001a3ff870', ''),
#              ('5ad3f187604f3c001a3ff871', ''),
#              ('56de1645cffd8e1900b4b5d0', 'Harthacnut'),
#              ('56de1645cffd8e1900b4b5d1', '1041'),
#              ('56de1645cffd8e1900b4b5d2', 'Robert of Jumièges'),
#              ('5ad3f350604f3c001a3ff8ef', '1041'),
#              ('5ad3f350604f3c001a3ff8f0', ''),
#              ('5ad3f350604f3c001a3ff8f1', ''),
#              ('56de16ca4396321400ee25c5', 'Battle of Hastings'),
#              ('56de16ca4396321400ee25c6', 'Duke William II of Normandy'),
#              ('56de16ca4396321400ee25c7', '1066'),
#              ('56de16ca4396321400ee25c8', 'Anglo-Saxons'),
#              ('5ad3f4b1604f3c001a3ff951', ''),
#              ('5ad3f4b1604f3c001a3ff952', ''),
#              ('5ad3f4b1604f3c001a3ff953', ''),
#              ('5ad3f4b1604f3c001a3ff954', ''),
#              ('56de1728cffd8e1900b4b5d7', 'Modern English'),
#              ('5ad3f5b0604f3c001a3ff9ab', ''),
#              ('5ad3f5b0604f3c001a3ff9ac', ''),
#              ('5ad3f5b0604f3c001a3ff9ad', ''),
#              ('56de179dcffd8e1900b4b5da', '1169'),
#              ('56de179dcffd8e1900b4b5db', 'Irish'),
#              ('56de179dcffd8e1900b4b5dc', 'Irish'),
#              ('5ad3f6f5604f3c001a3ffa09', ''),
#              ('5ad3f6f5604f3c001a3ffa0a', ''),
#              ('5ad3f6f5604f3c001a3ffa0b', ''),
#              ('56de17f9cffd8e1900b4b5e0', ''),
#              ('56de17f9cffd8e1900b4b5e1', 'King Malcolm III'),
#              ('56de17f9cffd8e1900b4b5e2', '1072'),
#              ('56de17f9cffd8e1900b4b5e3', 'his son Duncan'),
#              ('5ad3f7ac604f3c001a3ffa3b', ''),
#              ('5ad3f7ac604f3c001a3ffa3c', ''),
#              ('5ad3f7ac604f3c001a3ffa3d', 'his son Duncan'),
#              ('56de3cd0cffd8e1900b4b6be', 'Sybilla of Normandy'),
#              ('56de3cd0cffd8e1900b4b6bf', 'Normans'),
#              ('5ad3f8d2604f3c001a3ffa8d', ''),
#              ('5ad3f8d2604f3c001a3ffa8e', ''),
#              ('56de3d594396321400ee26ca', 'Hereford'),
#              ('56de3d594396321400ee26cb', 'the Welsh'),
#              ('56de3d594396321400ee26cc', 'Edward the Confessor'),
#              ('5ad3fb01604f3c001a3ffb35', ''),
#              ('5ad3fb01604f3c001a3ffb36', ''),
#              ('56de3dbacffd8e1900b4b6d2', 'the Marches'),
#              ('5ad3fb6e604f3c001a3ffb5f', ''),
#              ('5ad3fb6e604f3c001a3ffb60', ''),
#              ('56de3e414396321400ee26d8', '1018'),
#              ('56de3e414396321400ee26d9', 'William of Montreuil'),
#              ('5ad3fc41604f3c001a3ffb8f', ''),
#              ('5ad3fc41604f3c001a3ffb90', ''),
#              ('5ad3fc41604f3c001a3ffb91', ''),
#              ('5ad3fc41604f3c001a3ffb92', ''),
#              ('56de3ebc4396321400ee26e6', '1097'),
#              ('56de3ebc4396321400ee26e7', 'Tancred'),
#              ('56de3ebc4396321400ee26e8', 'Jerusalem'),
#              ('5ad4017a604f3c001a3ffd1f', ''),
#              ('5ad4017a604f3c001a3ffd20', ''),
#              ('56de3efccffd8e1900b4b6fe', '380 years'),
#              ('5ad401f2604f3c001a3ffd41', ''),
#              ('5ad401f2604f3c001a3ffd42', ''),
#              ('56de3f784396321400ee26fa', 'a storm'),
#              ('56de3f784396321400ee26fb', 'Berengaria'),
#              ('56de3f784396321400ee26fc', '1191'),
#              ('56de3f784396321400ee26fd', 'Isaac Komnenos'),
#              ('5ad40280604f3c001a3ffd57', ''),
#              ('5ad40280604f3c001a3ffd58', ''),
#              ('5ad40280604f3c001a3ffd59', ''),
#              ('56de40da4396321400ee2708', 'Conrad of Montferrat'),
#              ('56de40da4396321400ee2709', 'silver'),
#              ('56de40da4396321400ee270a', 'Guy de Lusignan'),
#              ('5ad404a6604f3c001a3ffde1', ''),
#              ('5ad404a6604f3c001a3ffde2', ''),
#              ('5ad404a6604f3c001a3ffde3', ''),
#              ('56de49564396321400ee277a', 'Africa'),
#              ('5ad40419604f3c001a3ffdb7', ''),
#              ('5ad40419604f3c001a3ffdb8', ''),
#              ('56de49a8cffd8e1900b4b7a7', 'Bethencourt'),
#              ('56de49a8cffd8e1900b4b7a8', 'Enrique Pérez de Guzmán'),
#              ('56de49a8cffd8e1900b4b7a9', 'Maciot de Bethencourt'),
#              ('5ad403c1604f3c001a3ffd97', ''),
#              ('5ad403c1604f3c001a3ffd98', ''),
#              ('56de4a474396321400ee2786', 'Channel Islands'),
#              ('56de4a474396321400ee2787', 'two'),
#              ('5ad40358604f3c001a3ffd7d', ''),
#              ('5ad40358604f3c001a3ffd7e', ''),
#              ('5ad40358604f3c001a3ffd7f', ''),
#              ('56de4a89cffd8e1900b4b7bd', 'Romanesque'),
#              ('56de4a89cffd8e1900b4b7be', 'rounded'),
#              ('5ad402ce604f3c001a3ffd67', 'rounded'),
#              ('56de4b074396321400ee2793', 'Early Gothic'),
#              ('56de4b074396321400ee2794', 'Anglo-Saxon'),
#              ('56de4b074396321400ee2795', 'Sicily'),
#              ('5ad400b0604f3c001a3ffcdf', ''),
#              ('5ad400b0604f3c001a3ffce0', ''),
#              ('5ad400b0604f3c001a3ffce1', ''),
#              ('56de4b5c4396321400ee2799', 'early 11th century'),
#              ('56de4b5c4396321400ee279a', 'the dukes'),
#              ('5ad3ffd7604f3c001a3ffca7', ''),
#              ('5ad3ffd7604f3c001a3ffca8', ''),
#              ('5ad3ffd7604f3c001a3ffca9', ''),
#              ('5ad3ffd7604f3c001a3ffcaa', ''),
#              ('56de4bb84396321400ee27a2', '16th century'),
#              ('5ad3ff1b604f3c001a3ffc73', ''),
#              ('5ad3ff1b604f3c001a3ffc74', ''),
#              ('56de4c324396321400ee27ab', 'embroidery'),
#              ('56de4c324396321400ee27ac', 'Bayeux Tapestry'),
#              ('56de4c324396321400ee27ad', 'Odo'),
#              ('5ad3fe91604f3c001a3ffc47', ''),
#              ('5ad3fe91604f3c001a3ffc48', ''),
#              ('56de51244396321400ee27ef', 'mosaics'),
#              ('5ad3fe0d604f3c001a3ffc1b', ''),
#              ('5ad3fe0d604f3c001a3ffc1c', ''),
#              ('5ad3fe0d604f3c001a3ffc1d', ''),
#              ('56de51c64396321400ee27f7', '11th century'),
#              ('56de51c64396321400ee27f8',
#               'William of Volpiano and John of Ravenna'),
#              ('5ad3fd68604f3c001a3ffbe7', ''),
#              ('5ad3fd68604f3c001a3ffbe8', 'musical production and education'),
#              ('56de52614396321400ee27fb', 'southern Italy'),
#              ('56de52614396321400ee27fc', "Sant'Eufemia"),
#              ('56de52614396321400ee27fd', 'Robert Guiscard'),
#              ('56de52614396321400ee27fe', 'singing'),
#              ('5ad3fccf604f3c001a3ffbb5', ''),
#              ('56e16182e3433e1400422e28', 'Computational complexity theory'),
#              ('56e16182e3433e1400422e29', 'inherent difficulty'),
#              ('56e16182e3433e1400422e2a', 'A computational problem'),
#              ('5ad5316b5b96ef001a10ab72', ''),
#              ('5ad5316b5b96ef001a10ab73', 'Computational complexity theory'),
#              ('5ad5316b5b96ef001a10ab74', ''),
#              ('5ad5316b5b96ef001a10ab75', ''),
#              ('5ad5316b5b96ef001a10ab76', ''),
#              ('56e16839cd28a01900c67887', 'significant resources'),
#              ('56e16839cd28a01900c67888', ''),
#              ('56e16839cd28a01900c67889', 'time and storage'),
#              ('56e16839cd28a01900c6788a', 'number of gates in a circuit'),
#              ('56e16839cd28a01900c6788b', ''),
#              ('5ad532575b96ef001a10ab7c', ''),
#              ('5ad532575b96ef001a10ab7d', ''),
#              ('5ad532575b96ef001a10ab7e', ''),
#              ('5ad532575b96ef001a10ab7f', ''),
#              ('5ad532575b96ef001a10ab80', ''),
#              ('56e17644e3433e1400422f40',
#               'analysis of algorithms and computability theory'),
#              ('56e17644e3433e1400422f41', ''),
#              ('56e17644e3433e1400422f42', 'computational complexity theory'),
#              ('56e17644e3433e1400422f43', 'analysis of algorithms'),
#              ('5ad5344b5b96ef001a10ab86', ''),
#              ('5ad5344b5b96ef001a10ab87', ''),
#              ('5ad5344b5b96ef001a10ab88', ''),
#              ('5ad5344b5b96ef001a10ab89', ''),
#              ('5ad5344b5b96ef001a10ab8a', ''),
#              ('56e17a7ccd28a01900c679a1', 'problem instance'),
#              ('56e17a7ccd28a01900c679a2', 'a problem'),
#              ('56e17a7ccd28a01900c679a3', 'concrete'),
#              ('56e17a7ccd28a01900c679a4', 'problem instance'),
#              ('56e17a7ccd28a01900c679a5', 'solution'),
#              ('5ad5364c5b96ef001a10ab90', ''),
#              ('5ad5364c5b96ef001a10ab91', ''),
#              ('5ad5364c5b96ef001a10ab92', ''),
#              ('5ad5364c5b96ef001a10ab93', ''),
#              ('5ad5364c5b96ef001a10ab94', ''),
#              ('56e17e6ee3433e1400422f7f', '2000'),
#              ('56e17e6ee3433e1400422f80',
#               "Is there a route of at most 2000 kilometres passing through all of Germany's 15 largest cities"),
#              ('56e17e6ee3433e1400422f81', 'computational problems'),
#              ('5ad537a15b96ef001a10ab9a', ''),
#              ('5ad537a15b96ef001a10ab9b', ''),
#              ('5ad537a15b96ef001a10ab9c', ''),
#              ('5ad537a15b96ef001a10ab9d', ''),
#              ('56e181d9e3433e1400422fa0', 'a problem instance'),
#              ('56e181d9e3433e1400422fa1', 'binary alphabet'),
#              ('56e181d9e3433e1400422fa2', 'bitstrings'),
#              ('56e181d9e3433e1400422fa3', 'binary notation'),
#              ('56e181d9e3433e1400422fa4',
#               'directly via their adjacency matrices, or by encoding their adjacency lists in binary'),
#              ('5ad5391e5b96ef001a10aba2', ''),
#              ('5ad5391e5b96ef001a10aba3', ''),
#              ('5ad5391e5b96ef001a10aba4', ''),
#              ('5ad5391e5b96ef001a10aba5', ''),
#              ('5ad5391e5b96ef001a10aba6', ''),
#              ('56e190bce3433e1400422fc8', 'Decision problems'),
#              ('56e190bce3433e1400422fc9', '1 or 0'),
#              ('56e190bce3433e1400422fca', '1 or 0'),
#              ('56e190bce3433e1400422fcb', 'yes'),
#              ('56e190bce3433e1400422fcc', 'yes'),
#              ('5ad53b9d5b96ef001a10abc8', ''),
#              ('5ad53b9d5b96ef001a10abc9', ''),
#              ('5ad53b9d5b96ef001a10abca', ''),
#              ('5ad53b9d5b96ef001a10abcb', ''),
#              ('5ad53b9d5b96ef001a10abcc', 'yes'),
#              ('56e19557e3433e1400422fee', 'arbitrary'),
#              ('56e19557e3433e1400422ff0', 'formal language'),
#              ('56e19557e3433e1400422ff1',
#               'how graphs are encoded as binary strings'),
#              ('5ad53d705b96ef001a10abd2', ''),
#              ('5ad53d705b96ef001a10abd3', ''),
#              ('5ad53d705b96ef001a10abd4', ''),
#              ('5ad53d705b96ef001a10abd5', ''),
#              ('56e19724cd28a01900c679f6', 'computational problem'),
#              ('56e19724cd28a01900c679f7', 'a single'),
#              ('56e19724cd28a01900c679f8', 'function problem'),
#              ('56e19724cd28a01900c679f9', 'integer factorization problem'),
#              ('56e19724cd28a01900c679fa', 'complex'),
#              ('5ad53e615b96ef001a10abda', ''),
#              ('5ad53e615b96ef001a10abdb', ''),
#              ('5ad53e615b96ef001a10abdc', ''),
#              ('5ad53e615b96ef001a10abdd', ''),
#              ('5ad53e615b96ef001a10abde', 'complex'),
#              ('56e1a0dccd28a01900c67a2e', 'decision problems'),
#              ('56e1a0dccd28a01900c67a2f', 'triples'),
#              ('5ad53f815b96ef001a10abe4', ''),
#              ('5ad53f815b96ef001a10abe5', ''),
#              ('5ad53f815b96ef001a10abe6', ''),
#              ('56e1a38de3433e140042305c', 'size of the instance'),
#              ('56e1a38de3433e140042305d', 'the instance'),
#              ('56e1a38de3433e140042305e',
#               'as a function of the size of the instance'),
#              ('56e1a38de3433e140042305f', 'bits'),
#              ('56e1a38de3433e1400423060', 'input size'),
#              ('5ad541ad5b96ef001a10abea', ''),
#              ('5ad541ad5b96ef001a10abeb', ''),
#              ('5ad541ad5b96ef001a10abec', ''),
#              ('5ad541ad5b96ef001a10abed', ''),
#              ('5ad541ad5b96ef001a10abee', ''),
#              ('56e1a564cd28a01900c67a48', 'Cobham'),
#              ('56e1a564cd28a01900c67a49', 'the time taken'),
#              ('56e1a564cd28a01900c67a4a', ''),
#              ('56e1a564cd28a01900c67a4b', ''),
#              ('56e1a564cd28a01900c67a4c', 'polynomial time algorithm'),
#              ('5ad542db5b96ef001a10abf4', ''),
#              ('5ad542db5b96ef001a10abf5', ''),
#              ('5ad542db5b96ef001a10abf6', ''),
#              ('5ad542db5b96ef001a10abf7', ''),
#              ('5ad542db5b96ef001a10abf8', ''),
#              ('56e1aba0e3433e1400423094', 'A Turing machine'),
#              ('56e1aba0e3433e1400423095', 'an algorithm'),
#              ('56e1aba0e3433e1400423097', 'Turing machine'),
#              ('56e1aba0e3433e1400423098', 'symbols'),
#              ('5ad543c05b96ef001a10abfe', ''),
#              ('5ad543c05b96ef001a10abff', ''),
#              ('5ad543c05b96ef001a10ac00', ''),
#              ('5ad543c05b96ef001a10ac01', ''),
#              ('56e1aff7cd28a01900c67a68', 'deterministic Turing machine'),
#              ('56e1aff7cd28a01900c67a69', 'a fixed set of rules'),
#              ('56e1aff7cd28a01900c67a6a', 'probabilistic Turing machine'),
#              ('56e1aff7cd28a01900c67a6b', 'non-deterministic Turing machine'),
#              ('56e1aff7cd28a01900c67a6c', 'randomized algorithms'),
#              ('5ad546c75b96ef001a10ac0e', ''),
#              ('5ad546c75b96ef001a10ac0f', ''),
#              ('5ad546c75b96ef001a10ac10', ''),
#              ('5ad546c75b96ef001a10ac11', ''),
#              ('5ad546c75b96ef001a10ac12', ''),
#              ('56e1b00ce3433e140042309e', 'complexity classes'),
#              ('56e1b00ce3433e140042309f', 'time or space) are bounded'),
#              ('56e1b00ce3433e14004230a1',
#               'symmetric Turing machines and alternating Turing machines'),
#              ('5ad545545b96ef001a10ac06', ''),
#              ('5ad545545b96ef001a10ac07',
#               'resources (such as time or space) are bounded'),
#              ('5ad545545b96ef001a10ac08', ''),
#              ('5ad545545b96ef001a10ac09', ''),
#              ('56e1b169cd28a01900c67a72', 'random access machines'),
#              ('56e1b169cd28a01900c67a73', ''),
#              ('56e1b169cd28a01900c67a74', 'time and memory'),
#              ('56e1b169cd28a01900c67a75',
#               'the machines operate deterministically'),
#              ('5ad547945b96ef001a10ac18', ''),
#              ('5ad547945b96ef001a10ac19', 'time and memory consumption'),
#              ('5ad547945b96ef001a10ac1a', ''),
#              ('5ad547945b96ef001a10ac1b', ''),
#              ('56e1b355e3433e14004230b0', 'non-deterministic'),
#              ('56e1b355e3433e14004230b1', 'more unusual resources'),
#              ('56e1b355e3433e14004230b2', 'mathematical models'),
#              ('56e1b355e3433e14004230b3', 'time'),
#              ('5ad5489b5b96ef001a10ac2a', ''),
#              ('5ad5489b5b96ef001a10ac2b', ''),
#              ('5ad5489b5b96ef001a10ac2c', ''),
#              ('5ad5489b5b96ef001a10ac2d', ''),
#              ('5ad5489b5b96ef001a10ac2e', ''),
#              ('56e1b62ecd28a01900c67aa3',
#               'the total number of state transitions'),
#              ('56e1b62ecd28a01900c67aa4', 'difficulty'),
#              ('56e1b62ecd28a01900c67aa5', 'DTIME(f(n)).'),
#              ('56e1b62ecd28a01900c67aa6', 'time and space'),
#              ('5ad54a375b96ef001a10ac48', ''),
#              ('5ad54a375b96ef001a10ac49', ''),
#              ('5ad54a375b96ef001a10ac4a', 'DTIME(f(n)).'),
#              ('5ad54a375b96ef001a10ac4b', ''),
#              ('5ad54a375b96ef001a10ac4c', ''),
#              ('56e1b754cd28a01900c67abc', 'complexity'),
#              ('56e1b754cd28a01900c67abd', 'computational'),
#              ('56e1b754cd28a01900c67abe', 'Blum complexity axioms'),
#              ('56e1b754cd28a01900c67abf',
#               'Complexity measures are very generally defined by the Blum complexity axioms. Other complexity'),
#              ('56e1b754cd28a01900c67ac0', 'complexity'),
#              ('5ad54b035b96ef001a10ac52', ''),
#              ('5ad54b035b96ef001a10ac53', ''),
#              ('5ad54b035b96ef001a10ac54', ''),
#              ('5ad54b035b96ef001a10ac55', ''),
#              ('5ad54b035b96ef001a10ac56', ''),
#              ('56e1b8f3e3433e14004230e6', 'best, worst and average'),
#              ('56e1b8f3e3433e14004230e7', ''),
#              ('56e1b8f3e3433e14004230e8', ''),
#              ('56e1b8f3e3433e14004230e9', ''),
#              ('5ad54c2f5b96ef001a10ac5c', 'best, worst and average'),
#              ('5ad54c2f5b96ef001a10ac5d', ''),
#              ('5ad54c2f5b96ef001a10ac5e', ''),
#              ('5ad54c2f5b96ef001a10ac5f', ''),
#              ('56e1ba41cd28a01900c67ae0', 'quicksort'),
#              ('56e1ba41cd28a01900c67ae1', 'worst-case'),
#              ('56e1ba41cd28a01900c67ae2', 'O(n2)'),
#              ('5ad54d625b96ef001a10ac64', ''),
#              ('5ad54d625b96ef001a10ac65', ''),
#              ('5ad54d625b96ef001a10ac66', ''),
#              ('5ad54d625b96ef001a10ac67', ''),
#              ('5ad54d625b96ef001a10ac68', ''),
#              ('56e1bc3ae3433e1400423104',
#               'the most efficient algorithm solving a given problem'),
#              ('56e1bc3ae3433e1400423105', 'analysis of algorithms'),
#              ('56e1bc3ae3433e1400423106', 'lower bounds'),
#              ('56e1bc3ae3433e1400423107', ''),
#              ('56e1bc3ae3433e1400423108', ''),
#              ('5ad54e7c5b96ef001a10ac76',
#               'one is interested in proving upper and lower bounds on the minimum amount of time required by the most efficient algorithm solving a given problem'),
#              ('5ad54e7c5b96ef001a10ac77', ''),
#              ('5ad54e7c5b96ef001a10ac78', ''),
#              ('5ad54e7c5b96ef001a10ac79', ''),
#              ('5ad54e7c5b96ef001a10ac7a', ''),
#              ('56e1bd4acd28a01900c67afc', 'big O notation'),
#              ('56e1bd4acd28a01900c67afd',
#               'constant factors and smaller terms'),
#              ('56e1bd4acd28a01900c67afe', 'T(n) = O(n2).'),
#              ('56e1bd4acd28a01900c67aff',
#               'specific details of the computational model used'),
#              ('5ad54f775b96ef001a10ac88', ''),
#              ('5ad54f775b96ef001a10ac89', ''),
#              ('5ad54f775b96ef001a10ac8a', ''),
#              ('5ad54f775b96ef001a10ac8b', ''),
#              ('56e1c0f6cd28a01900c67b2c', 'complexity classes'),
#              ('56e1c0f6cd28a01900c67b2d', ''),
#              ('56e1c0f6cd28a01900c67b2e', 'complicated definitions'),
#              ('5ad5501f5b96ef001a10ac90', ''),
#              ('5ad5501f5b96ef001a10ac91', ''),
#              ('5ad5501f5b96ef001a10ac92', ''),
#              ('5ad5501f5b96ef001a10ac93', ''),
#              ('56e1c2eee3433e1400423134', 'the chosen machine model'),
#              ('56e1c2eee3433e1400423135', 'linear'),
#              ('56e1c2eee3433e1400423136', 'single-tape'),
#              ('56e1c2eee3433e1400423137', 'Cobham-Edmonds thesis'),
#              ('56e1c2eee3433e1400423138', 'P'),
#              ('5ad55ee35b96ef001a10ace4', ''),
#              ('5ad55ee35b96ef001a10ace5', ''),
#              ('5ad55ee35b96ef001a10ace6', ''),
#              ('5ad55ee35b96ef001a10ace7', ''),
#              ('5ad55ee35b96ef001a10ace8', ''),
#              ('56e1c3e1e3433e1400423148', 'time or space'),
#              ('56e1c3e1e3433e1400423149', ''),
#              ('56e1c3e1e3433e140042314a', 'complexity classes'),
#              ('5ad55fe75b96ef001a10ad0c', ''),
#              ('5ad55fe75b96ef001a10ad0d', 'time or space'),
#              ('5ad55fe75b96ef001a10ad0e', ''),
#              ('5ad55fe75b96ef001a10ad0f', ''),
#              ('56e1c4fce3433e140042314e', 'BPP, ZPP and RP'),
#              ('56e1c4fce3433e140042314f', 'Boolean circuits'),
#              ('56e1c4fce3433e1400423150', 'quantum'),
#              ('56e1c4fce3433e1400423151', '#P'),
#              ('56e1c4fce3433e1400423152', 'Interactive'),
#              ('5ad560b85b96ef001a10ad1e', 'BPP, ZPP and RP'),
#              ('5ad560b85b96ef001a10ad1f', ''),
#              ('5ad560b85b96ef001a10ad20', ''),
#              ('5ad560b85b96ef001a10ad21', ''),
#              ('5ad560b85b96ef001a10ad22', ''),
#              ('56e1c720e3433e140042316a', 'computation time'),
#              ('56e1c720e3433e140042316b', 'DTIME(n2'),
#              ('56e1c720e3433e140042316c', 'time and space hierarchy theorems'),
#              ('56e1c720e3433e140042316d', 'a proper hierarchy'),
#              ('56e1c720e3433e140042316e', 'quantitative'),
#              ('5ad561c85b96ef001a10ad3c', ''),
#              ('5ad561c85b96ef001a10ad3d', ''),
#              ('5ad561c85b96ef001a10ad3e', ''),
#              ('5ad561c85b96ef001a10ad3f', ''),
#              ('5ad561c85b96ef001a10ad40', ''),
#              ('56e1c7e2cd28a01900c67b74',
#               'The time and space hierarchy theorems'),
#              ('56e1c7e2cd28a01900c67b75', 'EXPTIME'),
#              ('56e1c7e2cd28a01900c67b76', 'PSPACE'),
#              ('5ad562525b96ef001a10ad50', ''),
#              ('5ad562525b96ef001a10ad51', ''),
#              ('5ad562525b96ef001a10ad52', ''),
#              ('5ad562525b96ef001a10ad53', ''),
#              ('56e1c9bfe3433e1400423192', 'a reduction'),
#              ('56e1c9bfe3433e1400423193', 'another problem'),
#              ('56e1c9bfe3433e1400423194', 'reduces to Y'),
#              ('56e1c9bfe3433e1400423195',
#               'Cook reductions, Karp reductions and Levin reductions'),
#              ('56e1c9bfe3433e1400423196',
#               'bound on the complexity of reductions'),
#              ('5ad5632f5b96ef001a10ad6c', ''),
#              ('5ad5632f5b96ef001a10ad6d', ''),
#              ('5ad5632f5b96ef001a10ad6e', ''),
#              ('5ad5632f5b96ef001a10ad6f', ''),
#              ('5ad5632f5b96ef001a10ad70', ''),
#              ('56e1cbe2cd28a01900c67bac', 'polynomial-time reduction'),
#              ('56e1cbe2cd28a01900c67bad', 'multiplying two integers'),
#              ('56e1cbe2cd28a01900c67bae', 'polynomial'),
#              ('56e1cbe2cd28a01900c67baf',
#               'giving the same input to both inputs'),
#              ('56e1cbe2cd28a01900c67bb0', 'multiplication'),
#              ('5ad5648b5b96ef001a10ad94', ''),
#              ('5ad5648b5b96ef001a10ad95', ''),
#              ('5ad5648b5b96ef001a10ad96', ''),
#              ('5ad5648b5b96ef001a10ad97', ''),
#              ('5ad5648b5b96ef001a10ad98', ''),
#              ('56e1ce08e3433e14004231a4', 'the type of reduction being used'),
#              ('56e1ce08e3433e14004231a5',
#               'every problem in C can be reduced to X'),
#              ('56e1ce08e3433e14004231a6', 'solve any problem in C'),
#              ('56e1ce08e3433e14004231a8', 'NP-hard problems'),
#              ('5ad565575b96ef001a10adb2', ''),
#              ('5ad565575b96ef001a10adb3', ''),
#              ('5ad565575b96ef001a10adb4', ''),
#              ('5ad565575b96ef001a10adb5', ''),
#              ('56e1d9fee3433e14004231cb', 'NP-complete problems'),
#              ('56e1d9fee3433e14004231cc', ''),
#              ('56e1d9fee3433e14004231cd',
#               'there is no known polynomial-time solution'),
#              ('56e1d9fee3433e14004231ce', 'NP'),
#              ('5ad566375b96ef001a10adce', ''),
#              ('5ad566375b96ef001a10adcf', ''),
#              ('5ad566375b96ef001a10add0', ''),
#              ('5ad566375b96ef001a10add1', ''),
#              ('56e1dc62cd28a01900c67bca', 'P'),
#              ('56e1dc62cd28a01900c67bcb', 'Cobham–Edmonds thesis'),
#              ('56e1dc62cd28a01900c67bcc', 'NP'),
#              ('56e1dc62cd28a01900c67bcd',
#               'Boolean satisfiability problem, the Hamiltonian path problem and the vertex cover problem'),
#              ('56e1dc62cd28a01900c67bce', ''),
#              ('5ad567055b96ef001a10adea', ''),
#              ('5ad567055b96ef001a10adeb', ''),
#              ('5ad567055b96ef001a10adec', ''),
#              ('5ad567055b96ef001a10aded', ''),
#              ('5ad567055b96ef001a10adee', ''),
#              ('56e1ddfce3433e14004231d5', 'more efficient solutions'),
#              ('56e1ddfce3433e14004231d6', 'protein structure prediction'),
#              ('56e1ddfce3433e14004231d8', 'US$1,000,000'),
#              ('5ad568175b96ef001a10ae10', ''),
#              ('5ad568175b96ef001a10ae11', ''),
#              ('5ad568175b96ef001a10ae12', ''),
#              ('5ad568175b96ef001a10ae13', ''),
#              ('5ad568175b96ef001a10ae14', ''),
#              ('56e1ded7cd28a01900c67bd4', 'Ladner'),
#              ('56e1ded7cd28a01900c67bd5', 'NP-intermediate problems'),
#              ('56e1ded7cd28a01900c67bd6',
#               'The graph isomorphism problem, the discrete logarithm problem and the integer factorization problem'),
#              ('5ad568d35b96ef001a10ae1a', ''),
#              ('5ad568d35b96ef001a10ae1b', 'NP-intermediate problems'),
#              ('5ad568d35b96ef001a10ae1c', ''),
#              ('5ad568d35b96ef001a10ae1d', ''),
#              ('56e1e9dfe3433e14004231fc', 'graph isomorphism problem'),
#              ('56e1e9dfe3433e14004231fd', ''),
#              ('56e1e9dfe3433e14004231fe', ''),
#              ('56e1e9dfe3433e14004231ff', 'second level'),
#              ('56e1e9dfe3433e1400423200', 'Laszlo Babai and Eugene Luks'),
#              ('5ad569c05b96ef001a10ae36', ''),
#              ('5ad569c05b96ef001a10ae37', ''),
#              ('5ad569c05b96ef001a10ae38', ''),
#              ('5ad569c05b96ef001a10ae39', ''),
#              ('5ad569c05b96ef001a10ae3a', ''),
#              ('56e1ec83cd28a01900c67c0a', ''),
#              ('56e1ec83cd28a01900c67c0b', 'k'),
#              ('56e1ec83cd28a01900c67c0c', 'RSA algorithm'),
#              ('56e1ec83cd28a01900c67c0e', 'general number field sieve'),
#              ('5ad56aea5b96ef001a10ae48', ''),
#              ('5ad56aea5b96ef001a10ae49', ''),
#              ('5ad56aea5b96ef001a10ae4a', ''),
#              ('5ad56aea5b96ef001a10ae4b', ''),
#              ('5ad56aea5b96ef001a10ae4c', ''),
#              ('56e1ee4de3433e1400423210', 'unequal'),
#              ('56e1ee4de3433e1400423211', 'P = PSPACE'),
#              ('56e1ee4de3433e1400423212', 'between P and PSPACE'),
#              ('56e1ee4de3433e1400423214',
#               'Proving that any of these classes are unequal'),
#              ('5ad56bcd5b96ef001a10ae62', ''),
#              ('5ad56bcd5b96ef001a10ae63', ''),
#              ('5ad56bcd5b96ef001a10ae64', 'between P and PSPACE'),
#              ('5ad56bcd5b96ef001a10ae65', ''),
#              ('5ad56bcd5b96ef001a10ae66', ''),
#              ('56e1efa0e3433e140042321a', 'co-NP'),
#              ('56e1efa0e3433e140042321b', 'reversed'),
#              ('56e1efa0e3433e140042321c', ''),
#              ('56e1efa0e3433e140042321d', 'P is not equal to NP'),
#              ('5ad56c6b5b96ef001a10ae6c', ''),
#              ('5ad56c6b5b96ef001a10ae6d', ''),
#              ('5ad56c6b5b96ef001a10ae6e', ''),
#              ('5ad56c6b5b96ef001a10ae6f', ''),
#              ('56e1f10ee3433e1400423222', 'L'),
#              ('56e1f10ee3433e1400423223', ''),
#              ('56e1f10ee3433e1400423224', 'many complexity classes'),
#              ('56e1f10ee3433e1400423225', ''),
#              ('56e1f10ee3433e1400423226',
#               'if they are distinct or equal classes'),
#              ('5ad56d3e5b96ef001a10ae84', ''),
#              ('5ad56d3e5b96ef001a10ae85', ''),
#              ('5ad56d3e5b96ef001a10ae86', ''),
#              ('5ad56d3e5b96ef001a10ae87', ''),
#              ('5ad56d3e5b96ef001a10ae88', ''),
#              ('56e1fc57e3433e140042322c', 'intractable problems'),
#              ('56e1fc57e3433e140042322f', 'exponential-time'),
#              ('56e1fc57e3433e1400423230', 'NP-complete problems'),
#              ('5ad56e5c5b96ef001a10ae9e', ''),
#              ('5ad56e5c5b96ef001a10ae9f', ''),
#              ('5ad56e5c5b96ef001a10aea0', ''),
#              ('5ad56e5c5b96ef001a10aea1', ''),
#              ('5ad56e5c5b96ef001a10aea2', ''),
#              ('56e1febfe3433e1400423236', 'Presburger arithmetic'),
#              ('56e1febfe3433e1400423237', 'algorithms have been written'),
#              ('56e1febfe3433e1400423238', 'NP-complete knapsack problem'),
#              ('56e1febfe3433e1400423239', 'less than quadratic time'),
#              ('56e1febfe3433e140042323a',
#               'NP-complete Boolean satisfiability problem'),
#              ('5ad56ef05b96ef001a10aea8', 'Presburger arithmetic'),
#              ('5ad56ef05b96ef001a10aea9', ''),
#              ('5ad56ef05b96ef001a10aeaa', ''),
#              ('5ad56ef05b96ef001a10aeab', ''),
#              ('56e200e4cd28a01900c67c14', ''),
#              ('56e200e4cd28a01900c67c15', 'Alan Turing'),
#              ('56e200e4cd28a01900c67c16', 'Turing machines'),
#              ('56e200e4cd28a01900c67c17', '1936'),
#              ('56e200e4cd28a01900c67c18', 'a computer'),
#              ('5ad56fe65b96ef001a10aec2', ''),
#              ('5ad56fe65b96ef001a10aec3', ''),
#              ('5ad56fe65b96ef001a10aec4', ''),
#              ('5ad56fe65b96ef001a10aec5', ''),
#              ('5ad56fe65b96ef001a10aec6', ''),
#              ('56e202e9e3433e1400423240',
#               'On the Computational Complexity of Algorithms'),
#              ('56e202e9e3433e1400423241',
#               'Juris Hartmanis and Richard Stearns'),
#              ('56e202e9e3433e1400423242', '1965'),
#              ('56e202e9e3433e1400423243', 'time and space complexity'),
#              ('56e202e9e3433e1400423244', '1965'),
#              ('5ad570b25b96ef001a10aedc', ''),
#              ('5ad570b25b96ef001a10aedd', ''),
#              ('5ad570b25b96ef001a10aede', ''),
#              ('5ad570b25b96ef001a10aedf', 'time and space complexity'),
#              ('56e2042ecd28a01900c67c1e', 'John Myhill'),
#              ('56e2042ecd28a01900c67c1f', ''),
#              ('56e2042ecd28a01900c67c20', 'Hisao Yamada'),
#              ('5ad5719f5b96ef001a10aeec', ''),
#              ('5ad5719f5b96ef001a10aeed', ''),
#              ('5ad5719f5b96ef001a10aeee', ''),
#              ('5ad5719f5b96ef001a10aeef', ''),
#              ('5ad5719f5b96ef001a10aef0', ''),
#              ('56e20a27cd28a01900c67c24', ''),
#              ('56e20a27cd28a01900c67c25', 'encoding'),
#              ('5ad53ac65b96ef001a10abac', ''),
#              ('5ad53ac65b96ef001a10abad', ''),
#              ('5ad53ac65b96ef001a10abae', ''),
#              ('5ad53ac65b96ef001a10abaf', ''),
#              ('56e20a3ae3433e140042324a', 'Manuel Blum'),
#              ('56e20a3ae3433e140042324b', 'speed-up theorem'),
#              ('56e20a3ae3433e140042324d',
#               'Reducibility Among Combinatorial Problems'),
#              ('56e20a3ae3433e140042324e', '21'),
#              ('5ad572b15b96ef001a10af06', ''),
#              ('5ad572b15b96ef001a10af07', ''),
#              ('5ad572b15b96ef001a10af08', ''),
#              ('5ad572b15b96ef001a10af09', ''),
#              ('5ad572b15b96ef001a10af0a', ''),
#              ('5705e26d75f01819005e76d4', 'SoCal'),
#              ('5705e26d75f01819005e76d5', '10'),
#              ('5705e26d75f01819005e76d6', 'economic center'),
#              ('5705e26d75f01819005e76d7', 'demographics and economic'),
#              ('5705e26d75f01819005e76d8', 'historical political divisions'),
#              ('5ad0178577cf76001a68698a', ''),
#              ('5ad0178577cf76001a68698b', 'Kern and San Luis Obispo counties'),
#              ('5ad0178577cf76001a68698c', ''),
#              ('5705e33f52bb89140068964c',
#               'greater Southern California Megaregion'),
#              ('5705e33f52bb89140068964d', '11'),
#              ('5705e33f52bb89140068964e', 'Nevada'),
#              ('5705e33f52bb89140068964f', 'Mexican'),
#              ('5705e33f52bb891400689650', 'Tijuana'),
#              ('5ad0185a77cf76001a6869b8', ''),
#              ('5ad0185a77cf76001a6869b9', ''),
#              ('5ad0185a77cf76001a6869ba', ''),
#              ('5705e3f252bb89140068966a', 'Pacific'),
#              ('5705e3f252bb89140068966b', 'seven'),
#              ('5705e3f252bb89140068966c', 'over 12 million'),
#              ('5705e3f252bb89140068966d', ''),
#              ('5705e3f252bb89140068966e', 'over 17.5 million'),
#              ('5ad01a6277cf76001a686a0c', '60'),
#              ('5ad01a6277cf76001a686a0d', ''),
#              ('5ad01a6277cf76001a686a0e', 'over four million'),
#              ('5ad01a6277cf76001a686a0f', ''),
#              ('5705e4fe75f01819005e7704', 'Colorado River'),
#              ('5705e4fe75f01819005e7705', 'Colorado Desert'),
#              ('5705e4fe75f01819005e7706', 'Mojave Desert'),
#              ('5705e4fe75f01819005e7707', 'Mexico–United States border'),
#              ('5ad01c8877cf76001a686a64', ''),
#              ('5ad01c8877cf76001a686a65', ''),
#              ('5ad01c8877cf76001a686a66', ''),
#              ('5705e63175f01819005e7720', 'southern California'),
#              ('5705e63175f01819005e7721', '3,792,621'),
#              ('5705e63175f01819005e7722', 'Los Angeles'),
#              ('5705e63175f01819005e7723', 'San Diego'),
#              ('5705e63175f01819005e7724', 'south'),
#              ('5ad01e4677cf76001a686aa6', 'Los Angeles and San Diego'),
#              ('5ad01e4677cf76001a686aa7', ''),
#              ('5ad01e4677cf76001a686aa8', ''),
#              ('5ad01e4677cf76001a686aa9', ''),
#              ('5705e99452bb891400689688', ''),
#              ('5705e99452bb891400689689', 'United States'),
#              ('5705e99452bb89140068968a', 'counties'),
#              ('5705e99452bb89140068968b', ''),
#              ('5705e99452bb89140068968c', ''),
#              ('5ad01f0f77cf76001a686ac2', ''),
#              ('5ad01f0f77cf76001a686ac3', '15'),
#              ('5ad01f0f77cf76001a686ac4', ''),
#              ('5705eb3375f01819005e7764', 'Hollywood'),
#              ('5705eb3375f01819005e7765', 'Los Angeles'),
#              ('5705eb3375f01819005e7766', 'The Walt Disney Company'),
#              ('5705eb3375f01819005e7767', 'music'),
#              ('5705eb3375f01819005e7768', 'Sony'),
#              ('5ad0206677cf76001a686afa', ''),
#              ('5ad0206677cf76001a686afb', ''),
#              ('5ad0206677cf76001a686afc', ''),
#              ('5ad0206677cf76001a686afd',
#               'The Walt Disney Company (which also owns ABC), Sony Pictures, Universal, MGM, Paramount Pictures, 20th Century Fox, and Warner Brothers'),
#              ('5705ec1675f01819005e776e', 'skateboard'),
#              ('5705ec1675f01819005e776f', 'Tony Hawk'),
#              ('5705ec1675f01819005e7770', 'Shaun White'),
#              ('5705ec1675f01819005e7771', 'Oahu'),
#              ('5705ec1675f01819005e7772', 'Transpacific Yacht Race'),
#              ('5ad0220a77cf76001a686b2a', ''),
#              ('5ad0220a77cf76001a686b2b', 'professional surfers'),
#              ('5ad0220a77cf76001a686b2c', ''),
#              ('5ad0220a77cf76001a686b2d', ''),
#              ('5ad0220a77cf76001a686b2e', ''),
#              ('5705eccb52bb8914006896b8', 'Palm Springs'),
#              ('5705eccb52bb8914006896b9', 'popular beaches'),
#              ('5705eccb52bb8914006896ba', 'desert'),
#              ('5705eccb52bb8914006896bb', 'nearby open spaces'),
#              ('5ad0228a77cf76001a686b58', 'locals and tourists'),
#              ('5ad0228a77cf76001a686b59', ''),
#              ('5ad0228a77cf76001a686b5a', ''),
#              ('5705edcd52bb8914006896ca', '37° 9\' 58.23"'),
#              ('5705edcd52bb8914006896cb', '11'),
#              ('5705edcd52bb8914006896cc', 'ten'),
#              ('5705edcd52bb8914006896cd', 'Tehachapi Mountains'),
#              ('5705edcd52bb8914006896ce', 'northern'),
#              ('5ad0297e77cf76001a686c3a', ''),
#              ('5ad0297e77cf76001a686c3b', ''),
#              ('5ad0297e77cf76001a686c3c', ''),
#              ('5ad0297e77cf76001a686c3d', ''),
#              ('5705eee952bb8914006896de', 'Mexico'),
#              ('5705eee952bb8914006896df', 'Alta California'),
#              ('5705eee952bb8914006896e0', 'Monterey'),
#              ('5705eee952bb8914006896e1', 'Compromise of 1850'),
#              ('5705eee952bb8914006896e2', 'free'),
#              ('5ad02cde77cf76001a686cc6', ''),
#              ('5ad02cde77cf76001a686cc7', ''),
#              ('5ad02cde77cf76001a686cc8', ''),
#              ('5ad02cde77cf76001a686cc9', ''),
#              ('5705f09e75f01819005e77a4', 'inequitable taxes'),
#              ('5705f09e75f01819005e77a5', 'Cow Counties'),
#              ('5705f09e75f01819005e77a6', 'three'),
#              ('5705f09e75f01819005e77a7', '75%'),
#              ('5705f09e75f01819005e77a8', 'Milton Latham'),
#              ('5ad02e5d77cf76001a686d3a', ''),
#              ('5ad02e5d77cf76001a686d3b', ''),
#              ('5ad02e5d77cf76001a686d3c', ''),
#              ('5ad02e5d77cf76001a686d3d', ''),
#              ('5ad02e5d77cf76001a686d3e', ''),
#              ('5705f13d52bb8914006896f0', 'Los Angeles Times'),
#              ('5705f13d52bb8914006896f1', '1900'),
#              ('5705f13d52bb8914006896f2', '1999'),
#              ('5705f13d52bb8914006896f3', 'Imperial'),
#              ('5705f13d52bb8914006896f4', 'seven'),
#              ('5ad02ee077cf76001a686d58', ''),
#              ('5ad02ee077cf76001a686d59', ''),
#              ('5ad02ee077cf76001a686d5a', ''),
#              ('5705f36452bb891400689718', 'regional tourism groups'),
#              ('5705f36452bb891400689719',
#               'California State Automobile Association'),
#              ('5705f36452bb89140068971a', 'three-region'),
#              ('5705f36452bb89140068971b', 'South of the Tehachapis'),
#              ('5705f36452bb89140068971c', 'southern California region'),
#              ('5ad02ff177cf76001a686da2', 'AAA Auto Clubs'),
#              ('5ad02ff177cf76001a686da3', 'AAA Auto Clubs'),
#              ('5ad02ff177cf76001a686da4', ''),
#              ('5ad02ff177cf76001a686da5', 'regional tourism groups'),
#              ('5705f7c875f01819005e77dc', 'third'),
#              ('5705f7c875f01819005e77dd', 'vast areas'),
#              ('5705f7c875f01819005e77de', 'use of automobiles and highways'),
#              ('5705f7c875f01819005e77df', 'highways'),
#              ('5705f7c875f01819005e77e0', 'international metropolitan region'),
#              ('5ad0316a77cf76001a686de4',
#               'Great Lakes Megalopolis and the Northeastern megalopolis'),
#              ('5ad0316a77cf76001a686de5', ''),
#              ('5ad0316a77cf76001a686de6', ''),
#              ('5705fb7f52bb891400689750', 'Camp Pendleton'),
#              ('5705fb7f52bb891400689751', 'Inland Empire'),
#              ('5705fb7f52bb891400689752', ''),
#              ('5705fb7f52bb891400689753', 'Orange Counties'),
#              ('5705fb7f52bb891400689754', '1990s'),
#              ('5ad0331877cf76001a686e16', ''),
#              ('5ad0331877cf76001a686e17', 'L.A. and Orange Counties'),
#              ('5ad0331877cf76001a686e18', ''),
#              ('5ad0331877cf76001a686e19', 'Santa Maria and San Luis Obispo'),
#              ('5705fc3a52bb89140068976a', 'Mediterranean'),
#              ('5705fc3a52bb89140068976b', 'infrequent rain'),
#              ('5705fc3a52bb89140068976c', "90-60's"),
#              ('5705fc3a52bb89140068976d', 'very rare'),
#              ('5705fc3a52bb89140068976e', "70-50's"),
#              ('5ad0381a77cf76001a686e30', 'Mediterranean'),
#              ('5ad0381a77cf76001a686e31', ''),
#              ('5ad0381a77cf76001a686e32', ''),
#              ('5ad0381a77cf76001a686e33', ''),
#              ('5705fd8475f01819005e7840',
#               'geologic, topographic, and natural ecosystem'),
#              ('5705fd8475f01819005e7841', 'Pacific Ocean'),
#              ('5705fd8475f01819005e7842', 'topographic'),
#              ('5705fd8475f01819005e7843', 'Peninsular Ranges'),
#              ('5705fd8475f01819005e7844', 'interior valleys'),
#              ('5ad0394877cf76001a686e56', ''),
#              ('5ad0394877cf76001a686e57', ''),
#              ('5ad0394877cf76001a686e58', ''),
#              ('5ad0394877cf76001a686e59', 'Southern California'),
#              ('5705fec152bb89140068977a', '10,000'),
#              ('5705fec152bb89140068977b', 'small'),
#              ('5705fec152bb89140068977c', '6.7'),
#              ('5705fec152bb89140068977d', 'property damage'),
#              ('5705fec152bb89140068977e', 'over $20 billion'),
#              ('5ad03c7377cf76001a686ebc', ''),
#              ('5ad03c7377cf76001a686ebd', ''),
#              ('5ad03c7377cf76001a686ebe', '10,000'),
#              ('5ad03c7377cf76001a686ebf', ''),
#              ('5705ffde52bb891400689784', 'San Andreas Fault'),
#              ('5705ffde52bb891400689785', '6.7+'),
#              ('5705ffde52bb891400689786', 'Puente Hills Fault'),
#              ('5705ffde52bb891400689787', 'The USGS'),
#              ('5705ffde52bb891400689788', 'occurrence'),
#              ('5ad03d2277cf76001a686ecc', ''),
#              ('5ad03d2277cf76001a686ecd',
#               'San Jacinto Fault, the Puente Hills Fault, and the Elsinore Fault Zone'),
#              ('5ad03d2277cf76001a686ece', ''),
#              ('5ad03d2277cf76001a686ecf', ''),
#              ('570602fa52bb89140068979e', 'economically'),
#              ('570602fa52bb89140068979f', 'global'),
#              ('570602fa52bb8914006897a0', 'economic'),
#              ('5ad0410977cf76001a686efe', ''),
#              ('5ad0410977cf76001a686eff',
#               'the hub of economic activity for its respective region and being home to many tourist destinations'),
#              ('5ad0410977cf76001a686f00', ''),
#              ('570603c475f01819005e7882', '2010'),
#              ('570603c475f01819005e7883', 'high growth rates'),
#              ('570603c475f01819005e7884', '10.0%'),
#              ('570603c475f01819005e7885', ''),
#              ('570603c475f01819005e7886', 'Greater Sacramento'),
#              ('5ad0421177cf76001a686f14', ''),
#              ('5ad0421177cf76001a686f15', ''),
#              ('5ad0421177cf76001a686f16', ''),
#              ('5ad0421177cf76001a686f17', ''),
#              ('5706074552bb8914006897d4', 'Metropolitan Statistical Areas'),
#              ('5706074552bb8914006897d5', 'two'),
#              ('5706074552bb8914006897d6', 'five million'),
#              ('5706074552bb8914006897d7', 'Southern Border Region'),
#              ('5706074552bb8914006897d8', '17,786,419'),
#              ('5ad042cf77cf76001a686f24', ''),
#              ('5ad042cf77cf76001a686f25', ''),
#              ('5ad042cf77cf76001a686f26', ''),
#              ('5ad042cf77cf76001a686f27', ''),
#              ('5ad042cf77cf76001a686f28', ''),
#              ('570607f575f01819005e78b4', 'Los Angeles'),
#              ('570607f575f01819005e78b5', '1.3 million'),
#              ('570607f575f01819005e78b6', 'twelve'),
#              ('570607f575f01819005e78b7', '100,000'),
#              ('570607f575f01819005e78b8', 'Riverside'),
#              ('5ad0440877cf76001a686f3e', ''),
#              ('5ad0440877cf76001a686f3f', ''),
#              ('5ad0440877cf76001a686f40', ''),
#              ('5ad0440877cf76001a686f41', ''),
#              ('5ad0440877cf76001a686f42', ''),
#              ('5706094b52bb8914006897de', 'petroleum'),
#              ('5706094b52bb8914006897df', 'Hollywood'),
#              ('5706094b52bb8914006897e0', 'housing bubble'),
#              ('5706094b52bb8914006897e1', 'diverse'),
#              ('5706094b52bb8914006897e2', 'heavily impacted'),
#              ('5ad044f077cf76001a686f58', ''),
#              ('5ad044f077cf76001a686f59', ''),
#              ('5ad044f077cf76001a686f5a', 'abundance of petroleum'),
#              ('5ad044f077cf76001a686f5b', ''),
#              ('57060a1175f01819005e78d2', '1920s'),
#              ('57060a1175f01819005e78d3', 'richest'),
#              ('57060a1175f01819005e78d4', 'cattle'),
#              ('57060a1175f01819005e78d5', 'citrus'),
#              ('57060a1175f01819005e78d6', 'aerospace'),
#              ('5ad0458b77cf76001a686f72', ''),
#              ('5ad0458b77cf76001a686f73', ''),
#              ('5ad0458b77cf76001a686f74', ''),
#              ('5ad0458b77cf76001a686f75', ''),
#              ('57060a6e52bb8914006897f8', 'major business districts'),
#              ('57060a6e52bb8914006897f9', 'Central business districts'),
#              ('57060a6e52bb8914006897fa', ''),
#              ('5ad0461477cf76001a686f7a', 'Central business districts'),
#              ('5ad0461477cf76001a686f7b',
#               'Downtown Los Angeles, Downtown San Diego, Downtown San Bernardino, Downtown Bakersfield, South Coast Metro and Downtown Riverside'),
#              ('5ad0461477cf76001a686f7c', ''),
#              ('57060cc352bb89140068980e', 'business districts'),
#              ('57060cc352bb89140068980f', 'Los Angeles Area'),
#              ('57060cc352bb891400689810', 'San Fernando Valley'),
#              ('57060cc352bb891400689811', 'Los Angeles'),
#              ('5ad0470477cf76001a686f80',
#               'Downtown Burbank, Downtown Santa Monica, Downtown Glendale and Downtown Long Beach'),
#              ('5ad0470477cf76001a686f81',
#               'Downtown Los Angeles central business district'),
#              ('5ad0470477cf76001a686f82',
#               'Century City, Westwood and Warner Center'),
#              ('57060df252bb891400689820', 'business districts'),
#              ('57060df252bb891400689821', 'Downtown Riverside'),
#              ('57060df252bb891400689822',
#               'Hospitality Business/Financial Centre'),
#              ('5ad0475c77cf76001a686f86',
#               'Downtown San Bernardino, Hospitality Business/Financial Centre, University Town'),
#              ('5ad0475c77cf76001a686f87', ''),
#              ('57060eaf75f01819005e7910', 'Orange County'),
#              ('57060eaf75f01819005e7911', 'University of California, Irvine'),
#              ('57060eaf75f01819005e7912', 'West Irvine'),
#              ('57060eaf75f01819005e7913', 'South Coast Metro'),
#              ('57060eaf75f01819005e7914', 'rapidly'),
#              ('5ad0483977cf76001a686f8a', 'Orange County'),
#              ('5ad0483977cf76001a686f8b', ''),
#              ('5ad0483977cf76001a686f8c', 'international corporations'),
#              ('5ad0483977cf76001a686f8d', ''),
#              ('57060f3e75f01819005e7922', 'Downtown San Diego'),
#              ('57060f3e75f01819005e7923', 'Northern San Diego'),
#              ('57060f3e75f01819005e7924', 'North County'),
#              ('57060f3e75f01819005e7925', 'San Diego'),
#              ('5ad04b2377cf76001a686f92', ''),
#              ('5ad04b2377cf76001a686f93', ''),
#              ('5ad04b2377cf76001a686f94', ''),
#              ('570610b275f01819005e792a', 'Los Angeles International Airport'),
#              ('570610b275f01819005e792b', 'passenger volume'),
#              ('570610b275f01819005e792c', 'third'),
#              ('570610b275f01819005e792d', 'San Diego International Airport'),
#              ('570610b275f01819005e792e', 'Van Nuys Airport'),
#              ('5ad04bfc77cf76001a686f98', ''),
#              ('5ad04bfc77cf76001a686f99', 'San Diego International Airport'),
#              ('5ad04bfc77cf76001a686f9a', ''),
#              ('5ad04bfc77cf76001a686f9b',
#               'Orange County, Bakersfield, Ontario, Burbank and Long Beach'),
#              ('5706111a52bb89140068984c', 'Metrolink'),
#              ('5706111a52bb89140068984d', 'seven'),
#              ('5706111a52bb89140068984e', 'Six'),
#              ('5706111a52bb89140068984f', 'Orange'),
#              ('5ad04d3077cf76001a686fa0', ''),
#              ('5ad04d3077cf76001a686fa1', 'Metrolink'),
#              ('5ad04d3077cf76001a686fa2', ''),
#              ('570611c475f01819005e793c', 'Port of Los Angeles'),
#              ('570611c475f01819005e793d', 'Port of Long Beach'),
#              ('570611c475f01819005e793e', 'Southern'),
#              ('5ad04de377cf76001a686fa6', ''),
#              ('5ad04de377cf76001a686fa7', ''),
#              ('5ad04de377cf76001a686fa8', ''),
#              ('5ad04de377cf76001a686fa9', 'Port of Los Angeles'),
#              ('5706139252bb891400689864', 'The Tech Coast'),
#              ('5706139252bb891400689865', 'research'),
#              ('5706139252bb891400689866', 'private institutions'),
#              ('5706139252bb891400689867', '5'),
#              ('5706139252bb891400689868', '12'),
#              ('5ad04ecf77cf76001a686fae',
#               'Irvine, Los Angeles, Riverside, Santa Barbara, and San Diego'),
#              ('5ad04ecf77cf76001a686faf', '12'),
#              ('5ad04ecf77cf76001a686fb0', '12'),
#              ('5ad04ecf77cf76001a686fb1', ''),
#              ('5ad04ecf77cf76001a686fb2', ''),
#              ('5706143575f01819005e7950', 'Professional'),
#              ('5706143575f01819005e7951', 'NBA'),
#              ('5706143575f01819005e7952', 'MLB'),
#              ('5706143575f01819005e7953', 'Los Angeles Kings'),
#              ('5706143575f01819005e7954', 'LA Galaxy'),
#              ('5ad04f7977cf76001a686fb8', ''),
#              ('5ad04f7977cf76001a686fb9', ''),
#              ('5ad04f7977cf76001a686fba', ''),
#              ('5ad04f7977cf76001a686fbb', ''),
#              ('5ad04f7977cf76001a686fbc', ''),
#              ('5706149552bb891400689880', 'Chivas USA'),
#              ('5706149552bb891400689881', 'two'),
#              ('5706149552bb891400689882', '2014'),
#              ('5706149552bb891400689883', 'StubHub Center'),
#              ('5706149552bb891400689884', '2018'),
#              ('5ad050c877cf76001a686fc2', 'two'),
#              ('5ad050c877cf76001a686fc3', ''),
#              ('5ad050c877cf76001a686fc4', ''),
#              ('5ad050c877cf76001a686fc5', ''),
#              ('570614ff52bb89140068988a', 'College'),
#              ('570614ff52bb89140068988b', 'UCLA'),
#              ('570614ff52bb89140068988c', 'Trojans'),
#              ('570614ff52bb89140068988d', 'Pac-12 Conference'),
#              ('570614ff52bb89140068988e', 'Division I'),
#              ('5ad0511577cf76001a686fca', ''),
#              ('5ad0511577cf76001a686fcb', 'Trojans'),
#              ('5ad0511577cf76001a686fcc', ''),
#              ('5706155352bb891400689894', 'Rugby'),
#              ('5706155352bb891400689895', 'high school'),
#              ('5706155352bb891400689896', 'official school sport'),
#              ('5ad051be77cf76001a686fd0', ''),
#              ('57092322efce8f15003a7db0', 'BSkyB'),
#              ('57092322efce8f15003a7db1', 'BSkyB'),
#              ('57092322efce8f15003a7db2', '2014'),
#              ('57092322efce8f15003a7db3',
#               'British Sky Broadcasting Group plc'),
#              ('57092322efce8f15003a7db4', 'Sky UK Limited'),
#              ('5a2c08aebfd06b001a5ae989', ''),
#              ('5a2c08aebfd06b001a5ae98a', ''),
#              ('5a2c08aebfd06b001a5ae98b', ''),
#              ('5a2c08aebfd06b001a5ae98c', ''),
#              ('5a2c08aebfd06b001a5ae98d', ''),
#              ('57094a79efce8f15003a7dc4', '2006'),
#              ('57094a79efce8f15003a7dc5', 'two'),
#              ('57094a79efce8f15003a7dc6', 'Sky'),
#              ('57094a79efce8f15003a7dc7', '£1.3bn'),
#              ('5a2c0c2fbfd06b001a5ae99b', ''),
#              ('5a2c0c2fbfd06b001a5ae99c', ''),
#              ('5a2c0c2fbfd06b001a5ae99d', ''),
#              ('5a2c0c2fbfd06b001a5ae99e', ''),
#              ('5a2c0c2fbfd06b001a5ae99f', ''),
#              ('57094b4f9928a814004714f6', 'ONdigital'),
#              ('57094b4f9928a814004714f7',
#               "ITV Digital's free-to-air replacement, Freeview"),
#              ('57094b4f9928a814004714f8', 'three'),
#              ('57094b4f9928a814004714f9', 'Sky Three'),
#              ('57094b4f9928a814004714fa', ''),
#              ('5a2c14b4bfd06b001a5ae9d3', ''),
#              ('5a2c14b4bfd06b001a5ae9d4', ''),
#              ('5a2c14b4bfd06b001a5ae9d5', ''),
#              ('5a2c14b4bfd06b001a5ae9d6', ''),
#              ('5a2c14b4bfd06b001a5ae9d7', ''),
#              ('57094ca7efce8f15003a7dd6', 'Sky+ PVR'),
#              ('57094ca7efce8f15003a7dd7', 'September 2007'),
#              ('57094ca7efce8f15003a7dd8', 'pay a monthly fee'),
#              ('57094ca7efce8f15003a7dd9', 'January 2010'),
#              ('57094ca7efce8f15003a7dda', 'Sky+HD Box'),
#              ('5a2c16e3bfd06b001a5ae9e7', ''),
#              ('5a2c16e3bfd06b001a5ae9e8', ''),
#              ('5a2c16e3bfd06b001a5ae9e9', ''),
#              ('5a2c16e3bfd06b001a5ae9ea', ''),
#              ('5a2c16e3bfd06b001a5ae9eb', ''),
#              ('57094d489928a8140047150a', 'VideoGuard'),
#              ('57094d489928a8140047150b', 'NDS'),
#              ('57094d489928a8140047150c', 'Cisco Systems'),
#              ('57094d489928a8140047150d', 'BSkyB'),
#              ('57094d489928a8140047150e', 'Sky+'),
#              ('5a2c3a5cbfd06b001a5aea79', ''),
#              ('5a2c3a5cbfd06b001a5aea7a', ''),
#              ('5a2c3a5cbfd06b001a5aea7b', ''),
#              ('5a2c3a5cbfd06b001a5aea7c', ''),
#              ('5a2c3a5cbfd06b001a5aea7d', ''),
#              ('570953a7efce8f15003a7dfe', '2007'),
#              ...])

# %%
from datasets import load_metric
metric = load_metric("squad_v2" if squad_v2 else "squad")
# Out:
# <ipython-input-43-e660a519b5d4>:2: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("squad_v2" if squad_v2 else "squad")
# Downloading builder script:   0%|          | 0.00/2.25k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.19k [00:00<?, ?B/s]
# The repository for squad_v2 contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/squad_v2.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y

# %%
if squad_v2:
    formatted_predictions = [
        {"id": k, "prediction_text": v, "no_answer_probability": na_probs_dict[k]}
        for k, v in final_predictions.items()
    ]
else:
    formatted_predictions = [{"id": k, "prediction_text": v} for k, v in final_predictions.items()]

# %%
references = [{"id": ex["id"], "answers": ex["answers"]} for ex in raw_datasets["validation"]]

# %%
# Compute the metric
metric_result = metric.compute(predictions=formatted_predictions, references=references)
print(metric_result)

# %%
validation_features
# Out:
# Dataset({
#     features: ['input_ids', 'attention_mask', 'offset_mapping', 'example_id'],
#     num_rows: 12165
# })

# %%
formatted_predictions
# Out:
# [{'id': '56ddde6b9a695914005b9628',
#   'prediction_text': 'France',
#   'no_answer_probability': 2.4876490010363496e-05},
#  {'id': '56ddde6b9a695914005b9629',
#   'prediction_text': '10th and 11th centuries',
#   'no_answer_probability': 0.0002689534841585773},
#  {'id': '56ddde6b9a695914005b962a',
#   'prediction_text': 'Denmark, Iceland and Norway',
#   'no_answer_probability': 0.015483987303625265},
#  {'id': '56ddde6b9a695914005b962b',
#   'prediction_text': 'Rollo',
#   'no_answer_probability': 0.11162799104060678},
#  {'id': '56ddde6b9a695914005b962c',
#   'prediction_text': '10th century',
#   'no_answer_probability': 8.597842999974016e-05},
#  {'id': '5ad39d53604f3c001a3fe8d1',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999461154717781},
#  {'id': '5ad39d53604f3c001a3fe8d2',
#   'prediction_text': '',
#   'no_answer_probability': 0.9859092655162919},
#  {'id': '5ad39d53604f3c001a3fe8d3',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999393720159937},
#  {'id': '5ad39d53604f3c001a3fe8d4',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999997580114054},
#  {'id': '56dddf4066d3e219004dad5f',
#   'prediction_text': 'William the Conqueror',
#   'no_answer_probability': 0.0038996206725778896},
#  {'id': '56dddf4066d3e219004dad60',
#   'prediction_text': 'Richard I of Normandy',
#   'no_answer_probability': 0.0005463420892147277},
#  {'id': '56dddf4066d3e219004dad61',
#   'prediction_text': 'Christian',
#   'no_answer_probability': 0.00036686259524002385},
#  {'id': '5ad3a266604f3c001a3fea27',
#   'prediction_text': '',
#   'no_answer_probability': 0.9991904030181439},
#  {'id': '5ad3a266604f3c001a3fea28',
#   'prediction_text': '',
#   'no_answer_probability': 0.863851684976284},
#  {'id': '5ad3a266604f3c001a3fea29',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999928202461701},
#  {'id': '5ad3a266604f3c001a3fea2a',
#   'prediction_text': 'Richard I of Normandy',
#   'no_answer_probability': 0.000834460263093835},
#  {'id': '5ad3a266604f3c001a3fea2b',
#   'prediction_text': '',
#   'no_answer_probability': 0.999996823311149},
#  {'id': '56dde0379a695914005b9636',
#   'prediction_text': 'Norseman, Viking".',
#   'no_answer_probability': 0.11516222873143664},
#  {'id': '56dde0379a695914005b9637',
#   'prediction_text': '9th century',
#   'no_answer_probability': 0.04484790343329438},
#  {'id': '5ad3ab70604f3c001a3feb89',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999677880114969},
#  {'id': '5ad3ab70604f3c001a3feb8a',
#   'prediction_text': '',
#   'no_answer_probability': 0.9971439874741471},
#  {'id': '56dde0ba66d3e219004dad75',
#   'prediction_text': '911',
#   'no_answer_probability': 2.6636455796610528e-05},
#  {'id': '56dde0ba66d3e219004dad76',
#   'prediction_text': '',
#   'no_answer_probability': 0.9567151548042914},
#  {'id': '56dde0ba66d3e219004dad77',
#   'prediction_text': 'Seine',
#   'no_answer_probability': 0.019382191201735868},
#  {'id': '5ad3ad61604f3c001a3fec0d',
#   'prediction_text': '',
#   'no_answer_probability': 0.997429131960124},
#  {'id': '5ad3ad61604f3c001a3fec0e',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999981961508171},
#  {'id': '5ad3ad61604f3c001a3fec0f',
#   'prediction_text': '',
#   'no_answer_probability': 0.9959219374783366},
#  {'id': '5ad3ad61604f3c001a3fec10',
#   'prediction_text': 'further Viking incursions',
#   'no_answer_probability': 0.0006226772406694149},
#  {'id': '56dde1d966d3e219004dad8d',
#   'prediction_text': '',
#   'no_answer_probability': 0.9996438995023449},
#  {'id': '5ad3ae14604f3c001a3fec39',
#   'prediction_text': '',
#   'no_answer_probability': 0.9997478303421281},
#  {'id': '5ad3ae14604f3c001a3fec3a',
#   'prediction_text': 'Danes, Norwegians, Norse–Gaels, Orkney Vikings',
#   'no_answer_probability': 0.18330105547281286},
#  {'id': '56dde27d9a695914005b9651',
#   'prediction_text': 'Catholicism',
#   'no_answer_probability': 0.10141132475464801},
#  {'id': '56dde27d9a695914005b9652',
#   'prediction_text': 'north',
#   'no_answer_probability': 5.089259728685e-05},
#  {'id': '5ad3af11604f3c001a3fec63',
#   'prediction_text': '',
#   'no_answer_probability': 0.999930269344368},
#  {'id': '5ad3af11604f3c001a3fec64',
#   'prediction_text': '',
#   'no_answer_probability': 0.9935117304033434},
#  {'id': '5ad3af11604f3c001a3fec65',
#   'prediction_text': '',
#   'no_answer_probability': 0.9995740413307389},
#  {'id': '56dde2fa66d3e219004dad9b',
#   'prediction_text': 'fighting horsemen',
#   'no_answer_probability': 1.6030271485462665e-05},
#  {'id': '5ad3c626604f3c001a3ff011',
#   'prediction_text': '',
#   'no_answer_probability': 0.823895879756849},
#  {'id': '5ad3c626604f3c001a3ff012',
#   'prediction_text': 'fighting horsemen',
#   'no_answer_probability': 0.2598256379609837},
#  {'id': '5ad3c626604f3c001a3ff013',
#   'prediction_text': '',
#   'no_answer_probability': 0.9983466884332869},
#  {'id': '56de0f6a4396321400ee257f',
#   'prediction_text': 'Pechenegs, the Bulgars, and especially the Seljuk Turks',
#   'no_answer_probability': 0.1645164628965632},
#  {'id': '5ad3dbc6604f3c001a3ff3e9',
#   'prediction_text': '',
#   'no_answer_probability': 0.9282788756737625},
#  {'id': '5ad3dbc6604f3c001a3ff3ea',
#   'prediction_text': 'the Pechenegs, the Bulgars, and especially the Seljuk Turks',
#   'no_answer_probability': 0.040162582876001086},
#  {'id': '5ad3dbc6604f3c001a3ff3eb',
#   'prediction_text': '',
#   'no_answer_probability': 0.9578334587487554},
#  {'id': '5ad3dbc6604f3c001a3ff3ec',
#   'prediction_text': 'Sicilian campaign of George Maniaces',
#   'no_answer_probability': 0.2774729816308713},
#  {'id': '56de0ffd4396321400ee258d',
#   'prediction_text': '1050s',
#   'no_answer_probability': 0.000916400148534778},
#  {'id': '56de0ffd4396321400ee258e',
#   'prediction_text': '1060s',
#   'no_answer_probability': 8.992845191712825e-05},
#  {'id': '56de0ffd4396321400ee258f',
#   'prediction_text': 'Alexius Komnenos',
#   'no_answer_probability': 2.5766586123308254e-05},
#  {'id': '5ad3de8b604f3c001a3ff467',
#   'prediction_text': 'Hervé',
#   'no_answer_probability': 0.11008788101422486},
#  {'id': '5ad3de8b604f3c001a3ff468',
#   'prediction_text': '',
#   'no_answer_probability': 0.9560634664484897},
#  {'id': '5ad3de8b604f3c001a3ff469',
#   'prediction_text': '',
#   'no_answer_probability': 0.999901630813113},
#  {'id': '5ad3de8b604f3c001a3ff46a',
#   'prediction_text': '',
#   'no_answer_probability': 0.9890976262707148},
#  {'id': '56de10b44396321400ee2593',
#   'prediction_text': 'Afranji',
#   'no_answer_probability': 0.0008312097149710454},
#  {'id': '56de10b44396321400ee2594',
#   'prediction_text': 'Oursel',
#   'no_answer_probability': 0.0011740822246468026},
#  {'id': '56de10b44396321400ee2595',
#   'prediction_text': 'Turkish forces',
#   'no_answer_probability': 0.00239673087012896},
#  {'id': '5ad3e96b604f3c001a3ff689',
#   'prediction_text': '',
#   'no_answer_probability': 0.9334308110294983},
#  {'id': '5ad3e96b604f3c001a3ff68a',
#   'prediction_text': '',
#   'no_answer_probability': 0.9687380865831757},
#  {'id': '5ad3e96b604f3c001a3ff68b',
#   'prediction_text': '',
#   'no_answer_probability': 0.9735944821139189},
#  {'id': '5ad3e96b604f3c001a3ff68c',
#   'prediction_text': 'upper Euphrates valley in northern Syria',
#   'no_answer_probability': 0.001475063443724479},
#  {'id': '56de11154396321400ee25aa',
#   'prediction_text': 'Italo-Norman named Raoul',
#   'no_answer_probability': 0.3598139200382316},
#  {'id': '5ad3ea79604f3c001a3ff6e9',
#   'prediction_text': 'Byzantine Greece',
#   'no_answer_probability': 1.6030271485462665e-05},
#  {'id': '5ad3ea79604f3c001a3ff6ea',
#   'prediction_text': '',
#   'no_answer_probability': 0.9991297839400847},
#  {'id': '5ad3ea79604f3c001a3ff6eb',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999489019880453},
#  {'id': '56de148dcffd8e1900b4b5bc',
#   'prediction_text': 'Robert Guiscard',
#   'no_answer_probability': 9.554101554043099e-05},
#  {'id': '56de148dcffd8e1900b4b5bd',
#   'prediction_text': 'February 1082',
#   'no_answer_probability': 1.1682324821977873e-05},
#  {'id': '56de148dcffd8e1900b4b5be',
#   'prediction_text': '30,000',
#   'no_answer_probability': 3.460477151432685e-05},
#  {'id': '5ad3ed26604f3c001a3ff799',
#   'prediction_text': '',
#   'no_answer_probability': 0.9969573895643206},
#  {'id': '5ad3ed26604f3c001a3ff79a',
#   'prediction_text': '',
#   'no_answer_probability': 0.9972955706305906},
#  {'id': '5ad3ed26604f3c001a3ff79b',
#   'prediction_text': '',
#   'no_answer_probability': 0.9874599812163353},
#  {'id': '5ad3ed26604f3c001a3ff79c',
#   'prediction_text': '30,000',
#   'no_answer_probability': 0.29910519024570714},
#  {'id': '56de15104396321400ee25b7',
#   'prediction_text': 'Deabolis',
#   'no_answer_probability': 0.00019487277625896733},
#  {'id': '56de15104396321400ee25b8',
#   'prediction_text': 'Bohemond',
#   'no_answer_probability': 2.1697729201957923e-05},
#  {'id': '56de15104396321400ee25b9',
#   'prediction_text': 'Deabolis',
#   'no_answer_probability': 3.4130848139299675e-06},
#  {'id': '5ad3ee2d604f3c001a3ff7e1',
#   'prediction_text': '',
#   'no_answer_probability': 0.985854896037305},
#  {'id': '5ad3ee2d604f3c001a3ff7e2',
#   'prediction_text': '',
#   'no_answer_probability': 0.9960314997270954},
#  {'id': '5ad3ee2d604f3c001a3ff7e3',
#   'prediction_text': 'Robert',
#   'no_answer_probability': 0.06608537866754877},
#  {'id': '56de1563cffd8e1900b4b5c2',
#   'prediction_text': '1185',
#   'no_answer_probability': 1.7917988275182845e-05},
#  {'id': '56de1563cffd8e1900b4b5c3',
#   'prediction_text': 'Dyrrachium',
#   'no_answer_probability': 0.003907214773811623},
#  {'id': '56de1563cffd8e1900b4b5c4',
#   'prediction_text': 'Adriatic',
#   'no_answer_probability': 0.008203786217346793},
#  {'id': '5ad3f028604f3c001a3ff823',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999983103975859},
#  {'id': '5ad3f028604f3c001a3ff824',
#   'prediction_text': 'high Byzantine officials',
#   'no_answer_probability': 0.3548800897081317},
#  {'id': '5ad3f028604f3c001a3ff825',
#   'prediction_text': '',
#   'no_answer_probability': 0.8305941186502768},
#  {'id': '56de15dbcffd8e1900b4b5c8',
#   'prediction_text': 'King Ethelred II of England',
#   'no_answer_probability': 0.016434573963927168},
#  {'id': '56de15dbcffd8e1900b4b5c9',
#   'prediction_text': 'Duke Richard II of Normandy',
#   'no_answer_probability': 0.38121956625614994},
#  {'id': '56de15dbcffd8e1900b4b5ca',
#   'prediction_text': 'Normandy',
#   'no_answer_probability': 2.1528879768913178e-05},
#  {'id': '56de15dbcffd8e1900b4b5cb',
#   'prediction_text': 'Sweyn Forkbeard',
#   'no_answer_probability': 3.0718185454758056e-05},
#  {'id': '5ad3f187604f3c001a3ff86f',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999921549129804},
#  {'id': '5ad3f187604f3c001a3ff870',
#   'prediction_text': '',
#   'no_answer_probability': 0.999999652350365},
#  {'id': '5ad3f187604f3c001a3ff871',
#   'prediction_text': '',
#   'no_answer_probability': 0.9991365501678425},
#  {'id': '56de1645cffd8e1900b4b5d0',
#   'prediction_text': 'Harthacnut',
#   'no_answer_probability': 9.856754450185615e-06},
#  {'id': '56de1645cffd8e1900b4b5d1',
#   'prediction_text': '1041',
#   'no_answer_probability': 8.31645944237297e-06},
#  {'id': '56de1645cffd8e1900b4b5d2',
#   'prediction_text': 'Robert of Jumièges',
#   'no_answer_probability': 1.4652874531682378e-05},
#  {'id': '5ad3f350604f3c001a3ff8ef',
#   'prediction_text': '1041',
#   'no_answer_probability': 2.3007035274670075e-05},
#  {'id': '5ad3f350604f3c001a3ff8f0',
#   'prediction_text': '',
#   'no_answer_probability': 0.999628452021657},
#  {'id': '5ad3f350604f3c001a3ff8f1',
#   'prediction_text': '',
#   'no_answer_probability': 0.999959389780303},
#  {'id': '56de16ca4396321400ee25c5',
#   'prediction_text': 'Battle of Hastings',
#   'no_answer_probability': 0.00013342001090985438},
#  {'id': '56de16ca4396321400ee25c6',
#   'prediction_text': 'Duke William II of Normandy',
#   'no_answer_probability': 4.0694577904668375e-05},
#  {'id': '56de16ca4396321400ee25c7',
#   'prediction_text': '1066',
#   'no_answer_probability': 3.8604257872352e-05},
#  {'id': '56de16ca4396321400ee25c8',
#   'prediction_text': 'Anglo-Saxons',
#   'no_answer_probability': 0.002720278917860909},
#  {'id': '5ad3f4b1604f3c001a3ff951',
#   'prediction_text': '',
#   'no_answer_probability': 0.9998945046605817},
#  {'id': '5ad3f4b1604f3c001a3ff952',
#   'prediction_text': '',
#   'no_answer_probability': 0.9995405673190938},
#  {'id': '5ad3f4b1604f3c001a3ff953',
#   'prediction_text': '',
#   'no_answer_probability': 0.9934991280804971},
#  {'id': '5ad3f4b1604f3c001a3ff954',
#   'prediction_text': '',
#   'no_answer_probability': 0.9981049279734704},
#  {'id': '56de1728cffd8e1900b4b5d7',
#   'prediction_text': 'Modern English',
#   'no_answer_probability': 0.0014550629385328433},
#  {'id': '5ad3f5b0604f3c001a3ff9ab',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999867161757},
#  {'id': '5ad3f5b0604f3c001a3ff9ac',
#   'prediction_text': '',
#   'no_answer_probability': 0.9996724157021403},
#  {'id': '5ad3f5b0604f3c001a3ff9ad',
#   'prediction_text': '',
#   'no_answer_probability': 0.6095241625665028},
#  {'id': '56de179dcffd8e1900b4b5da',
#   'prediction_text': '1169',
#   'no_answer_probability': 4.065027692616363e-06},
#  {'id': '56de179dcffd8e1900b4b5db',
#   'prediction_text': 'Irish',
#   'no_answer_probability': 0.022457052929416074},
#  {'id': '56de179dcffd8e1900b4b5dc',
#   'prediction_text': 'Irish',
#   'no_answer_probability': 0.030214587067393984},
#  {'id': '5ad3f6f5604f3c001a3ffa09',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999475048001882},
#  {'id': '5ad3f6f5604f3c001a3ffa0a',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999662915901456},
#  {'id': '5ad3f6f5604f3c001a3ffa0b',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999887734384846},
#  {'id': '56de17f9cffd8e1900b4b5e0',
#   'prediction_text': '',
#   'no_answer_probability': 0.9995637315398894},
#  {'id': '56de17f9cffd8e1900b4b5e1',
#   'prediction_text': 'King Malcolm III',
#   'no_answer_probability': 0.10248421925249873},
#  {'id': '56de17f9cffd8e1900b4b5e2',
#   'prediction_text': '1072',
#   'no_answer_probability': 8.0763495459825e-06},
#  {'id': '56de17f9cffd8e1900b4b5e3',
#   'prediction_text': 'his son Duncan',
#   'no_answer_probability': 0.001919237453341115},
#  {'id': '5ad3f7ac604f3c001a3ffa3b',
#   'prediction_text': '',
#   'no_answer_probability': 0.9988384479159582},
#  {'id': '5ad3f7ac604f3c001a3ffa3c',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999941084891316},
#  {'id': '5ad3f7ac604f3c001a3ffa3d',
#   'prediction_text': 'his son Duncan',
#   'no_answer_probability': 0.0003719108603812085},
#  {'id': '56de3cd0cffd8e1900b4b6be',
#   'prediction_text': 'Sybilla of Normandy',
#   'no_answer_probability': 0.00039588755425319156},
#  {'id': '56de3cd0cffd8e1900b4b6bf',
#   'prediction_text': 'Normans',
#   'no_answer_probability': 0.0002364329650897847},
#  {'id': '5ad3f8d2604f3c001a3ffa8d',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999308457277332},
#  {'id': '5ad3f8d2604f3c001a3ffa8e',
#   'prediction_text': '',
#   'no_answer_probability': 0.9993194933242302},
#  {'id': '56de3d594396321400ee26ca',
#   'prediction_text': 'Hereford',
#   'no_answer_probability': 0.0004601058612790196},
#  {'id': '56de3d594396321400ee26cb',
#   'prediction_text': 'the Welsh',
#   'no_answer_probability': 5.422763795549364e-05},
#  {'id': '56de3d594396321400ee26cc',
#   'prediction_text': 'Edward the Confessor',
#   'no_answer_probability': 0.00013631707508350336},
#  {'id': '5ad3fb01604f3c001a3ffb35',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999931476173908},
#  {'id': '5ad3fb01604f3c001a3ffb36',
#   'prediction_text': '',
#   'no_answer_probability': 0.9998647105881843},
#  {'id': '56de3dbacffd8e1900b4b6d2',
#   'prediction_text': 'the Marches',
#   'no_answer_probability': 0.3153141611162926},
#  {'id': '5ad3fb6e604f3c001a3ffb5f',
#   'prediction_text': '',
#   'no_answer_probability': 0.9989617092786887},
#  {'id': '5ad3fb6e604f3c001a3ffb60',
#   'prediction_text': '',
#   'no_answer_probability': 0.9961531279494066},
#  {'id': '56de3e414396321400ee26d8',
#   'prediction_text': '1018',
#   'no_answer_probability': 0.004914948803150347},
#  {'id': '56de3e414396321400ee26d9',
#   'prediction_text': 'William of Montreuil',
#   'no_answer_probability': 1.0070809714662182e-05},
#  {'id': '5ad3fc41604f3c001a3ffb8f',
#   'prediction_text': '',
#   'no_answer_probability': 0.8778961345311737},
#  {'id': '5ad3fc41604f3c001a3ffb90',
#   'prediction_text': '',
#   'no_answer_probability': 0.5964331462646254},
#  {'id': '5ad3fc41604f3c001a3ffb91',
#   'prediction_text': '',
#   'no_answer_probability': 0.9976632171415467},
#  {'id': '5ad3fc41604f3c001a3ffb92',
#   'prediction_text': '',
#   'no_answer_probability': 0.9994573779152519},
#  {'id': '56de3ebc4396321400ee26e6',
#   'prediction_text': '1097',
#   'no_answer_probability': 1.5905524907249103e-05},
#  {'id': '56de3ebc4396321400ee26e7',
#   'prediction_text': 'Tancred',
#   'no_answer_probability': 2.7643459783279656e-05},
#  {'id': '56de3ebc4396321400ee26e8',
#   'prediction_text': 'Jerusalem',
#   'no_answer_probability': 7.5648370392357845e-06},
#  {'id': '5ad4017a604f3c001a3ffd1f',
#   'prediction_text': '',
#   'no_answer_probability': 0.9990942665666217},
#  {'id': '5ad4017a604f3c001a3ffd20',
#   'prediction_text': '',
#   'no_answer_probability': 0.9957684125218387},
#  {'id': '56de3efccffd8e1900b4b6fe',
#   'prediction_text': '380 years',
#   'no_answer_probability': 0.0001740054355270893},
#  {'id': '5ad401f2604f3c001a3ffd41',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999728514604561},
#  {'id': '5ad401f2604f3c001a3ffd42',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999998649178801},
#  {'id': '56de3f784396321400ee26fa',
#   'prediction_text': 'a storm',
#   'no_answer_probability': 2.000844854917845e-05},
#  {'id': '56de3f784396321400ee26fb',
#   'prediction_text': 'Berengaria',
#   'no_answer_probability': 3.1198129969384747e-06},
#  {'id': '56de3f784396321400ee26fc',
#   'prediction_text': '1191',
#   'no_answer_probability': 0.0006550929443587467},
#  {'id': '56de3f784396321400ee26fd',
#   'prediction_text': 'Isaac Komnenos',
#   'no_answer_probability': 0.0004756318772649072},
#  {'id': '5ad40280604f3c001a3ffd57',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999962878894517},
#  {'id': '5ad40280604f3c001a3ffd58',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999713114670535},
#  {'id': '5ad40280604f3c001a3ffd59',
#   'prediction_text': '',
#   'no_answer_probability': 0.9976813599655814},
#  {'id': '56de40da4396321400ee2708',
#   'prediction_text': 'Conrad of Montferrat',
#   'no_answer_probability': 0.0003521250949548094},
#  {'id': '56de40da4396321400ee2709',
#   'prediction_text': 'silver',
#   'no_answer_probability': 0.000834460263093835},
#  {'id': '56de40da4396321400ee270a',
#   'prediction_text': 'Guy de Lusignan',
#   'no_answer_probability': 4.322974621015979e-06},
#  {'id': '5ad404a6604f3c001a3ffde1',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999825241607122},
#  {'id': '5ad404a6604f3c001a3ffde2',
#   'prediction_text': '',
#   'no_answer_probability': 0.9869292152258129},
#  {'id': '5ad404a6604f3c001a3ffde3',
#   'prediction_text': '',
#   'no_answer_probability': 0.9328214227111127},
#  {'id': '56de49564396321400ee277a',
#   'prediction_text': 'Africa',
#   'no_answer_probability': 5.0842924270045725e-05},
#  {'id': '5ad40419604f3c001a3ffdb7',
#   'prediction_text': '',
#   'no_answer_probability': 0.9949690829216368},
#  {'id': '5ad40419604f3c001a3ffdb8',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999997643085783},
#  {'id': '56de49a8cffd8e1900b4b7a7',
#   'prediction_text': 'Bethencourt',
#   'no_answer_probability': 1.5059061059627363e-05},
#  {'id': '56de49a8cffd8e1900b4b7a8',
#   'prediction_text': 'Enrique Pérez de Guzmán',
#   'no_answer_probability': 0.0012207952467143705},
#  {'id': '56de49a8cffd8e1900b4b7a9',
#   'prediction_text': 'Maciot de Bethencourt',
#   'no_answer_probability': 0.00015446467916056827},
#  {'id': '5ad403c1604f3c001a3ffd97',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999977130317754},
#  {'id': '5ad403c1604f3c001a3ffd98',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999986905452738},
#  {'id': '56de4a474396321400ee2786',
#   'prediction_text': 'Channel Islands',
#   'no_answer_probability': 0.0010566838241698937},
#  {'id': '56de4a474396321400ee2787',
#   'prediction_text': 'two',
#   'no_answer_probability': 0.002199798043691517},
#  {'id': '5ad40358604f3c001a3ffd7d',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999989920764106},
#  {'id': '5ad40358604f3c001a3ffd7e',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999995990754527},
#  {'id': '5ad40358604f3c001a3ffd7f',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999994995774526},
#  {'id': '56de4a89cffd8e1900b4b7bd',
#   'prediction_text': 'Romanesque',
#   'no_answer_probability': 6.604621150357542e-06},
#  {'id': '56de4a89cffd8e1900b4b7be',
#   'prediction_text': 'rounded',
#   'no_answer_probability': 8.131747651020262e-06},
#  {'id': '5ad402ce604f3c001a3ffd67',
#   'prediction_text': 'rounded',
#   'no_answer_probability': 0.0024726231566347748},
#  {'id': '56de4b074396321400ee2793',
#   'prediction_text': 'Early Gothic',
#   'no_answer_probability': 0.14128141600070077},
#  {'id': '56de4b074396321400ee2794',
#   'prediction_text': 'Anglo-Saxon',
#   'no_answer_probability': 0.006705847928328613},
#  {'id': '56de4b074396321400ee2795',
#   'prediction_text': 'Sicily',
#   'no_answer_probability': 0.010923455408082405},
#  {'id': '5ad400b0604f3c001a3ffcdf',
#   'prediction_text': '',
#   'no_answer_probability': 0.9998957590402705},
#  {'id': '5ad400b0604f3c001a3ffce0',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999814951822802},
#  {'id': '5ad400b0604f3c001a3ffce1',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999982154243633},
#  {'id': '56de4b5c4396321400ee2799',
#   'prediction_text': 'early 11th century',
#   'no_answer_probability': 3.771002492473604e-05},
#  {'id': '56de4b5c4396321400ee279a',
#   'prediction_text': 'the dukes',
#   'no_answer_probability': 0.0001914778596956345},
#  {'id': '5ad3ffd7604f3c001a3ffca7',
#   'prediction_text': '',
#   'no_answer_probability': 0.999882943219636},
#  {'id': '5ad3ffd7604f3c001a3ffca8',
#   'prediction_text': '',
#   'no_answer_probability': 0.8548846370796298},
#  {'id': '5ad3ffd7604f3c001a3ffca9',
#   'prediction_text': '',
#   'no_answer_probability': 0.999924787446258},
#  {'id': '5ad3ffd7604f3c001a3ffcaa',
#   'prediction_text': '',
#   'no_answer_probability': 0.9743860854300219},
#  {'id': '56de4bb84396321400ee27a2',
#   'prediction_text': '16th century',
#   'no_answer_probability': 4.683386688301382e-06},
#  {'id': '5ad3ff1b604f3c001a3ffc73',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999244930948731},
#  {'id': '5ad3ff1b604f3c001a3ffc74',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999946943264102},
#  {'id': '56de4c324396321400ee27ab',
#   'prediction_text': 'embroidery',
#   'no_answer_probability': 0.0001488384825728813},
#  {'id': '56de4c324396321400ee27ac',
#   'prediction_text': 'Bayeux Tapestry',
#   'no_answer_probability': 2.3052013764592773e-05},
#  {'id': '56de4c324396321400ee27ad',
#   'prediction_text': 'Odo',
#   'no_answer_probability': 0.00010091088160551772},
#  {'id': '5ad3fe91604f3c001a3ffc47',
#   'prediction_text': '',
#   'no_answer_probability': 0.9998623453663109},
#  {'id': '5ad3fe91604f3c001a3ffc48',
#   'prediction_text': '',
#   'no_answer_probability': 0.99998928671734},
#  {'id': '56de51244396321400ee27ef',
#   'prediction_text': 'mosaics',
#   'no_answer_probability': 0.00220408924367988},
#  {'id': '5ad3fe0d604f3c001a3ffc1b',
#   'prediction_text': '',
#   'no_answer_probability': 0.9988384479159582},
#  {'id': '5ad3fe0d604f3c001a3ffc1c',
#   'prediction_text': '',
#   'no_answer_probability': 0.7008948097542927},
#  {'id': '5ad3fe0d604f3c001a3ffc1d',
#   'prediction_text': '',
#   'no_answer_probability': 0.9970878217168856},
#  {'id': '56de51c64396321400ee27f7',
#   'prediction_text': '11th century',
#   'no_answer_probability': 2.3343530494368995e-06},
#  {'id': '56de51c64396321400ee27f8',
#   'prediction_text': 'William of Volpiano and John of Ravenna',
#   'no_answer_probability': 0.00029365463331598425},
#  {'id': '5ad3fd68604f3c001a3ffbe7',
#   'prediction_text': '',
#   'no_answer_probability': 0.9964203573960624},
#  {'id': '5ad3fd68604f3c001a3ffbe8',
#   'prediction_text': 'musical production and education',
#   'no_answer_probability': 0.002273895452921985},
#  {'id': '56de52614396321400ee27fb',
#   'prediction_text': 'southern Italy',
#   'no_answer_probability': 7.766951856747236e-06},
#  {'id': '56de52614396321400ee27fc',
#   'prediction_text': "Sant'Eufemia",
#   'no_answer_probability': 8.415109250079664e-05},
#  {'id': '56de52614396321400ee27fd',
#   'prediction_text': 'Robert Guiscard',
#   'no_answer_probability': 2.9657043453821356e-05},
#  {'id': '56de52614396321400ee27fe',
#   'prediction_text': 'singing',
#   'no_answer_probability': 0.00026068081246379037},
#  {'id': '5ad3fccf604f3c001a3ffbb5',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999966447484879},
#  {'id': '56e16182e3433e1400422e28',
#   'prediction_text': 'Computational complexity theory',
#   'no_answer_probability': 0.003551884549034502},
#  {'id': '56e16182e3433e1400422e29',
#   'prediction_text': 'inherent difficulty',
#   'no_answer_probability': 4.8132143248577596e-06},
#  {'id': '56e16182e3433e1400422e2a',
#   'prediction_text': 'A computational problem',
#   'no_answer_probability': 0.0003726376876619113},
#  {'id': '5ad5316b5b96ef001a10ab72',
#   'prediction_text': '',
#   'no_answer_probability': 0.9890765445919175},
#  {'id': '5ad5316b5b96ef001a10ab73',
#   'prediction_text': 'Computational complexity theory',
#   'no_answer_probability': 0.007066400963249157},
#  {'id': '5ad5316b5b96ef001a10ab74',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999970068909},
#  {'id': '5ad5316b5b96ef001a10ab75',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999984471954},
#  {'id': '5ad5316b5b96ef001a10ab76',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999620313184164},
#  {'id': '56e16839cd28a01900c67887',
#   'prediction_text': 'significant resources',
#   'no_answer_probability': 0.009161026922093826},
#  {'id': '56e16839cd28a01900c67888',
#   'prediction_text': '',
#   'no_answer_probability': 0.9982419612904427},
#  {'id': '56e16839cd28a01900c67889',
#   'prediction_text': 'time and storage',
#   'no_answer_probability': 0.051272418130294733},
#  {'id': '56e16839cd28a01900c6788a',
#   'prediction_text': 'number of gates in a circuit',
#   'no_answer_probability': 0.07892588556500026},
#  {'id': '56e16839cd28a01900c6788b',
#   'prediction_text': '',
#   'no_answer_probability': 0.8330531399355948},
#  {'id': '5ad532575b96ef001a10ab7c',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999998892095338},
#  {'id': '5ad532575b96ef001a10ab7d',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999905434905},
#  {'id': '5ad532575b96ef001a10ab7e',
#   'prediction_text': '',
#   'no_answer_probability': 0.9141375437004452},
#  {'id': '5ad532575b96ef001a10ab7f',
#   'prediction_text': '',
#   'no_answer_probability': 0.999999675954901},
#  {'id': '5ad532575b96ef001a10ab80',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999994821775066},
#  {'id': '56e17644e3433e1400422f40',
#   'prediction_text': 'analysis of algorithms and computability theory',
#   'no_answer_probability': 0.018617802261831698},
#  {'id': '56e17644e3433e1400422f41',
#   'prediction_text': '',
#   'no_answer_probability': 0.6714705667356973},
#  {'id': '56e17644e3433e1400422f42',
#   'prediction_text': 'computational complexity theory',
#   'no_answer_probability': 0.2309197629292718},
#  {'id': '56e17644e3433e1400422f43',
#   'prediction_text': 'analysis of algorithms',
#   'no_answer_probability': 0.21866937668390204},
#  {'id': '5ad5344b5b96ef001a10ab86',
#   'prediction_text': '',
#   'no_answer_probability': 0.999222153437942},
#  {'id': '5ad5344b5b96ef001a10ab87',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999953003662},
#  {'id': '5ad5344b5b96ef001a10ab88',
#   'prediction_text': '',
#   'no_answer_probability': 0.9998464376023504},
#  {'id': '5ad5344b5b96ef001a10ab89',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999997115067183},
#  {'id': '5ad5344b5b96ef001a10ab8a',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999974647378},
#  {'id': '56e17a7ccd28a01900c679a1',
#   'prediction_text': 'problem instance',
#   'no_answer_probability': 9.44280341008577e-05},
#  {'id': '56e17a7ccd28a01900c679a2',
#   'prediction_text': 'a problem',
#   'no_answer_probability': 0.0008864989276457546},
#  {'id': '56e17a7ccd28a01900c679a3',
#   'prediction_text': 'concrete',
#   'no_answer_probability': 0.0037434976760134867},
#  {'id': '56e17a7ccd28a01900c679a4',
#   'prediction_text': 'problem instance',
#   'no_answer_probability': 0.4785288375393227},
#  {'id': '56e17a7ccd28a01900c679a5',
#   'prediction_text': 'solution',
#   'no_answer_probability': 0.09877258875237437},
#  {'id': '5ad5364c5b96ef001a10ab90',
#   'prediction_text': '',
#   'no_answer_probability': 0.999999804795663},
#  {'id': '5ad5364c5b96ef001a10ab91',
#   'prediction_text': '',
#   'no_answer_probability': 0.9362850057480346},
#  {'id': '5ad5364c5b96ef001a10ab92',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999997499638692},
#  {'id': '5ad5364c5b96ef001a10ab93',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999955245292076},
#  {'id': '5ad5364c5b96ef001a10ab94',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999998851331612},
#  {'id': '56e17e6ee3433e1400422f7f',
#   'prediction_text': '2000',
#   'no_answer_probability': 0.0013912341086783425},
#  {'id': '56e17e6ee3433e1400422f80',
#   'prediction_text': "Is there a route of at most 2000 kilometres passing through all of Germany's 15 largest cities",
#   'no_answer_probability': 0.01665704000922906},
#  {'id': '56e17e6ee3433e1400422f81',
#   'prediction_text': 'computational problems',
#   'no_answer_probability': 0.018124720744468643},
#  {'id': '5ad537a15b96ef001a10ab9a',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999909676148664},
#  {'id': '5ad537a15b96ef001a10ab9b',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999957127607707},
#  {'id': '5ad537a15b96ef001a10ab9c',
#   'prediction_text': '',
#   'no_answer_probability': 0.9800530655725895},
#  {'id': '5ad537a15b96ef001a10ab9d',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999815087304007},
#  {'id': '56e181d9e3433e1400422fa0',
#   'prediction_text': 'a problem instance',
#   'no_answer_probability': 0.00010472557180794286},
#  {'id': '56e181d9e3433e1400422fa1',
#   'prediction_text': 'binary alphabet',
#   'no_answer_probability': 0.00020947364614149903},
#  {'id': '56e181d9e3433e1400422fa2',
#   'prediction_text': 'bitstrings',
#   'no_answer_probability': 0.005554924703691103},
#  {'id': '56e181d9e3433e1400422fa3',
#   'prediction_text': 'binary notation',
#   'no_answer_probability': 6.631064849748857e-05},
#  {'id': '56e181d9e3433e1400422fa4',
#   'prediction_text': 'directly via their adjacency matrices, or by encoding their adjacency lists in binary',
#   'no_answer_probability': 0.007695647178392188},
#  {'id': '5ad5391e5b96ef001a10aba2',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999997605969795},
#  {'id': '5ad5391e5b96ef001a10aba3',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999360045077},
#  {'id': '5ad5391e5b96ef001a10aba4',
#   'prediction_text': '',
#   'no_answer_probability': 0.8910549527982959},
#  {'id': '5ad5391e5b96ef001a10aba5',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999853292279994},
#  {'id': '5ad5391e5b96ef001a10aba6',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999925333280311},
#  {'id': '56e190bce3433e1400422fc8',
#   'prediction_text': 'Decision problems',
#   'no_answer_probability': 1.1256751152999319e-05},
#  {'id': '56e190bce3433e1400422fc9',
#   'prediction_text': '1 or 0',
#   'no_answer_probability': 0.03149938030244345},
#  {'id': '56e190bce3433e1400422fca',
#   'prediction_text': '1 or 0',
#   'no_answer_probability': 0.012147170099805133},
#  {'id': '56e190bce3433e1400422fcb',
#   'prediction_text': 'yes',
#   'no_answer_probability': 0.000538927395869352},
#  {'id': '56e190bce3433e1400422fcc',
#   'prediction_text': 'yes',
#   'no_answer_probability': 0.0008247465245442326},
#  {'id': '5ad53b9d5b96ef001a10abc8',
#   'prediction_text': '',
#   'no_answer_probability': 0.9539660976007597},
#  {'id': '5ad53b9d5b96ef001a10abc9',
#   'prediction_text': '',
#   'no_answer_probability': 0.9904406006529085},
#  {'id': '5ad53b9d5b96ef001a10abca',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999937739967},
#  {'id': '5ad53b9d5b96ef001a10abcb',
#   'prediction_text': '',
#   'no_answer_probability': 0.9690910414827888},
#  {'id': '5ad53b9d5b96ef001a10abcc',
#   'prediction_text': 'yes',
#   'no_answer_probability': 0.0019570169401946333},
#  {'id': '56e19557e3433e1400422fee',
#   'prediction_text': 'arbitrary',
#   'no_answer_probability': 0.01024860192315863},
#  {'id': '56e19557e3433e1400422ff0',
#   'prediction_text': 'formal language',
#   'no_answer_probability': 0.00039280794303510477},
#  {'id': '56e19557e3433e1400422ff1',
#   'prediction_text': 'how graphs are encoded as binary strings',
#   'no_answer_probability': 0.34775858364472695},
#  {'id': '5ad53d705b96ef001a10abd2',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999982262833566},
#  {'id': '5ad53d705b96ef001a10abd3',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999885038083},
#  {'id': '5ad53d705b96ef001a10abd4',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999998967319295},
#  {'id': '5ad53d705b96ef001a10abd5',
#   'prediction_text': '',
#   'no_answer_probability': 0.999999909398672},
#  {'id': '56e19724cd28a01900c679f6',
#   'prediction_text': 'computational problem',
#   'no_answer_probability': 0.0003071427867865988},
#  {'id': '56e19724cd28a01900c679f7',
#   'prediction_text': 'a single',
#   'no_answer_probability': 0.00019525368469422547},
#  {'id': '56e19724cd28a01900c679f8',
#   'prediction_text': 'function problem',
#   'no_answer_probability': 5.307507822667364e-05},
#  {'id': '56e19724cd28a01900c679f9',
#   'prediction_text': 'integer factorization problem',
#   'no_answer_probability': 9.895928162244041e-05},
#  {'id': '56e19724cd28a01900c679fa',
#   'prediction_text': 'complex',
#   'no_answer_probability': 2.6019439017511468e-05},
#  {'id': '5ad53e615b96ef001a10abda',
#   'prediction_text': '',
#   'no_answer_probability': 0.9998618066757615},
#  {'id': '5ad53e615b96ef001a10abdb',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999331947684},
#  {'id': '5ad53e615b96ef001a10abdc',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999288941282126},
#  {'id': '5ad53e615b96ef001a10abdd',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999864276934},
#  {'id': '5ad53e615b96ef001a10abde',
#   'prediction_text': 'complex',
#   'no_answer_probability': 7.982876083720604e-05},
#  {'id': '56e1a0dccd28a01900c67a2e',
#   'prediction_text': 'decision problems',
#   'no_answer_probability': 0.0012424173581033714},
#  {'id': '56e1a0dccd28a01900c67a2f',
#   'prediction_text': 'triples',
#   'no_answer_probability': 0.00021235659825357737},
#  {'id': '5ad53f815b96ef001a10abe4',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999988244915368},
#  {'id': '5ad53f815b96ef001a10abe5',
#   'prediction_text': '',
#   'no_answer_probability': 0.999960883449675},
#  {'id': '5ad53f815b96ef001a10abe6',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999702974007},
#  {'id': '56e1a38de3433e140042305c',
#   'prediction_text': 'size of the instance',
#   'no_answer_probability': 0.007891984412351595},
#  {'id': '56e1a38de3433e140042305d',
#   'prediction_text': 'the instance',
#   'no_answer_probability': 0.0005285091055194787},
#  {'id': '56e1a38de3433e140042305e',
#   'prediction_text': 'as a function of the size of the instance',
#   'no_answer_probability': 0.0003282245259583278},
#  {'id': '56e1a38de3433e140042305f',
#   'prediction_text': 'bits',
#   'no_answer_probability': 0.005149607466074953},
#  {'id': '56e1a38de3433e1400423060',
#   'prediction_text': 'input size',
#   'no_answer_probability': 0.00016799534967291814},
#  {'id': '5ad541ad5b96ef001a10abea',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999998943861867},
#  {'id': '5ad541ad5b96ef001a10abeb',
#   'prediction_text': '',
#   'no_answer_probability': 0.999995685987055},
#  {'id': '5ad541ad5b96ef001a10abec',
#   'prediction_text': '',
#   'no_answer_probability': 0.9720986237904434},
#  {'id': '5ad541ad5b96ef001a10abed',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999628383214765},
#  {'id': '5ad541ad5b96ef001a10abee',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999973064932},
#  {'id': '56e1a564cd28a01900c67a48',
#   'prediction_text': 'Cobham',
#   'no_answer_probability': 0.00027159213274713373},
#  {'id': '56e1a564cd28a01900c67a49',
#   'prediction_text': 'the time taken',
#   'no_answer_probability': 0.0015761828049447452},
#  {'id': '56e1a564cd28a01900c67a4a',
#   'prediction_text': '',
#   'no_answer_probability': 0.9667260589136598},
#  {'id': '56e1a564cd28a01900c67a4b',
#   'prediction_text': '',
#   'no_answer_probability': 0.9920002454916221},
#  {'id': '56e1a564cd28a01900c67a4c',
#   'prediction_text': 'polynomial time algorithm',
#   'no_answer_probability': 0.000251186788490731},
#  {'id': '5ad542db5b96ef001a10abf4',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999998199936335},
#  {'id': '5ad542db5b96ef001a10abf5',
#   'prediction_text': '',
#   'no_answer_probability': 0.9993815622028044},
#  {'id': '5ad542db5b96ef001a10abf6',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999986776950035},
#  {'id': '5ad542db5b96ef001a10abf7',
#   'prediction_text': '',
#   'no_answer_probability': 0.999999242145328},
#  {'id': '5ad542db5b96ef001a10abf8',
#   'prediction_text': '',
#   'no_answer_probability': 0.9949885983164881},
#  {'id': '56e1aba0e3433e1400423094',
#   'prediction_text': 'A Turing machine',
#   'no_answer_probability': 0.0010546241771754892},
#  {'id': '56e1aba0e3433e1400423095',
#   'prediction_text': 'an algorithm',
#   'no_answer_probability': 0.00039743639851913467},
#  {'id': '56e1aba0e3433e1400423097',
#   'prediction_text': 'Turing machine',
#   'no_answer_probability': 0.0004850083256040621},
#  {'id': '56e1aba0e3433e1400423098',
#   'prediction_text': 'symbols',
#   'no_answer_probability': 0.0002157000067505086},
#  {'id': '5ad543c05b96ef001a10abfe',
#   'prediction_text': '',
#   'no_answer_probability': 0.9980845002257733},
#  {'id': '5ad543c05b96ef001a10abff',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999060318732237},
#  {'id': '5ad543c05b96ef001a10ac00',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999041188415},
#  {'id': '5ad543c05b96ef001a10ac01',
#   'prediction_text': '',
#   'no_answer_probability': 0.9799765587105447},
#  {'id': '56e1aff7cd28a01900c67a68',
#   'prediction_text': 'deterministic Turing machine',
#   'no_answer_probability': 0.00038521327635874397},
#  {'id': '56e1aff7cd28a01900c67a69',
#   'prediction_text': 'a fixed set of rules',
#   'no_answer_probability': 0.006351235832394431},
#  {'id': '56e1aff7cd28a01900c67a6a',
#   'prediction_text': 'probabilistic Turing machine',
#   'no_answer_probability': 2.3278228613078775e-05},
#  {'id': '56e1aff7cd28a01900c67a6b',
#   'prediction_text': 'non-deterministic Turing machine',
#   'no_answer_probability': 0.03185885568604045},
#  {'id': '56e1aff7cd28a01900c67a6c',
#   'prediction_text': 'randomized algorithms',
#   'no_answer_probability': 5.8857602820831475e-06},
#  {'id': '5ad546c75b96ef001a10ac0e',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999579486794},
#  {'id': '5ad546c75b96ef001a10ac0f',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999975320231771},
#  {'id': '5ad546c75b96ef001a10ac10',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999943972036},
#  {'id': '5ad546c75b96ef001a10ac11',
#   'prediction_text': '',
#   'no_answer_probability': 0.999998735163472},
#  {'id': '5ad546c75b96ef001a10ac12',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999389350744},
#  {'id': '56e1b00ce3433e140042309e',
#   'prediction_text': 'complexity classes',
#   'no_answer_probability': 1.337891888435967e-06},
#  {'id': '56e1b00ce3433e140042309f',
#   'prediction_text': 'time or space) are bounded',
#   'no_answer_probability': 0.005888159475804548},
#  {'id': '56e1b00ce3433e14004230a1',
#   'prediction_text': 'symmetric Turing machines and alternating Turing machines',
#   'no_answer_probability': 0.0019916526378489677},
#  {'id': '5ad545545b96ef001a10ac06',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999953003662},
#  {'id': '5ad545545b96ef001a10ac07',
#   'prediction_text': 'resources (such as time or space) are bounded',
#   'no_answer_probability': 0.05510689943883947},
#  {'id': '5ad545545b96ef001a10ac08',
#   'prediction_text': '',
#   'no_answer_probability': 0.999999970757897},
#  {'id': '5ad545545b96ef001a10ac09',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999979063878},
#  {'id': '56e1b169cd28a01900c67a72',
#   'prediction_text': 'random access machines',
#   'no_answer_probability': 4.71141234840934e-05},
#  {'id': '56e1b169cd28a01900c67a73',
#   'prediction_text': '',
#   'no_answer_probability': 0.8221891305219505},
#  {'id': '56e1b169cd28a01900c67a74',
#   'prediction_text': 'time and memory',
#   'no_answer_probability': 0.0006449432198490946},
#  {'id': '56e1b169cd28a01900c67a75',
#   'prediction_text': 'the machines operate deterministically',
#   'no_answer_probability': 0.00019949312905980011},
#  {'id': '5ad547945b96ef001a10ac18',
#   'prediction_text': '',
#   'no_answer_probability': 0.999993383779222},
#  {'id': '5ad547945b96ef001a10ac19',
#   'prediction_text': 'time and memory consumption',
#   'no_answer_probability': 0.002128110030718733},
#  {'id': '5ad547945b96ef001a10ac1a',
#   'prediction_text': '',
#   'no_answer_probability': 0.7053792935590418},
#  {'id': '5ad547945b96ef001a10ac1b',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999943422206},
#  {'id': '56e1b355e3433e14004230b0',
#   'prediction_text': 'non-deterministic',
#   'no_answer_probability': 0.0003943447435870698},
#  {'id': '56e1b355e3433e14004230b1',
#   'prediction_text': 'more unusual resources',
#   'no_answer_probability': 0.0025065753820135623},
#  {'id': '56e1b355e3433e14004230b2',
#   'prediction_text': 'mathematical models',
#   'no_answer_probability': 0.0026782178534964355},
#  {'id': '56e1b355e3433e14004230b3',
#   'prediction_text': 'time',
#   'no_answer_probability': 0.0364937662290278},
#  {'id': '5ad5489b5b96ef001a10ac2a',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999810089285},
#  {'id': '5ad5489b5b96ef001a10ac2b',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999997239101107},
#  {'id': '5ad5489b5b96ef001a10ac2c',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999984652861},
#  {'id': '5ad5489b5b96ef001a10ac2d',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999788139289},
#  {'id': '5ad5489b5b96ef001a10ac2e',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999998832102751},
#  {'id': '56e1b62ecd28a01900c67aa3',
#   'prediction_text': 'the total number of state transitions',
#   'no_answer_probability': 0.0035038230702441114},
#  {'id': '56e1b62ecd28a01900c67aa4',
#   'prediction_text': 'difficulty',
#   'no_answer_probability': 3.748972207984784e-05},
#  {'id': '56e1b62ecd28a01900c67aa5',
#   'prediction_text': 'DTIME(f(n)).',
#   'no_answer_probability': 7.874486427310235e-05},
#  {'id': '56e1b62ecd28a01900c67aa6',
#   'prediction_text': 'time and space',
#   'no_answer_probability': 0.31489265091054125},
#  {'id': '5ad54a375b96ef001a10ac48',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999862408602},
#  {'id': '5ad54a375b96ef001a10ac49',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999997651032},
#  {'id': '5ad54a375b96ef001a10ac4a',
#   'prediction_text': 'DTIME(f(n)).',
#   'no_answer_probability': 0.000115017355457},
#  {'id': '5ad54a375b96ef001a10ac4b',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999801448318111},
#  {'id': '5ad54a375b96ef001a10ac4c',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999047384535359},
#  {'id': '56e1b754cd28a01900c67abc',
#   'prediction_text': 'complexity',
#   'no_answer_probability': 0.00016636302631944773},
#  {'id': '56e1b754cd28a01900c67abd',
#   'prediction_text': 'computational',
#   'no_answer_probability': 0.48340453559462787},
#  {'id': '56e1b754cd28a01900c67abe',
#   'prediction_text': 'Blum complexity axioms',
#   'no_answer_probability': 1.2705822488467692e-05},
#  {'id': '56e1b754cd28a01900c67abf',
#   'prediction_text': 'Complexity measures are very generally defined by the Blum complexity axioms. Other complexity',
#   'no_answer_probability': 8.699182836045935e-05},
#  {'id': '56e1b754cd28a01900c67ac0',
#   'prediction_text': 'complexity',
#   'no_answer_probability': 0.0010505169064556233},
#  {'id': '5ad54b035b96ef001a10ac52',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999909765357},
#  {'id': '5ad54b035b96ef001a10ac53',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999975996618},
#  {'id': '5ad54b035b96ef001a10ac54',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999919586743},
#  {'id': '5ad54b035b96ef001a10ac55',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999971102891},
#  {'id': '5ad54b035b96ef001a10ac56',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999993862704949},
#  {'id': '56e1b8f3e3433e14004230e6',
#   'prediction_text': 'best, worst and average',
#   'no_answer_probability': 0.0006349506508316176},
#  {'id': '56e1b8f3e3433e14004230e7',
#   'prediction_text': '',
#   'no_answer_probability': 0.9304582554941719},
#  {'id': '56e1b8f3e3433e14004230e8',
#   'prediction_text': '',
#   'no_answer_probability': 0.8824278664544912},
#  {'id': '56e1b8f3e3433e14004230e9',
#   'prediction_text': '',
#   'no_answer_probability': 0.6361270987720502},
#  {'id': '5ad54c2f5b96ef001a10ac5c',
#   'prediction_text': 'best, worst and average',
#   'no_answer_probability': 0.070176298439968},
#  {'id': '5ad54c2f5b96ef001a10ac5d',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999942806820133},
#  {'id': '5ad54c2f5b96ef001a10ac5e',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999941128025976},
#  {'id': '5ad54c2f5b96ef001a10ac5f',
#   'prediction_text': '',
#   'no_answer_probability': 0.999939961169196},
#  {'id': '56e1ba41cd28a01900c67ae0',
#   'prediction_text': 'quicksort',
#   'no_answer_probability': 0.0004092474464933876},
#  {'id': '56e1ba41cd28a01900c67ae1',
#   'prediction_text': 'worst-case',
#   'no_answer_probability': 0.0553106522159961},
#  {'id': '56e1ba41cd28a01900c67ae2',
#   'prediction_text': 'O(n2)',
#   'no_answer_probability': 0.010570488620307572},
#  {'id': '5ad54d625b96ef001a10ac64',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999975523195},
#  {'id': '5ad54d625b96ef001a10ac65',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999570390392049},
#  {'id': '5ad54d625b96ef001a10ac66',
#   'prediction_text': '',
#   'no_answer_probability': 0.9548162433273092},
#  {'id': '5ad54d625b96ef001a10ac67',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999872748758},
#  {'id': '5ad54d625b96ef001a10ac68',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999943400638407},
#  {'id': '56e1bc3ae3433e1400423104',
#   'prediction_text': 'the most efficient algorithm solving a given problem',
#   'no_answer_probability': 0.0018712103000360922},
#  {'id': '56e1bc3ae3433e1400423105',
#   'prediction_text': 'analysis of algorithms',
#   'no_answer_probability': 0.004962942101872842},
#  {'id': '56e1bc3ae3433e1400423106',
#   'prediction_text': 'lower bounds',
#   'no_answer_probability': 0.016689061601468685},
#  {'id': '56e1bc3ae3433e1400423107',
#   'prediction_text': '',
#   'no_answer_probability': 0.7158214700253839},
#  {'id': '56e1bc3ae3433e1400423108',
#   'prediction_text': '',
#   'no_answer_probability': 0.9286679988850831},
#  {'id': '5ad54e7c5b96ef001a10ac76',
#   'prediction_text': 'one is interested in proving upper and lower bounds on the minimum amount of time required by the most efficient algorithm solving a given problem',
#   'no_answer_probability': 0.010735162609090678},
#  {'id': '5ad54e7c5b96ef001a10ac77',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999593219892},
#  {'id': '5ad54e7c5b96ef001a10ac78',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999959486625},
#  {'id': '5ad54e7c5b96ef001a10ac79',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999963184127},
#  {'id': '5ad54e7c5b96ef001a10ac7a',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999961381311384},
#  {'id': '56e1bd4acd28a01900c67afc',
#   'prediction_text': 'big O notation',
#   'no_answer_probability': 2.689784467408732e-05},
#  {'id': '56e1bd4acd28a01900c67afd',
#   'prediction_text': 'constant factors and smaller terms',
#   'no_answer_probability': 5.761219097124058e-05},
#  {'id': '56e1bd4acd28a01900c67afe',
#   'prediction_text': 'T(n) = O(n2).',
# ...
#   'no_answer_probability': 0.00047193222743899363},
#  {'id': '57060df252bb891400689821',
#   'prediction_text': 'Downtown Riverside',
#   'no_answer_probability': 0.006475691544916451},
#  {'id': '57060df252bb891400689822',
#   'prediction_text': 'Hospitality Business/Financial Centre',
#   'no_answer_probability': 1.6410412180322812e-05},
#  {'id': '5ad0475c77cf76001a686f86',
#   'prediction_text': 'Downtown San Bernardino, Hospitality Business/Financial Centre, University Town',
#   'no_answer_probability': 0.06903792817479},
#  {'id': '5ad0475c77cf76001a686f87',
#   'prediction_text': '',
#   'no_answer_probability': 0.9924666933268805},
#  {'id': '57060eaf75f01819005e7910',
#   'prediction_text': 'Orange County',
#   'no_answer_probability': 0.0004565269236873427},
#  {'id': '57060eaf75f01819005e7911',
#   'prediction_text': 'University of California, Irvine',
#   'no_answer_probability': 3.71979856004292e-05},
#  {'id': '57060eaf75f01819005e7912',
#   'prediction_text': 'West Irvine',
#   'no_answer_probability': 3.453725236238312e-05},
#  {'id': '57060eaf75f01819005e7913',
#   'prediction_text': 'South Coast Metro',
#   'no_answer_probability': 9.591491663639704e-05},
#  {'id': '57060eaf75f01819005e7914',
#   'prediction_text': 'rapidly',
#   'no_answer_probability': 7.339867668136992e-05},
#  {'id': '5ad0483977cf76001a686f8a',
#   'prediction_text': 'Orange County',
#   'no_answer_probability': 0.03817827426156642},
#  {'id': '5ad0483977cf76001a686f8b',
#   'prediction_text': '',
#   'no_answer_probability': 0.9637799441350253},
#  {'id': '5ad0483977cf76001a686f8c',
#   'prediction_text': 'international corporations',
#   'no_answer_probability': 0.024609928625961945},
#  {'id': '5ad0483977cf76001a686f8d',
#   'prediction_text': '',
#   'no_answer_probability': 0.9864417542337218},
#  {'id': '57060f3e75f01819005e7922',
#   'prediction_text': 'Downtown San Diego',
#   'no_answer_probability': 1.075026616101254e-06},
#  {'id': '57060f3e75f01819005e7923',
#   'prediction_text': 'Northern San Diego',
#   'no_answer_probability': 0.000373365934854313},
#  {'id': '57060f3e75f01819005e7924',
#   'prediction_text': 'North County',
#   'no_answer_probability': 3.3084709357610544e-05},
#  {'id': '57060f3e75f01819005e7925',
#   'prediction_text': 'San Diego',
#   'no_answer_probability': 0.0011972111981317268},
#  {'id': '5ad04b2377cf76001a686f92',
#   'prediction_text': '',
#   'no_answer_probability': 0.6680145362320873},
#  {'id': '5ad04b2377cf76001a686f93',
#   'prediction_text': '',
#   'no_answer_probability': 0.9903663476405535},
#  {'id': '5ad04b2377cf76001a686f94',
#   'prediction_text': '',
#   'no_answer_probability': 0.9988575504601823},
#  {'id': '570610b275f01819005e792a',
#   'prediction_text': 'Los Angeles International Airport',
#   'no_answer_probability': 4.647439810053512e-05},
#  {'id': '570610b275f01819005e792b',
#   'prediction_text': 'passenger volume',
#   'no_answer_probability': 0.042087727915618836},
#  {'id': '570610b275f01819005e792c',
#   'prediction_text': 'third',
#   'no_answer_probability': 0.000602354126495203},
#  {'id': '570610b275f01819005e792d',
#   'prediction_text': 'San Diego International Airport',
#   'no_answer_probability': 2.58674310813544e-05},
#  {'id': '570610b275f01819005e792e',
#   'prediction_text': 'Van Nuys Airport',
#   'no_answer_probability': 1.471022341746074e-05},
#  {'id': '5ad04bfc77cf76001a686f98',
#   'prediction_text': '',
#   'no_answer_probability': 0.9224823435231172},
#  {'id': '5ad04bfc77cf76001a686f99',
#   'prediction_text': 'San Diego International Airport',
#   'no_answer_probability': 0.09334687851957547},
#  {'id': '5ad04bfc77cf76001a686f9a',
#   'prediction_text': '',
#   'no_answer_probability': 0.9903102833254365},
#  {'id': '5ad04bfc77cf76001a686f9b',
#   'prediction_text': 'Orange County, Bakersfield, Ontario, Burbank and Long Beach',
#   'no_answer_probability': 0.06730107458490008},
#  {'id': '5706111a52bb89140068984c',
#   'prediction_text': 'Metrolink',
#   'no_answer_probability': 7.058701601549535e-05},
#  {'id': '5706111a52bb89140068984d',
#   'prediction_text': 'seven',
#   'no_answer_probability': 0.0006680048639588462},
#  {'id': '5706111a52bb89140068984e',
#   'prediction_text': 'Six',
#   'no_answer_probability': 0.0004092474464933876},
#  {'id': '5706111a52bb89140068984f',
#   'prediction_text': 'Orange',
#   'no_answer_probability': 0.3065270453190574},
#  {'id': '5ad04d3077cf76001a686fa0',
#   'prediction_text': '',
#   'no_answer_probability': 0.9975225547581584},
#  {'id': '5ad04d3077cf76001a686fa1',
#   'prediction_text': 'Metrolink',
#   'no_answer_probability': 0.007345826574477061},
#  {'id': '5ad04d3077cf76001a686fa2',
#   'prediction_text': '',
#   'no_answer_probability': 0.9549844683997677},
#  {'id': '570611c475f01819005e793c',
#   'prediction_text': 'Port of Los Angeles',
#   'no_answer_probability': 7.558067277940654e-05},
#  {'id': '570611c475f01819005e793d',
#   'prediction_text': 'Port of Long Beach',
#   'no_answer_probability': 8.0763495459825e-06},
#  {'id': '570611c475f01819005e793e',
#   'prediction_text': 'Southern',
#   'no_answer_probability': 5.671904740038749e-05},
#  {'id': '5ad04de377cf76001a686fa6',
#   'prediction_text': '',
#   'no_answer_probability': 0.5448013956982781},
#  {'id': '5ad04de377cf76001a686fa7',
#   'prediction_text': '',
#   'no_answer_probability': 0.7732163651347154},
#  {'id': '5ad04de377cf76001a686fa8',
#   'prediction_text': '',
#   'no_answer_probability': 0.7943849604299823},
#  {'id': '5ad04de377cf76001a686fa9',
#   'prediction_text': 'Port of Los Angeles',
#   'no_answer_probability': 0.004007288945911384},
#  {'id': '5706139252bb891400689864',
#   'prediction_text': 'The Tech Coast',
#   'no_answer_probability': 0.002054744574393517},
#  {'id': '5706139252bb891400689865',
#   'prediction_text': 'research',
#   'no_answer_probability': 8.648364497085594e-05},
#  {'id': '5706139252bb891400689866',
#   'prediction_text': 'private institutions',
#   'no_answer_probability': 0.00011235328063870752},
#  {'id': '5706139252bb891400689867',
#   'prediction_text': '5',
#   'no_answer_probability': 0.0008492456216931709},
#  {'id': '5706139252bb891400689868',
#   'prediction_text': '12',
#   'no_answer_probability': 0.00023322322859006098},
#  {'id': '5ad04ecf77cf76001a686fae',
#   'prediction_text': 'Irvine, Los Angeles, Riverside, Santa Barbara, and San Diego',
#   'no_answer_probability': 0.0012793074828344202},
#  {'id': '5ad04ecf77cf76001a686faf',
#   'prediction_text': '12',
#   'no_answer_probability': 0.1108555949252609},
#  {'id': '5ad04ecf77cf76001a686fb0',
#   'prediction_text': '12',
#   'no_answer_probability': 0.04193052356366861},
#  {'id': '5ad04ecf77cf76001a686fb1',
#   'prediction_text': '',
#   'no_answer_probability': 0.9997388096809043},
#  {'id': '5ad04ecf77cf76001a686fb2',
#   'prediction_text': '',
#   'no_answer_probability': 0.9994801880178869},
#  {'id': '5706143575f01819005e7950',
#   'prediction_text': 'Professional',
#   'no_answer_probability': 3.9365628661091304e-05},
#  {'id': '5706143575f01819005e7951',
#   'prediction_text': 'NBA',
#   'no_answer_probability': 0.00023276826494601476},
#  {'id': '5706143575f01819005e7952',
#   'prediction_text': 'MLB',
#   'no_answer_probability': 0.0001395492902440564},
#  {'id': '5706143575f01819005e7953',
#   'prediction_text': 'Los Angeles Kings',
#   'no_answer_probability': 0.00011412238544346031},
#  {'id': '5706143575f01819005e7954',
#   'prediction_text': 'LA Galaxy',
#   'no_answer_probability': 0.0067580871064780975},
#  {'id': '5ad04f7977cf76001a686fb8',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999809316607029},
#  {'id': '5ad04f7977cf76001a686fb9',
#   'prediction_text': '',
#   'no_answer_probability': 0.9996590379774362},
#  {'id': '5ad04f7977cf76001a686fba',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999957106668901},
#  {'id': '5ad04f7977cf76001a686fbb',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999857658323139},
#  {'id': '5ad04f7977cf76001a686fbc',
#   'prediction_text': '',
#   'no_answer_probability': 0.9858003197936877},
#  {'id': '5706149552bb891400689880',
#   'prediction_text': 'Chivas USA',
#   'no_answer_probability': 0.0002487463383385775},
#  {'id': '5706149552bb891400689881',
#   'prediction_text': 'two',
#   'no_answer_probability': 0.001579259428801316},
#  {'id': '5706149552bb891400689882',
#   'prediction_text': '2014',
#   'no_answer_probability': 0.005030917078363314},
#  {'id': '5706149552bb891400689883',
#   'prediction_text': 'StubHub Center',
#   'no_answer_probability': 1.9679025610662343e-05},
#  {'id': '5706149552bb891400689884',
#   'prediction_text': '2018',
#   'no_answer_probability': 0.045437217644639455},
#  {'id': '5ad050c877cf76001a686fc2',
#   'prediction_text': 'two',
#   'no_answer_probability': 0.00017536993773773873},
#  {'id': '5ad050c877cf76001a686fc3',
#   'prediction_text': '',
#   'no_answer_probability': 0.665410558746814},
#  {'id': '5ad050c877cf76001a686fc4',
#   'prediction_text': '',
#   'no_answer_probability': 0.9996828010288636},
#  {'id': '5ad050c877cf76001a686fc5',
#   'prediction_text': '',
#   'no_answer_probability': 0.9989371130945769},
#  {'id': '570614ff52bb89140068988a',
#   'prediction_text': 'College',
#   'no_answer_probability': 0.00018342603186166003},
#  {'id': '570614ff52bb89140068988b',
#   'prediction_text': 'UCLA',
#   'no_answer_probability': 0.013350851012744882},
#  {'id': '570614ff52bb89140068988c',
#   'prediction_text': 'Trojans',
#   'no_answer_probability': 0.00042140934820029377},
#  {'id': '570614ff52bb89140068988d',
#   'prediction_text': 'Pac-12 Conference',
#   'no_answer_probability': 0.024609928625961945},
#  {'id': '570614ff52bb89140068988e',
#   'prediction_text': 'Division I',
#   'no_answer_probability': 9.18812330093012e-05},
#  {'id': '5ad0511577cf76001a686fca',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999974009229626},
#  {'id': '5ad0511577cf76001a686fcb',
#   'prediction_text': 'Trojans',
#   'no_answer_probability': 0.14657520915950842},
#  {'id': '5ad0511577cf76001a686fcc',
#   'prediction_text': '',
#   'no_answer_probability': 0.9985133846890513},
#  {'id': '5706155352bb891400689894',
#   'prediction_text': 'Rugby',
#   'no_answer_probability': 0.0021827164453451808},
#  {'id': '5706155352bb891400689895',
#   'prediction_text': 'high school',
#   'no_answer_probability': 9.142760396925338e-06},
#  {'id': '5706155352bb891400689896',
#   'prediction_text': 'official school sport',
#   'no_answer_probability': 9.44280341008577e-05},
#  {'id': '5ad051be77cf76001a686fd0',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999944193036027},
#  {'id': '57092322efce8f15003a7db0',
#   'prediction_text': 'BSkyB',
#   'no_answer_probability': 0.0002046221872743099},
#  {'id': '57092322efce8f15003a7db1',
#   'prediction_text': 'BSkyB',
#   'no_answer_probability': 7.951138347609496e-06},
#  {'id': '57092322efce8f15003a7db2',
#   'prediction_text': '2014',
#   'no_answer_probability': 9.915273115920184e-05},
#  {'id': '57092322efce8f15003a7db3',
#   'prediction_text': 'British Sky Broadcasting Group plc',
#   'no_answer_probability': 0.00010910978391445432},
#  {'id': '57092322efce8f15003a7db4',
#   'prediction_text': 'Sky UK Limited',
#   'no_answer_probability': 0.0038468720505935136},
#  {'id': '5a2c08aebfd06b001a5ae989',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999986956503473},
#  {'id': '5a2c08aebfd06b001a5ae98a',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999947878095},
#  {'id': '5a2c08aebfd06b001a5ae98b',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999989064434814},
#  {'id': '5a2c08aebfd06b001a5ae98c',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999998858042408},
#  {'id': '5a2c08aebfd06b001a5ae98d',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999293016654},
#  {'id': '57094a79efce8f15003a7dc4',
#   'prediction_text': '2006',
#   'no_answer_probability': 0.0013354008189733722},
#  {'id': '57094a79efce8f15003a7dc5',
#   'prediction_text': 'two',
#   'no_answer_probability': 0.0016009643344723696},
#  {'id': '57094a79efce8f15003a7dc6',
#   'prediction_text': 'Sky',
#   'no_answer_probability': 0.0005692035297118063},
#  {'id': '57094a79efce8f15003a7dc7',
#   'prediction_text': '£1.3bn',
#   'no_answer_probability': 0.0005781619985816635},
#  {'id': '5a2c0c2fbfd06b001a5ae99b',
#   'prediction_text': '',
#   'no_answer_probability': 0.999998497969815},
#  {'id': '5a2c0c2fbfd06b001a5ae99c',
#   'prediction_text': '',
#   'no_answer_probability': 0.9577545043363116},
#  {'id': '5a2c0c2fbfd06b001a5ae99d',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999540053039929},
#  {'id': '5a2c0c2fbfd06b001a5ae99e',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999927129665239},
#  {'id': '5a2c0c2fbfd06b001a5ae99f',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999996615624052},
#  {'id': '57094b4f9928a814004714f6',
#   'prediction_text': 'ONdigital',
#   'no_answer_probability': 2.01456908529364e-05},
#  {'id': '57094b4f9928a814004714f7',
#   'prediction_text': "ITV Digital's free-to-air replacement, Freeview",
#   'no_answer_probability': 0.19314738002256465},
#  {'id': '57094b4f9928a814004714f8',
#   'prediction_text': 'three',
#   'no_answer_probability': 0.0024154832575663415},
#  {'id': '57094b4f9928a814004714f9',
#   'prediction_text': 'Sky Three',
#   'no_answer_probability': 0.00045386099327526173},
#  {'id': '57094b4f9928a814004714fa',
#   'prediction_text': '',
#   'no_answer_probability': 0.995354442450284},
#  {'id': '5a2c14b4bfd06b001a5ae9d3',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999985045560414},
#  {'id': '5a2c14b4bfd06b001a5ae9d4',
#   'prediction_text': '',
#   'no_answer_probability': 0.9991109024118872},
#  {'id': '5a2c14b4bfd06b001a5ae9d5',
#   'prediction_text': '',
#   'no_answer_probability': 0.9884918509356967},
#  {'id': '5a2c14b4bfd06b001a5ae9d6',
#   'prediction_text': '',
#   'no_answer_probability': 0.9998788735868865},
#  {'id': '5a2c14b4bfd06b001a5ae9d7',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999997654566101},
#  {'id': '57094ca7efce8f15003a7dd6',
#   'prediction_text': 'Sky+ PVR',
#   'no_answer_probability': 0.0003982130906163543},
#  {'id': '57094ca7efce8f15003a7dd7',
#   'prediction_text': 'September 2007',
#   'no_answer_probability': 7.76756834641502e-05},
#  {'id': '57094ca7efce8f15003a7dd8',
#   'prediction_text': 'pay a monthly fee',
#   'no_answer_probability': 0.0027097022927968584},
#  {'id': '57094ca7efce8f15003a7dd9',
#   'prediction_text': 'January 2010',
#   'no_answer_probability': 2.931153855960119e-05},
#  {'id': '57094ca7efce8f15003a7dda',
#   'prediction_text': 'Sky+HD Box',
#   'no_answer_probability': 0.0008215337841091554},
#  {'id': '5a2c16e3bfd06b001a5ae9e7',
#   'prediction_text': '',
#   'no_answer_probability': 0.997263778900852},
#  {'id': '5a2c16e3bfd06b001a5ae9e8',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999970382767793},
#  {'id': '5a2c16e3bfd06b001a5ae9e9',
#   'prediction_text': '',
#   'no_answer_probability': 0.9994161675418086},
#  {'id': '5a2c16e3bfd06b001a5ae9ea',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999325135090215},
#  {'id': '5a2c16e3bfd06b001a5ae9eb',
#   'prediction_text': '',
#   'no_answer_probability': 0.9347534342381864},
#  {'id': '57094d489928a8140047150a',
#   'prediction_text': 'VideoGuard',
#   'no_answer_probability': 6.631064849748857e-05},
#  {'id': '57094d489928a8140047150b',
#   'prediction_text': 'NDS',
#   'no_answer_probability': 0.009376237450848677},
#  {'id': '57094d489928a8140047150c',
#   'prediction_text': 'Cisco Systems',
#   'no_answer_probability': 0.06394842065123194},
#  {'id': '57094d489928a8140047150d',
#   'prediction_text': 'BSkyB',
#   'no_answer_probability': 0.00010472557180794286},
#  {'id': '57094d489928a8140047150e',
#   'prediction_text': 'Sky+',
#   'no_answer_probability': 9.915273115920184e-05},
#  {'id': '5a2c3a5cbfd06b001a5aea79',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999994323929693},
#  {'id': '5a2c3a5cbfd06b001a5aea7a',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999999824361302},
#  {'id': '5a2c3a5cbfd06b001a5aea7b',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999974286932398},
#  {'id': '5a2c3a5cbfd06b001a5aea7c',
#   'prediction_text': '',
#   'no_answer_probability': 0.999999977226227},
#  {'id': '5a2c3a5cbfd06b001a5aea7d',
#   'prediction_text': '',
#   'no_answer_probability': 0.9999947885245446},
#  {'id': '570953a7efce8f15003a7dfe',
#   'prediction_text': '2007',
#   'no_answer_probability': 7.02432170975006e-05},
#  ...]

# %%
predictions_dict = {pred['id']: pred['prediction_text'] for pred in formatted_predictions}

# %%
# Create the no-answer probabilities dictionary
na_probs_dict = {pred['id']: pred['no_answer_probability'] for pred in formatted_predictions}

# %%
def save_predictions(predictions, filename):
    with open(filename, 'w') as f:
        json.dump(predictions, f)

# %%
# Save the predictions and no-answer probabilities to JSON files
save_predictions(predictions_dict, '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/predictions_roberta_large.json')
save_predictions(na_probs_dict, '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/na_probs_roberta_large.json')

# %%
trainer.push_to_hub(commit_message="Training complete")
# Out:
# CommitInfo(commit_url='https://huggingface.co/ozgurkk/roberta-large-finetuned-squad/commit/2f03dbf6187571b1bd1b11cbe0380ccfc2dc23f4', commit_message='Training complete', commit_description='', oid='2f03dbf6187571b1bd1b11cbe0380ccfc2dc23f4', pr_url=None, pr_revision=None, pr_num=None)

# %%
# Paths to the evaluation script and data files
eval_script_path = '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/SQuAD/evaluate-v2.0.py'
data_file_path = '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/SQuAD/dev-v2.0.json'
pred_file_path = '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/predictions_roberta_large.json'
na_prob_file_path = '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/na_probs_roberta_large.json'
out_file_path = '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/eval_results_roberta_large.json'
out_image_dir = '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/images_roberta_large'

# %%
# Command to run the evaluation script
command = [
    'python', eval_script_path,
    data_file_path,
    pred_file_path,
    '-n', na_prob_file_path,
    '-o', out_file_path,
    '-p', out_image_dir
]

# %%
# Use the evaluation script
import subprocess
subprocess.run(command, check=True)
# Out:
# CompletedProcess(args=['python', '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/SQuAD/evaluate-v2.0.py', '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/SQuAD/dev-v2.0.json', '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/predictions_roberta_large.json', '-n', '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/na_probs_roberta_large.json', '-o', '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/eval_results_roberta_large.json', '-p', '/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/model_outputs/images_roberta_large'], returncode=0)

# %%
import json

# %%
# Load the predictions and no-answer probabilities
with open('/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/SQuAD/predictions_roberta_v2.json') as f:
    predictions = json.load(f)

with open('/content/drive/MyDrive/Colab Notebooks/E.ON_Data_Challenge/SQuAD/na_probs_roberta_v2.json') as f:
    na_probs = json.load(f)

# %%
# Inspect some predictions and their no-answer probabilities
for qid, pred in list(predictions.items())[:10]:
    print(f"Question ID: {qid}")
    print(f"Prediction: {pred}")
    print(f"No-Answer Probability: {na_probs[qid]}")
    print()
# Out:
# Question ID: 56ddde6b9a695914005b9628
# Prediction: France
# No-Answer Probability: 1.2380037591258592e-09
#
# Question ID: 56ddde6b9a695914005b9629
# Prediction: 10th and 11th centuries
# No-Answer Probability: 9.307120690588079e-11
#
# Question ID: 56ddde6b9a695914005b962a
# Prediction: Denmark, Iceland and Norway
# No-Answer Probability: 0.0009584648438362855
#
# Question ID: 56ddde6b9a695914005b962b
# Prediction: Rollo
# No-Answer Probability: 6.096360547613931e-06
#
# Question ID: 56ddde6b9a695914005b962c
# Prediction: 10th
# No-Answer Probability: 2.754689953456816e-09
#
# Question ID: 5ad39d53604f3c001a3fe8d1
# Prediction:
# No-Answer Probability: 0.9999999838824869
#
# Question ID: 5ad39d53604f3c001a3fe8d2
# Prediction:
# No-Answer Probability: 0.9999963950646829
#
# Question ID: 5ad39d53604f3c001a3fe8d3
# Prediction: West Francia
# No-Answer Probability: 0.1364357087286803
#
# Question ID: 5ad39d53604f3c001a3fe8d4
# Prediction:
# No-Answer Probability: 0.9999999998804943
#
# Question ID: 56dddf4066d3e219004dad5f
# Prediction: William the Conqueror
# No-Answer Probability: 7.439225783222888e-07

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# now it seems like the model is working fine - lets check some answers first and then build and interface
# test some questions and answers
from transformers import AutoTokenizer, AutoModelForQuestionAnswering, pipeline

# Load the fine-tuned model
model_name = "ozgurkk/roberta-base-finetuned-squad"  # Replace with your model path or name
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForQuestionAnswering.from_pretrained(model_name)

# Initialize the QA pipeline
qa_pipeline = pipeline('question-answering', model=model, tokenizer=tokenizer)

# Define a function to handle no-answer logic
def get_answer(question, context, threshold=0.5):
    result = qa_pipeline(question=question, context=context)
    answer = result['answer']
    score = result['score']
    start = result['start']
    end = result['end']

    # Apply the no-answer logic
    if score < threshold or start == end:
        return {"answer": "", "score": score, "no_answer_probability": 1 - score}
    else:
        return {"answer": answer, "score": score, "no_answer_probability": 1 - score}

# Test examples
context = "The Eiffel Tower is located in Paris and is one of the most famous landmarks in the world."
question_1 = "Where is the Eiffel Tower located?"
question_2 = "Who designed the Statue of Liberty?"

print(get_answer(question_1, context))
print(get_answer(question_2, context))
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.41k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/958 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/705 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/496M [00:00<?, ?B/s]
# {'answer': 'Paris', 'score': 0.9989422559738159, 'no_answer_probability': 0.001057744026184082}
# {'answer': '', 'score': 1.0751947110421156e-09, 'no_answer_probability': 0.9999999989248053}

# %%
# lets move on with the interface
# !pip install transformers gradio
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Collecting gradio
#   Downloading gradio-4.37.2-py3-none-any.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 64.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.2.2)
# Collecting fastapi (from gradio)
#   Downloading fastapi-0.111.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 14.1 MB/s eta 0:00:00
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.3.2.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==1.0.2 (from gradio)
#   Downloading gradio_client-1.0.2-py3-none-any.whl (318 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.2/318.2 kB 38.7 MB/s eta 0:00:00
# Collecting httpx>=0.24.1 (from gradio)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.7.1)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.10.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 17.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.0.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (9.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.8.0)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting python-multipart>=0.0.9 (from gradio)
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Collecting ruff>=0.2.2 (from gradio)
#   Downloading ruff-0.5.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 45.4 MB/s eta 0:00:00
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting tomlkit==0.12.0 (from gradio)
#   Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.12.3)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.12.2)
# Requirement already satisfied: urllib3~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.0.7)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.30.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.0.2->gradio) (2023.6.0)
# Collecting websockets<12.0,>=10.0 (from gradio-client==1.0.2->gradio)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 18.2 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio) (0.12.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (2024.6.2)
# Collecting httpcore==1.* (from httpx>=0.24.1->gradio)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.24.1->gradio)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (2.20.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi->gradio)
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 11.0 MB/s eta 0:00:00
# Collecting fastapi-cli>=0.0.2 (from fastapi->gradio)
#   Downloading fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi->gradio)
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 8.8 MB/s eta 0:00:00
# Collecting email_validator>=2.0.0 (from fastapi->gradio)
#   Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi->gradio)
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 40.2 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.18.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.16.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.24.1->gradio) (1.2.1)
# Collecting httptools>=0.5.0 (from uvicorn>=0.14.0->gradio)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 43.5 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn>=0.14.0->gradio)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn>=0.14.0->gradio)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 105.9 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn>=0.14.0->gradio)
#   Downloading watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 82.9 MB/s eta 0:00:00
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Building wheels for collected packages: ffmpy
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5584 sha256=b15bd8368ab45aa8c93222b4e090f1a886bcb8903b2118d5242f53f75d4ccae2
#   Stored in directory: /root/.cache/pip/wheels/bd/65/9a/671fc6dcde07d4418df0c592f8df512b26d7a0029c2a23dd81
# Successfully built ffmpy
# Installing collected packages: pydub, ffmpy, websockets, uvloop, ujson, tomlkit, semantic-version, ruff, python-multipart, python-dotenv, orjson, httptools, h11, dnspython, aiofiles, watchfiles, uvicorn, starlette, httpcore, email_validator, httpx, gradio-client, fastapi-cli, fastapi, gradio
# Successfully installed aiofiles-23.2.1 dnspython-2.6.1 email_validator-2.2.0 fastapi-0.111.0 fastapi-cli-0.0.4 ffmpy-0.3.2 gradio-4.37.2 gradio-client-1.0.2 h11-0.14.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 orjson-3.10.6 pydub-0.25.1 python-dotenv-1.0.1 python-multipart-0.0.9 ruff-0.5.1 semantic-version-2.10.0 starlette-0.37.2 tomlkit-0.12.0 ujson-5.10.0 uvicorn-0.30.1 uvloop-0.19.0 watchfiles-0.22.0 websockets-11.0.3

# %%
import gradio as gr

def qa_interface(question, context):
    result = get_answer(question, context)
    return result['answer'], result['score'], result['no_answer_probability']

# Create Gradio interface
iface = gr.Interface(
    fn=qa_interface,
    inputs=[gr.Textbox(lines=2, label="Question"), gr.Textbox(lines=5, label="Context")],
    outputs=[gr.Textbox(label="Answer"), gr.Textbox(label="Score"), gr.Textbox(label="No Answer Probability")],
    title="Question Answering Model with No-Answer Handling",
    description="Ask a question based on the provided context. The model will return the answer, the confidence score, and the probability of no answer."
)

# %%
iface.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://6aabd11781340a4862.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://6aabd11781340a4862.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
